# %% [markdown]
# # Capstone Project: Data Scraping for Independent Set

# %% [markdown]
# In this code notebook, we will create an independent dataset on which to deploy the model. The data will be scraped from Singapore brand [GRAYE](https://grayestudio.com), which markets itself as a sustainable designer label.

# %%
# import necessary libraries

import pandas as pd
import numpy as np
import pickle

from bs4 import BeautifulSoup
import requests
import re

# %% [markdown]
# ### Get urls for tshirt products

# %%
# check requests

tee_url = 'https://grayestudio.com/collections/t-shirts'
tee_res = requests.get(tee_url)
tee_res.status_code
# Out:
# 200

# %%
# check scraped text

tee_soup = BeautifulSoup(tee_res.content, 'lxml')
tee_soup.body
# Out:
# <body><div class="edit_popup" style="display: none;">
# <form class="edit_form" data-action="/cart/add" enctype="multipart/form-data" id="edit_cart_popup" method="post">
# </form>
# </div><!-- END app snippet --><!-- END app app block --><script defer="defer" src="https://cdn.shopify.com/extensions/07fd1ccd-f05b-4d31-94d4-a07a2e88cdad/0.4.0/assets/omnisend-in-shop.js" type="text/javascript"></script>
# <script defer="defer" src="https://cdn.shopify.com/extensions/4ab84696-81cc-4661-9fb4-2578a25bce95/0.94.0/assets/appointo_bundle.js" type="text/javascript"></script>
# <script defer="defer" src="https://cdn.shopify.com/extensions/0dc675f6-6451-4e34-ac60-441d0df6340d/5.38.0/assets/hulkcode.js" type="text/javascript"></script>
# <link href="https://cdn.shopify.com/extensions/0dc675f6-6451-4e34-ac60-441d0df6340d/5.38.0/assets/hulkcode.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://monorail-edge.shopifysvc.com" rel="dns-prefetch"/>
# <script>(function(){if ("sendBeacon" in navigator && "performance" in window) {var session_token = document.cookie.match(/_shopify_s=([^;]*)/);function handle_abandonment_event(e) {var entries = performance.getEntries().filter(function(entry) {return /monorail-edge.shopifysvc.com/.test(entry.name);});if (!window.abandonment_tracked && entries.length === 0) {window.abandonment_tracked = true;var currentMs = Date.now();var navigation_start = performance.timing.navigationStart;var payload = {shop_id: 14141076,url: window.location.href,navigation_start,duration: currentMs - navigation_start,session_token: session_token && session_token.length === 2 ? session_token[1] : "",page_type: "collection"};window.navigator.sendBeacon("https://monorail-edge.shopifysvc.com/v1/produce", JSON.stringify({schema_id: "online_store_buyer_site_abandonment/1.1",payload: payload,metadata: {event_created_at_ms: currentMs,event_sent_at_ms: currentMs}}));}}window.addEventListener('pagehide', handle_abandonment_event);}}());</script>
# <script id="web-pixels-manager-setup">(function e(e,n,a,o,t,r,i){function s(e,n){if(document.head){var a=document.createElement("link");e.match(/spin\.dev\/?/)&&(e+="?fast_storefront_renderer=1"),a.rel="preload",a.href=e,n&&(a.as=n);try{document.head.appendChild(a)}catch(e){console&&console.warn&&console.warn("[Web Pixels Manager] Could not append prefetch link tag to DOM.")}}}var l=i||[],d=null!==e;d&&(window.Shopify=window.Shopify||{},window.Shopify.analytics=window.Shopify.analytics||{},window.Shopify.analytics.replayQueue=[],window.Shopify.analytics.publish=function(e,n,a){window.Shopify.analytics.replayQueue.push([e,n,a])});var c=function(){var e="legacy",n="unknown",a=null,o=navigator.userAgent.match(/(Firefox|Chrome)\/(\d+)/i),t=navigator.userAgent.match(/(Edg)\/(\d+)/i),r=navigator.userAgent.match(/(Version)\/(\d+)(.+)(Safari)\/(\d+)/i);r?(n="safari",a=parseInt(r[2],10)):t?(n="edge",a=parseInt(t[2],10)):o&&(n=o[1].toLocaleLowerCase(),a=parseInt(o[2],10));var i={chrome:60,firefox:55,safari:11,edge:80}[n];return void 0!==i&&null!==a&&i<=a&&(e="modern"),e}(),p=c.substring(0,1),f=o.substring(0,1);if(d)try{self.performance.mark("wpm:start")}catch(e){}if(d){var u=self.location.origin,w=(e.webPixelsConfigList||[]).filter((function(e){return"app"===e.type.toLowerCase()}));for(let e=0;e<w.length;e++){s([u,"/wpm@",r,"/web-pixel-",w[e].id,"@",w[e].scriptVersion,"/sandbox/worker.",c,".js"].join(""),"script")}}var h,y,m,g,v,b,_,S,x=[a,"/wpm","/",f,r,p,".js"].join("");h={src:x,async:!0,onload:function(){if(e){var a=window.webPixelsManager.init(e);n(a),window.Shopify.analytics.replayQueue.forEach((function(e){a.publishCustomEvent(e[0],e[1],e[2])})),window.Shopify.analytics.replayQueue=[],window.Shopify.analytics.publish=a.publishCustomEvent,l.indexOf("web_pixels_visitor_api")>-1&&(window.Shopify.analytics.visitor=a.visitor)}},onerror:function(){var n=(e.storefrontBaseUrl?e.storefrontBaseUrl.replace(/\/$/,""):self.location.origin)+"/.well-known/shopify/monorail/unstable/produce_batch",a=JSON.stringify({metadata:{event_sent_at_ms:(new Date).getTime()},events:[{schema_id:"web_pixels_manager_load/2.0",payload:{version:t||"latest",page_url:self.location.href,status:"failed",error_msg:x+" has failed to load"},metadata:{event_created_at_ms:(new Date).getTime()}}]});try{if(self.navigator.sendBeacon.bind(self.navigator)(n,a))return!0}catch(e){}const o=new XMLHttpRequest;try{return o.open("POST",n,!0),o.setRequestHeader("Content-Type","text/plain"),o.send(a),!0}catch(e){console&&console.warn&&console.warn("[Web Pixels Manager] Got an unhandled error while logging a load error.")}return!1}},y=document.createElement("script"),m=h.src,g=h.async||!0,v=h.onload,b=h.onerror,_=document.head,S=document.body,y.async=g,y.src=m,v&&y.addEventListener("load",v),b&&y.addEventListener("error",b),_?_.appendChild(y):S?S.appendChild(y):console.error("Did not find a head or body element to append the script")})({shopId: 14141076,storefrontBaseUrl: "https://grayestudio.com",cdnBaseUrl: "https://grayestudio.com/cdn",surface: "storefront-renderer",enabledBetaFlags: ["web_pixels_async_pixel_refactor"],webPixelsConfigList: [{"id":"51183930","configuration":"{\"pixelCode\":\"CAJF0PRC77U28261QING\"}","eventPayloadVersion":"v1","runtimeContext":"STRICT","scriptVersion":"0.1.0-99c70b3e91db3b02f187f0b0b5db3b0a","type":"APP","apiClientId":4383523},{"id":"shopify-app-pixel","configuration":"{}","eventPayloadVersion":"v1","runtimeContext":"STRICT","scriptVersion":"0559","apiClientId":"shopify-pixel","type":"APP"},{"id":"shopify-custom-pixel","eventPayloadVersion":"v1","runtimeContext":"LAX","scriptVersion":"0559","apiClientId":"shopify-pixel","type":"CUSTOM"}],initData: {"cart":null,"checkout":null,"customer":null,"productVariants":[]},},function pageEvents(webPixelsManagerAPI) {webPixelsManagerAPI.publish("page_viewed");webPixelsManagerAPI.publish("collection_viewed", {"collection":{"id":"109948371032","title":"T-Shirts","productVariants":[{"id":"44289609138490","image":{"s ...
# window.ShopifyAnalytics.meta = window.ShopifyAnalytics.meta || {};
# window.ShopifyAnalytics.meta.currency = 'SGD';
# var meta = {"products":[{"id":8081498636602,"gid":"gid:\/\/shopify\/Product\/8081498636602","vendor":"G R A Y E","type":"Top","variants":[{"id":44289609138490,"price":9200,"name":"V Ribbed Tee - Mint Green - SMALL","public_title":"SMALL","sku":"23TS01G-S"},{"id":44289609171258,"price":9200,"name":"V Ribbed Tee - Mint Green - MEDIUM","public_title":"MEDIUM","sku":"23TS01G-M"},{"id":44289609204026,"price":9200,"name":"V Ribbed Tee - Mint Green - LARGE","public_title":"LARGE","sku":"23TS01G-L"},{"id":44289609236794,"price":9200,"name":"V Ribbed Tee - Mint Green - EXTRA LARGE","public_title":"EXTRA LARGE","sku":"23TS01G-XL"}]},{"id":8078095876410,"gid":"gid:\/\/shopify\/Product\/8078095876410","vendor":"G R A Y E","type":"Top","variants":[{"id":44289610711354,"price":9200,"name":"V Ribbed Tee - Space Blue - SMALL","public_title":"SMALL","sku":"23TS01BL-S"},{"id":44289610744122,"price":9200,"name":"V Ribbed Tee - Space Blue - MEDIUM","public_title":"MEDIUM","sku":"23TS01BL-M"},{"id":44289610776890,"price":9200,"name":"V Ribbed Tee - Space Blue - LARGE","public_title":"LARGE","sku":"23TS01BL-L"},{"id":44289610809658,"price":9200,"name":"V Ribbed Tee - Space Blue - EXTRA LARGE","public_title":"EXTRA LARGE","sku":"23TS01BL-XL"}]},{"id":6984519319640,"gid":"gid:\/\/shopify\/Product\/6984519319640","vendor":"G R A Y E","type":"T-shirt","variants":[{"id":39832738627672,"price":5900,"name":"Cupro tee - Stone - SMALL","public_title":"SMALL","sku":"20TS01BE-S"},{"id":39832738660440,"price":5900,"name":"Cupro tee - Stone - MEDIUM","public_title":"MEDIUM","sku":"20TS01BE-M"},{"id":39832738725976,"price":5900,"name":"Cupro tee - Stone - LARGE","public_title":"LARGE","sku":"20TS01BE-L"},{"id":39832738758744,"price":5900,"name":"Cupro tee - Stone - EXTRA LARGE","public_title":"EXTRA LARGE","sku":"20TS01BE-XL"},{"id":39832738791512,"price":5900,"name":"Cupro tee - Stone - EXTRA EXTRA LARGE","public_title":"EXTRA EXTRA LARGE","sku":"20TS01BE-XXL"}]},{"id":6984523284568,"gid":"gid:\/\/shopify\/Product\/6984523284568","vendor":"G R A Y E","type":"T-shirt","variants":[{"id":39832742625368,"price":5900,"name":"Cupro Tee - Brick - SMALL","public_title":"SMALL","sku":"20TS01R-S"},{"id":39832742690904,"price":5900,"name":"Cupro Tee - Brick - MEDIUM","public_title":"MEDIUM","sku":"20TS01R-M"},{"id":39832742723672,"price":5900,"name":"Cupro Tee - Brick - LARGE","public_title":"LARGE","sku":"20TS01R-L"},{"id":39832742756440,"price":5900,"name":"Cupro Tee - Brick - EXTRA LARGE","public_title":"EXTRA LARGE","sku":"20TS01R-XL"},{"id":39832742789208,"price":5900,"name":"Cupro Tee - Brick - EXTRA EXTRA LARGE","public_title":"EXTRA EXTRA LARGE","sku":"20TS01R-XXL"}]},{"id":8090356875578,"gid":"gid:\/\/shopify\/Product\/8090356875578","vendor":"G R A Y E","type":"T-shirt","variants":[{"id":44316060647738,"price":5900,"name":"Cupro Tee - Jade Green - SMALL","public_title":"SMALL","sku":"20TS01JG-S"},{"id":44316060680506,"price":5900,"name":"Cupro Tee - Jade Green - MEDIUM","public_title":"MEDIUM","sku":"20TS01JG-M"},{"id":44316060713274,"price":5900,"name":"Cupro Tee - Jade Green - LARGE","public_title":"LARGE","sku":"20TS01JG-L"},{"id":44316060746042,"price":5900,"name":"Cupro Tee - Jade Green - EXTRA LARGE","public_title":"EXTRA LARGE","sku":"20TS01JG-XL"},{"id":44316060778810,"price":5900,"name":"Cupro Tee - Jade Green - EXTRA EXTRA LARGE","public_title":"EXTRA EXTRA LARGE","sku":"20TS01JG-XXL"}]},{"id":7309932822616,"gid":"gid:\/\/shopify\/Product\/7309932822616","vendor":"G R A Y E","type":"T-shirt","variants":[{"id":40144509861976,"price":5900,"name":"Cupro Tee - Melange White - SMALL","public_title":"SMALL","sku":"20TS01MW-S"},{"id":40144509894744,"price":5900,"name":"Cupro Tee - Melange White - MEDIUM","public_title":"MEDIUM","sku":"20TS01MW-M"},{"id":40144509927512,"price":5900,"name":"Cupro Tee - Melange White - LARGE","public_title":"LARGE","sku":"20TS01MW-L"},{"id":40144509960280,"price":5900,"name":"Cupro Tee - Melange White - EXTRA LARGE","public_titl ...
# for (var attr in meta) {
#   window.ShopifyAnalytics.meta[attr] = meta[attr];
# }</script>
# <script>window.ShopifyAnalytics.merchantGoogleAnalytics = function() {
#
# };
# </script>
# <script class="analytics">(window.gaDevIds=window.gaDevIds||[]).push('BwiEti');
#
#
# (function () {
#     var customDocumentWrite = function(content) {
#       var jquery = null;
#
#       if (window.jQuery) {
#         jquery = window.jQuery;
#       } else if (window.Checkout && window.Checkout.$) {
#         jquery = window.Checkout.$;
#       }
#
#       if (jquery) {
#         jquery('body').append(content);
#       }
#     };
#
#     var hasLoggedConversion = function(token) {
#       if (token) {
#         return document.cookie.indexOf('loggedConversion=' + token) !== -1;
#       }
#       return false;
#     }
#
#     var setCookieIfConversion = function(token) {
#       if (token) {
#         var twoMonthsFromNow = new Date(Date.now());
#         twoMonthsFromNow.setMonth(twoMonthsFromNow.getMonth() + 2);
#
#         document.cookie = 'loggedConversion=' + token + '; expires=' + twoMonthsFromNow;
#       }
#     }
#
#     var trekkie = window.ShopifyAnalytics.lib = window.trekkie = window.trekkie || [];
#     if (trekkie.integrations) {
#       return;
#     }
#     trekkie.methods = [
#       'identify',
#       'page',
#       'ready',
#       'track',
#       'trackForm',
#       'trackLink'
#     ];
#     trekkie.factory = function(method) {
#       return function() {
#         var args = Array.prototype.slice.call(arguments);
#         args.unshift(method);
#         trekkie.push(args);
#         return trekkie;
#       };
#     };
#     for (var i = 0; i < trekkie.methods.length; i++) {
#       var key = trekkie.methods[i];
#       trekkie[key] = trekkie.factory(key);
#     }
#     trekkie.load = function(config) {
#       trekkie.config = config || {};
#       trekkie.config.initialDocumentCookie = document.cookie;
#       var first = document.getElementsByTagName('script')[0];
#       var script = document.createElement('script');
#       script.type = 'text/javascript';
#       script.onerror = function(e) {
#         var scriptFallback = document.createElement('script');
#         scriptFallback.type = 'text/javascript';
#         scriptFallback.onerror = function(error) {
#                 var Monorail = {
#       produce: function produce(monorailDomain, schemaId, payload) {
#         var currentMs = new Date().getTime();
#         var event = {
#           schema_id: schemaId,
#           payload: payload,
#           metadata: {
#             event_created_at_ms: currentMs,
#             event_sent_at_ms: currentMs
#           }
#         };
#         return Monorail.sendRequest("https://" + monorailDomain + "/v1/produce", JSON.stringify(event));
#       },
#       sendRequest: function sendRequest(endpointUrl, payload) {
#         // Try the sendBeacon API
#         if (window && window.navigator && typeof window.navigator.sendBeacon === 'function' && typeof window.Blob === 'function' && !Monorail.isIos12()) {
#           var blobData = new window.Blob([payload], {
#             type: 'text/plain'
#           });
#
#           if (window.navigator.sendBeacon(endpointUrl, blobData)) {
#             return true;
#           } // sendBeacon was not successful
#
#         } // XHR beacon
#
#         var xhr = new XMLHttpRequest();
#
#         try {
#           xhr.open('POST', endpointUrl);
#           xhr.setRequestHeader('Content-Type', 'text/plain');
#           xhr.send(payload);
#         } catch (e) {
#           console.log(e);
#         }
#
#         return false;
#       },
#       isIos12: function isIos12() {
#         return window.navigator.userAgent.lastIndexOf('iPhone; CPU iPhone OS 12_') !== -1 || window.navigator.userAgent.lastIndexOf('iPad; CPU OS 12_') !== -1;
#       }
#     };
#     Monorail.produce('monorail-edge.shopifysvc.com',
#       'trekkie_storefront_load_errors/1.1',
#       {shop_id: 14141076,
#       theme_id: 159228363066,
#       app_name: "storefront",
#       context_url: window.location.href,
#       source_url: "//grayestudio.com/cdn/s/trekkie.storefront.3838335172bb3eee0c7f8320cb9d78b9a94cf814.min.js"});
#
#         };
#         scriptFallback.async = true;
#         scriptFallback.src = '//grayestudio.com/cdn/s/trekkie.storefront.3838335172bb3eee0c7f8320cb9d78b9a94cf814.min.js';
#         first.parentNode.insertBefore(scriptFallback, first);
#       };
#       script.async = true;
#       script.src = '//grayestudio.com/cdn/s/trekkie.storefront.3838335172bb3eee0c7f8320cb9d78b9a94cf814.min.js';
#       first.parentNode.insertBefore(script, first);
#     };
#     trekkie.load(
#       {"Trekkie":{"appName":"storefront","development":false,"defaultAttributes":{"shopId":14141076,"isMerchantRequest":null,"themeId":159228363066,"themeCityHash":"8037124266340387688","contentLanguage":"en","currency":"SGD"},"isServerSideCookieWritingEnabled":true,"monorailRegion":"shop_domain"},"Google Analytics":{"trackingId":"UA-91818857-1","domain":"auto","siteSpeedSampleRate":"10","enhancedEcommerce":true,"doubleClick":true,"includeSearch":true},"Facebook Pixel":{"pixelIds":["210979665975230"],"agent":"plshopify1.2"},"TikTok Pixel":{"pixelId":"CAJF0PRC77U28261QING"},"Google Gtag Pixel":{"conversionId":"AW-863292767","eventLabels":[{"type":"page_view","action_label":"AW-863292767\/kRyOCIzQ__MBEN-a05sD"},{"type":"purchase","action_label":"AW-863292767\/d14LCI_Q__MBEN-a05sD"},{"type":"view_item","action_label":"AW-863292767\/_9SJCIrR__MBEN-a05sD"},{"type":"add_to_cart","action_label":"AW-863292767\/-z8LCI3R__MBEN-a05sD"},{"type":"begin_checkout","action_label":"AW-863292767\/24KiCJDR__MBEN-a05sD"},{"type":"search","action_label":"AW-863292767\/7H8GCJPR__MBEN-a05sD"},{"type":"add_payment_info","action_label":"AW-863292767\/74zlCJbR__MBEN-a05sD"}],"targetCountry":"SG"},"Session Attribution":{},"S2S":{"facebookCapiEnabled":true,"facebookAppPixelId":"210979665975230","source":"trekkie-storefront-renderer"}}
#     );
#
#     var loaded = false;
#     trekkie.ready(function() {
#       if (loaded) return;
#       loaded = true;
#
#       window.ShopifyAnalytics.lib = window.trekkie;
#
#         ga('require', 'linker');
#       function addListener(element, type, callback) {
#         if (element.addEventListener) {
#           element.addEventListener(type, callback);
#         }
#         else if (element.attachEvent) {
#           element.attachEvent('on' + type, callback);
#         }
#       }
#       function decorate(event) {
#         event = event || window.event;
#         var target = event.target || event.srcElement;
#         if (target && (target.getAttribute('action') || target.getAttribute('href'))) {
#           ga(function (tracker) {
#             var linkerParam = tracker.get('linkerParam');
#             document.cookie = '_shopify_ga=' + linkerParam + '; ' + 'path=/';
#           });
#         }
#       }
#       addListener(window, 'load', function(){
#         for (var i=0; i < document.forms.length; i++) {
#           var action = document.forms[i].getAttribute('action');
#           if(action && action.indexOf('/cart') >= 0) {
#             addListener(document.forms[i], 'submit', decorate);
#           }
#         }
#         for (var i=0; i < document.links.length; i++) {
#           var href = document.links[i].getAttribute('href');
#           if(href && href.indexOf('/checkout') >= 0) {
#             addListener(document.links[i], 'click', decorate);
#           }
#         }
#       });
#
#
#       var originalDocumentWrite = document.write;
#       document.write = customDocumentWrite;
#       try { window.ShopifyAnalytics.merchantGoogleAnalytics.call(this); } catch(error) {};
#       document.write = originalDocumentWrite;
#
#       window.ShopifyAnalytics.lib.page(null,{"pageType":"collection","resourceType":"collection","resourceId":109948371032});
#
#       var match = window.location.pathname.match(/checkouts\/(.+)\/(thank_you|post_purchase)/)
#       var token = match? match[1]: undefined;
#       if (!hasLoggedConversion(token)) {
#         setCookieIfConversion(token);
#         window.ShopifyAnalytics.lib.track("Viewed Product Category",{"currency":"SGD","category":"Collection: t-shirts","collectionName":"t-shirts","collectionId":109948371032,"nonInteraction":true});
#       }
#     });
#
#
#         var eventsListenerScript = document.createElement('script');
#         eventsListenerScript.async = true;
#         eventsListenerScript.src = "//grayestudio.com/cdn/shopifycloud/shopify/assets/shop_events_listener-65cd0ba3fcd81a1df33f2510ec5bcf8c0e0958653b50e3965ec972dd638ee13f.js";
#         document.getElementsByTagName('head')[0].appendChild(eventsListenerScript);
#
# })();</script>
# <script class="boomerang">
# (function () {
#   if (window.BOOMR && (window.BOOMR.version || window.BOOMR.snippetExecuted)) {
#     return;
#   }
#   window.BOOMR = window.BOOMR || {};
#   window.BOOMR.snippetStart = new Date().getTime();
#   window.BOOMR.snippetExecuted = true;
#   window.BOOMR.snippetVersion = 12;
#   window.BOOMR.application = "storefront-renderer";
#   window.BOOMR.themeName = "Pipeline";
#   window.BOOMR.themeVersion = "7.1.2";
#   window.BOOMR.shopId = 14141076;
#   window.BOOMR.themeId = 159228363066;
#   window.BOOMR.renderRegion = "gcp-asia-southeast1";
#   window.BOOMR.url =
#     "https://grayestudio.com/cdn/shopifycloud/boomerang/shopify-boomerang-1.0.0.min.js";
#   var where = document.currentScript || document.getElementsByTagName("script")[0];
#   var parentNode = where.parentNode;
#   var promoted = false;
#   var LOADER_TIMEOUT = 3000;
#   function promote() {
#     if (promoted) {
#       return;
#     }
#     var script = document.createElement("script");
#     script.id = "boomr-scr-as";
#     script.src = window.BOOMR.url;
#     script.async = true;
#     parentNode.appendChild(script);
#     promoted = true;
#   }
#   function iframeLoader(wasFallback) {
#     promoted = true;
#     var dom, bootstrap, iframe, iframeStyle;
#     var doc = document;
#     var win = window;
#     window.BOOMR.snippetMethod = wasFallback ? "if" : "i";
#     bootstrap = function(parent, scriptId) {
#       var script = doc.createElement("script");
#       script.id = scriptId || "boomr-if-as";
#       script.src = window.BOOMR.url;
#       BOOMR_lstart = new Date().getTime();
#       parent = parent || doc.body;
#       parent.appendChild(script);
#     };
#     if (!window.addEventListener && window.attachEvent && navigator.userAgent.match(/MSIE [67]./)) {
#       window.BOOMR.snippetMethod = "s";
#       bootstrap(parentNode, "boomr-async");
#       return;
#     }
#     iframe = document.createElement("IFRAME");
#     iframe.src = "about:blank";
#     iframe.title = "";
#     iframe.role = "presentation";
#     iframe.loading = "eager";
#     iframeStyle = (iframe.frameElement || iframe).style;
#     iframeStyle.width = 0;
#     iframeStyle.height = 0;
#     iframeStyle.border = 0;
#     iframeStyle.display = "none";
#     parentNode.appendChild(iframe);
#     try {
#       win = iframe.contentWindow;
#       doc = win.document.open();
#     } catch (e) {
#       dom = document.domain;
#       iframe.src = "javascript:var d=document.open();d.domain='" + dom + "';void(0);";
#       win = iframe.contentWindow;
#       doc = win.document.open();
#     }
#     if (dom) {
#       doc._boomrl = function() {
#         this.domain = dom;
#         bootstrap();
#       };
#       doc.write("<body onload='document._boomrl();'>");
#     } else {
#       win._boomrl = function() {
#         bootstrap();
#       };
#       if (win.addEventListener) {
#         win.addEventListener("load", win._boomrl, false);
#       } else if (win.attachEvent) {
#         win.attachEvent("onload", win._boomrl);
#       }
#     }
#     doc.close();
#   }
#   var link = document.createElement("link");
#   if (link.relList &&
#     typeof link.relList.supports === "function" &&
#     link.relList.supports("preload") &&
#     ("as" in link)) {
#     window.BOOMR.snippetMethod = "p";
#     link.href = window.BOOMR.url;
#     link.rel = "preload";
#     link.as = "script";
#     link.addEventListener("load", promote);
#     link.addEventListener("error", function() {
#       iframeLoader(true);
#     });
#     setTimeout(function() {
#       if (!promoted) {
#         iframeLoader(true);
#       }
#     }, LOADER_TIMEOUT);
#     BOOMR_lstart = new Date().getTime();
#     parentNode.appendChild(link);
#   } else {
#     iframeLoader(false);
#   }
#   function boomerangSaveLoadTime(e) {
#     window.BOOMR_onload = (e && e.timeStamp) || new Date().getTime();
#   }
#   if (window.addEventListener) {
#     window.addEventListener("load", boomerangSaveLoadTime, false);
#   } else if (window.attachEvent) {
#     window.attachEvent("onload", boomerangSaveLoadTime);
#   }
#   if (document.addEventListener) {
#     document.addEventListener("onBoomerangLoaded", function(e) {
#       e.detail.BOOMR.init({
#         ResourceTiming: {
#           enabled: true,
#           trackedResourceTypes: ["script", "img", "css"]
#         },
#       });
#       e.detail.BOOMR.t_end = new Date().getTime();
#     });
#   } else if (document.attachEvent) {
#     document.attachEvent("onpropertychange", function(e) {
#       if (!e) e=event;
#       if (e.propertyName === "onBoomerangLoaded") {
#         e.detail.BOOMR.init({
#           ResourceTiming: {
#             enabled: true,
#             trackedResourceTypes: ["script", "img", "css"]
#           },
#         });
#         e.detail.BOOMR.t_end = new Date().getTime();
#       }
#     });
#   }
# })();</script>
# <a class="in-page-link visually-hidden skip-link" href="#MainContent">Skip to content</a>
# <!-- BEGIN sections: group-header -->
# <div class="shopify-section shopify-section-group-group-header" id="shopify-section-sections--20875830395194__announcement"><!-- /sections/announcement.liquid -->
# </div><div class="shopify-section shopify-section-group-group-header" id="shopify-section-sections--20875830395194__header"><!-- /sections/header.liquid --><style data-shopify="">
#   :root {
#     --COLOR-NAV-TEXT-TRANSPARENT: #f8f6f2;
#     --COLOR-HEADER-TRANSPARENT-GRADIENT: rgba(0, 0, 0, 0.2);
#     --LOGO-PADDING: 15px;
#     --menu-backfill-height: auto;
#   }
# </style>
# <div class="header__wrapper" data-header-sticky="directional" data-header-style="split" data-header-transparent="true" data-header-wrapper="" data-section-id="sections--20875830395194__header" data-section-type="header" data-underline-current="false" style="--bar-opacity: 0; --bar-width: 0; --bar-left: 0;">
# <header class="theme__header" data-header-height="">
# <div class="header__inner">
# <div class="wrapper">
# <div class="header__mobile">
# <div class="header__mobile__left">
# <button aria-controls="header-menu" aria-expanded="false" aria-haspopup="true" aria-label="Open menu" class="header__mobile__button" data-drawer-toggle="hamburger">
# <svg aria-hidden="true" class="icon icon-nav" focusable="false" role="presentation" viewbox="0 0 25 25"><path d="M0 4.062h25v2H0zm0 7h25v2H0zm0 7h25v2H0z"></path></svg>
# </button>
# </div>
# <div class="header__logo header__logo--image">
# <a class="header__logo__link" href="/" style="--LOGO-WIDTH: 30px">
# <img alt="G R A Y E" class="logo__img logo__img--color" height="30" loading="eager" src="//grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=30" srcset="
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=60 2x,
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=90 3x,
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=30
#         " width="30"/>
# </a>
# </div>
# <div class="header__mobile__right">
# <a class="header__mobile__button" data-drawer-toggle="drawer-cart" href="/cart">
# <svg aria-hidden="true" class="icon icon-cart" focusable="false" role="presentation" viewbox="0 0 25 25"><path d="M5.058 23a2 2 0 1 0 4.001-.001A2 2 0 0 0 5.058 23zm12.079 0c0 1.104.896 2 2 2s1.942-.896 1.942-2-.838-2-1.942-2-2 .896-2 2zM0 1a1 1 0 0 0 1 1h1.078l.894 3.341L5.058 13c0 .072.034.134.042.204l-1.018 4.58A.997.997 0 0 0 5.058 19h16.71a1 1 0 0 0 0-2H6.306l.458-2.061c.1.017.19.061.294.061h12.31c1.104 0 1.712-.218 2.244-1.5l3.248-6.964C25.423 4.75 24.186 4 23.079 4H5.058c-.157 0-.292.054-.438.088L3.844.772A1 1 0 0 0 2.87 0H1a1 1 0 0 0-1 1zm5.098 5H22.93l-3.192 6.798c-.038.086-.07.147-.094.19-.067.006-.113.012-.277.012H7.058v-.198l-.038-.195L5.098 6z"></path></svg>
# <span class="visually-hidden">Cart</span>
# <span class="header__cart__status">
# <span data-header-cart-price="0">
#       $0.00
#     </span>
# <span data-header-cart-count="0">
#       (0)
#     </span>
# <span data-header-cart-full="false"></span>
# </span>
# </a>
# </div>
# </div>
# <div class="header__desktop header__desktop--split" data-header-desktop=""><div class="header__desktop__bar__l" data-takes-space="">
# <div class="header__logo header__logo--image">
# <a class="header__logo__link" href="/" style="--LOGO-WIDTH: 30px">
# <img alt="G R A Y E" class="logo__img logo__img--color" height="30" loading="eager" src="//grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=30" srcset="
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=60 2x,
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=90 3x,
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=30
#         " width="30"/>
# </a>
# </div>
# </div>
# <div class="header__desktop__bar__r" data-takes-space="">
# <div class="header__desktop__bar__inline">
# <nav class="header__menu">
# <div class="header__menu__inner" data-text-items-wrapper="">
# <!-- /snippets/nav-item.liquid -->
# <div aria-controls="dropdown-ac061ab46f04475c307999887d48ca8a" aria-expanded="false" aria-haspopup="true" class="menu__item parent" data-hover-disclosure-toggle="dropdown-ac061ab46f04475c307999887d48ca8a" data-main-menu-text-item="" role="button">
# <a class="navlink navlink--toplevel" data-top-link="" href="/collections/new">
# <span class="navtext">SHOP</span>
# </a>
# <div class="header__dropdown" data-hover-disclosure="" id="dropdown-ac061ab46f04475c307999887d48ca8a">
# <div class="header__dropdown__wrapper">
# <div class="header__dropdown__inner">
# <a class="navlink navlink--child" data-stagger="" href="/collections/new">
# <span class="navtext">NEW IN</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/popular">
# <span class="navtext">POPULAR</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/young">
# <span class="navtext">BABY &amp; KIDS</span>
# </a>
# <a class="navlink navlink--child main-menu--active" data-stagger="" href="/collections/t-shirts">
# <span class="navtext">T-SHIRTS</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/tops">
# <span class="navtext">TOPS</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/outerwears">
# <span class="navtext">OUTERWEAR</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/pants">
# <span class="navtext">BOTTOMS</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/artefact">
# <span class="navtext">ARTEFACT (ACCESSORIES)</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="https://grayestudio.com/products/gift-card?variant=32324020306008">
# <span class="navtext">GIFT CARD</span>
# </a>
# <a class="navlink navlink--child highlight--link" data-stagger="" href="/collections/sale">
# <span class="navtext">SALE</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <!-- /snippets/nav-item.liquid -->
# <div aria-controls="dropdown-154a22647d0d8c8c75bccbc092e8205e" aria-expanded="false" aria-haspopup="true" class="menu__item parent" data-hover-disclosure-toggle="dropdown-154a22647d0d8c8c75bccbc092e8205e" data-main-menu-text-item="" role="button">
# <a class="navlink navlink--toplevel" data-top-link="" href="/pages/about-us">
# <span class="navtext">GRAYE</span>
# </a>
# <div class="header__dropdown" data-hover-disclosure="" id="dropdown-154a22647d0d8c8c75bccbc092e8205e">
# <div class="header__dropdown__wrapper">
# <div class="header__dropdown__inner">
# <a class="navlink navlink--child" data-stagger="" href="/pages/about-us">
# <span class="navtext">ABOUT</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/pages/envision-with-graye">
# <span class="navtext">ENVISION WITH GRAYE</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/pages/garment-care">
# <span class="navtext">GARMENT CARE</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/blogs/news">
# <span class="navtext">JOURNEY</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/workshop">
# <span class="navtext">WORKSHOPS</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/pages/explore-our-stores">
# <span class="navtext">OUR STORES</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <!-- /snippets/nav-item.liquid -->
# <div aria-controls="dropdown-91c0fb17b91c8ef1b62f43a50d46a3fc" aria-expanded="false" aria-haspopup="true" class="menu__item parent" data-hover-disclosure-toggle="dropdown-91c0fb17b91c8ef1b62f43a50d46a3fc" data-main-menu-text-item="" role="button">
# <a class="navlink navlink--toplevel" data-top-link="" href="/collections/young">
# <span class="navtext">YOUNG</span>
# </a>
# <div class="header__dropdown" data-hover-disclosure="" id="dropdown-91c0fb17b91c8ef1b62f43a50d46a3fc">
# <div class="header__dropdown__wrapper">
# <div class="header__dropdown__inner">
# <a class="navlink navlink--child" data-stagger="" href="/pages/young-by-graye">
# <span class="navtext">ABOUT YOUNG</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/pages/onesie-to-tee">
# <span class="navtext">ONESIE TO TEE</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/young">
# <span class="navtext">SHOP YOUNG</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="hover__bar"></div>
# <div class="hover__bg"></div>
# </div>
# </nav>
# <div class="header__desktop__buttons header__desktop__buttons--icons"><div class="header__desktop__button">
# <a class="navlink" href="/account">
# <svg aria-hidden="true" class="icon icon-account" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M10.713 8.771c.31.112.53.191.743.27.555.204.985.372 1.367.539 1.229.535 1.993 1.055 2.418 1.885.464.937.722 1.958.758 2.997.03.84-.662 1.538-1.524 1.538H1.525c-.862 0-1.554-.697-1.524-1.538a7.36 7.36 0 0 1 .767-3.016c.416-.811 1.18-1.33 2.41-1.866a25.25 25.25 0 0 1 1.366-.54l.972-.35a1.42 1.42 0 0 0-.006-.072c-.937-1.086-1.369-2.267-1.369-4.17C4.141 1.756 5.517 0 8.003 0c2.485 0 3.856 1.755 3.856 4.448 0 2.03-.492 3.237-1.563 4.386.169-.18.197-.253.207-.305a1.2 1.2 0 0 0-.019.16l.228.082zm-9.188 5.742h12.95a5.88 5.88 0 0 0-.608-2.402c-.428-.835-2.214-1.414-4.46-2.224-.608-.218-.509-1.765-.24-2.053.631-.677 1.166-1.471 1.166-3.386 0-1.934-.782-2.96-2.33-2.96-1.549 0-2.336 1.026-2.336 2.96 0 1.915.534 2.709 1.165 3.386.27.288.369 1.833-.238 2.053-2.245.81-4.033 1.389-4.462 2.224a5.88 5.88 0 0 0-.607 2.402z"></path></svg>
# <span class="visually-hidden">My Account</span>
# </a>
# </div>
# <div class="header__desktop__button">
# <a class="navlink" data-popdown-toggle="search-popdown" href="/search">
# <svg aria-hidden="true" class="icon icon-search" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M16 14.864 14.863 16l-4.24-4.241a6.406 6.406 0 0 1-4.048 1.392 6.61 6.61 0 0 1-4.65-1.925A6.493 6.493 0 0 1 .5 9.098 6.51 6.51 0 0 1 0 6.575a6.536 6.536 0 0 1 1.922-4.652A6.62 6.62 0 0 1 4.062.5 6.52 6.52 0 0 1 6.575 0 6.5 6.5 0 0 1 9.1.5c.8.332 1.51.806 2.129 1.423a6.454 6.454 0 0 1 1.436 2.13 6.54 6.54 0 0 1 .498 2.522c0 1.503-.468 2.853-1.4 4.048L16 14.864zM3.053 10.091c.973.972 2.147 1.461 3.522 1.461 1.378 0 2.551-.489 3.525-1.461.968-.967 1.45-2.138 1.45-3.514 0-1.37-.482-2.545-1.45-3.524-.981-.968-2.154-1.45-3.525-1.45-1.376 0-2.547.483-3.513 1.45-.973.973-1.46 2.146-1.46 3.523 0 1.375.483 2.548 1.45 3.515z"></path></svg>
# <span class="visually-hidden">Search</span>
# </a>
# </div>
# <div class="header__desktop__button">
# <a class="navlink navlink--cart" data-drawer-toggle="drawer-cart" href="/cart">
# <svg aria-hidden="true" class="icon icon-cart" focusable="false" role="presentation" viewbox="0 0 25 25"><path d="M5.058 23a2 2 0 1 0 4.001-.001A2 2 0 0 0 5.058 23zm12.079 0c0 1.104.896 2 2 2s1.942-.896 1.942-2-.838-2-1.942-2-2 .896-2 2zM0 1a1 1 0 0 0 1 1h1.078l.894 3.341L5.058 13c0 .072.034.134.042.204l-1.018 4.58A.997.997 0 0 0 5.058 19h16.71a1 1 0 0 0 0-2H6.306l.458-2.061c.1.017.19.061.294.061h12.31c1.104 0 1.712-.218 2.244-1.5l3.248-6.964C25.423 4.75 24.186 4 23.079 4H5.058c-.157 0-.292.054-.438.088L3.844.772A1 1 0 0 0 2.87 0H1a1 1 0 0 0-1 1zm5.098 5H22.93l-3.192 6.798c-.038.086-.07.147-.094.19-.067.006-.113.012-.277.012H7.058v-.198l-.038-.195L5.098 6z"></path></svg>
# <span class="visually-hidden">Cart</span>
# <span class="header__cart__status">
# <span data-header-cart-price="0">
#       $0.00
#     </span>
# <span data-header-cart-count="0">
#       (0)
#     </span>
# <span data-header-cart-full="false"></span>
# </span>
# </a>
# </div>
# </div>
# </div>
# </div></div>
# </div>
# </div>
# </header>
# <nav aria-label="Main menu" class="drawer header__drawer display-none" data-drawer="hamburger" id="header-menu">
# <div class="drawer__content">
# <div class="drawer__top">
# <div class="drawer__top__left">
# <a class="drawer__account" href="/account">
# <svg aria-hidden="true" class="icon icon-account" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M10.713 8.771c.31.112.53.191.743.27.555.204.985.372 1.367.539 1.229.535 1.993 1.055 2.418 1.885.464.937.722 1.958.758 2.997.03.84-.662 1.538-1.524 1.538H1.525c-.862 0-1.554-.697-1.524-1.538a7.36 7.36 0 0 1 .767-3.016c.416-.811 1.18-1.33 2.41-1.866a25.25 25.25 0 0 1 1.366-.54l.972-.35a1.42 1.42 0 0 0-.006-.072c-.937-1.086-1.369-2.267-1.369-4.17C4.141 1.756 5.517 0 8.003 0c2.485 0 3.856 1.755 3.856 4.448 0 2.03-.492 3.237-1.563 4.386.169-.18.197-.253.207-.305a1.2 1.2 0 0 0-.019.16l.228.082zm-9.188 5.742h12.95a5.88 5.88 0 0 0-.608-2.402c-.428-.835-2.214-1.414-4.46-2.224-.608-.218-.509-1.765-.24-2.053.631-.677 1.166-1.471 1.166-3.386 0-1.934-.782-2.96-2.33-2.96-1.549 0-2.336 1.026-2.336 2.96 0 1.915.534 2.709 1.165 3.386.27.288.369 1.833-.238 2.053-2.245.81-4.033 1.389-4.462 2.224a5.88 5.88 0 0 0-.607 2.402z"></path></svg>
# <span class="visually-hidden">My Account</span>
# </a></div>
# <button aria-label="Close" class="drawer__button drawer__close" data-drawer-toggle="hamburger">
# <svg aria-hidden="true" class="icon icon-close" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.06 1 12.02 12.021-1.06 1.061L1 2.062z"></path><path d="M1 13.02 13.022 1l1.061 1.06-12.02 12.02z"></path></g></svg>
# </button>
# </div>
# <div class="drawer__inner" data-drawer-scrolls="">
# <div class="drawer__search" data-drawer-search="">
# <!-- /snippets/search-predictive.liquid -->
# <div data-search-popdown-wrap="">
# <div class="search-drawer search__predictive" data-popdown-outer="" id="search-drawer"><predictive-search><form action="/search" method="get" role="search">
# <div class="item--loadbar" data-loading-indicator="" style="display: none;"></div>
# <div class="search__predictive__outer">
# <div class="wrapper">
# <div class="search__predictive__main">
# <div class="search__predictive__actions">
# <button class="search__predictive__button" type="submit">
# <span class="visually-hidden">Search</span>
# <svg aria-hidden="true" class="icon icon-search" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M16 14.864 14.863 16l-4.24-4.241a6.406 6.406 0 0 1-4.048 1.392 6.61 6.61 0 0 1-4.65-1.925A6.493 6.493 0 0 1 .5 9.098 6.51 6.51 0 0 1 0 6.575a6.536 6.536 0 0 1 1.922-4.652A6.62 6.62 0 0 1 4.062.5 6.52 6.52 0 0 1 6.575 0 6.5 6.5 0 0 1 9.1.5c.8.332 1.51.806 2.129 1.423a6.454 6.454 0 0 1 1.436 2.13 6.54 6.54 0 0 1 .498 2.522c0 1.503-.468 2.853-1.4 4.048L16 14.864zM3.053 10.091c.973.972 2.147 1.461 3.522 1.461 1.378 0 2.551-.489 3.525-1.461.968-.967 1.45-2.138 1.45-3.514 0-1.37-.482-2.545-1.45-3.524-.981-.968-2.154-1.45-3.525-1.45-1.376 0-2.547.483-3.513 1.45-.973.973-1.46 2.146-1.46 3.523 0 1.375.483 2.548 1.45 3.515z"></path></svg>
# </button>
# <input aria-controls="predictive-search-results" aria-label="Search our store" data-predictive-search-input="search-popdown-results" name="q" placeholder="Search..." type="search" value=""/>
# <div class="search__predictive__clear">
# <button aria-label="Reset" class="search__predictive__close__inner search-reset is-hidden" type="reset">
# <svg aria-hidden="true" class="icon icon-close" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.06 1 12.02 12.021-1.06 1.061L1 2.062z"></path><path d="M1 13.02 13.022 1l1.061 1.06-12.02 12.02z"></path></g></svg>
# Clear</button>
# </div>
# </div>
# <div class="search__predictive__close">
# <button aria-label="Close" class="search__predictive__close__inner" data-close-popdown="" type="button">
# <svg aria-hidden="true" class="icon icon-close-small" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.237 1.073 12.021 12.021-1.414 1.414L.824 2.488z"></path><path d="m.823 13.094 12.021-12.02 1.414 1.413-12.02 12.021z"></path></g></svg>
# </button>
# </div>
# </div>
# </div>
# </div><div class="header__search__results" data-predictive-search-results="" tabindex="-1"></div>
# <span aria-hidden="true" class="predictive-search-status visually-hidden" data-predictive-search-status="" role="status"></span></form></predictive-search></div>
# <script data-predictive-search-aria-template="" type="text/x-template">
#     <div aria-live="polite">
#       <p>
#
#           {{@if(it.count)}}
#             <span class="badge">{{ it.count }}</span>
#           {{/if}}
#           {{ it.title }} <em>{{ it.query }}</em>
#
#       </p>
#     </div>
#   </script>
# <script data-predictive-search-title-template="" type="text/x-template">
#     <div class="search__results__heading">
#
#         <p>
#           <span class="search__results__title">{{ it.title }}</span>
#           <span class="badge">{{ it.count }}</span>
#         </p>
#
#     </div>
#   </script>
# <script data-search-other-template="" type="text/x-template">
#
#       {{@each(it) => object, index}}
#         <div class="other__inline animates" style="animation-delay: {{ index | animationDelay }}ms;">
#           <p class="other__inline__title">
#             <a href="{{ object.url }}">{{ object.title | safe }}</a>
#           </p>
#         </div>
#       {{/each}}
#
#   </script>
# <script data-search-product-template="" type="text/x-template">
#
#       {{@each(it) => object, index}}
#         <a href="{{ object.url }}" class="product__inline animates" style="animation-delay: {{ index | animationDelay }}ms;">
#           <div class="product__inline__image {{ @if (object.featured_image.width === null) }} product__inline__image--no-image {{ /if}}">
#             {{ @if (object.featured_image.width !== null) }}
#               <img class="img-aspect-ratio" width="{{object.featured_image.width}}" height="{{ object.featured_image.height }}" alt="{{ object.featured_image.alt }}" src="{{ object.thumb }}">
#             {{ /if}}
#           </div>
#           <div>
#             <p class="product__inline__title">
#               {{ object.title | safe }}
#             </p>
#             <p class="product__inline__price">
#               <span class="price {{ object.classes }}">
#                 {{ object.price | safe }}
#               </span>
#               {{@if(object.sold_out)}}
#                 <br /><em>{{ object.sold_out_translation }}</em>
#               {{/if}}
#               {{@if(object.on_sale)}}
#                 <span class="compare-at">
#                   {{ object.compare_at_price | safe }}
#                 </span>
#               {{/if}}
#             </p>
#           </div>
#         </a>
#       {{/each}}
#
#   </script>
# </div>
# </div>
# <div class="drawer__menu" data-sliderule-pane="0" data-stagger-animation="">
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper"><button class="sliderow" data-animates="0" data-sliderule-open="sliderule-df8e1ed0a18e833743bf2a0fd4e0361e">
# <span class="sliderow__title">SHOP</span>
# <span class="sliderule__chevron--right">
# <svg aria-hidden="true" class="icon icon-arrow-medium-right" focusable="false" role="presentation" viewbox="0 0 9 15"><path d="M6.875 7.066.87 1.06 1.93 0l6.006 6.005L7.94 6 9 7.06l-.004.006.005.005-1.06 1.06-.006-.004-6.005 6.005-1.061-1.06 6.005-6.006z" fill-rule="evenodd"></path></svg>
# <span class="visually-hidden">Expand menu</span>
# </span>
# </button>
# <div class="mobile__menu__dropdown sliderule__panel" data-sliderule="" id="sliderule-df8e1ed0a18e833743bf2a0fd4e0361e"><div class="sliderow sliderow__back" data-animates="1">
# <button class="drawer__button" data-sliderule-close="sliderule-df8e1ed0a18e833743bf2a0fd4e0361e">
# <span class="sliderule__chevron--left">
# <svg aria-hidden="true" class="icon icon-arrow-medium-left" focusable="false" role="presentation" viewbox="0 0 9 15"><path d="M2.127 7.066 8.132 1.06 7.072 0 1.065 6.005 1.061 6 0 7.06l.004.006L0 7.07l1.06 1.06.006-.004 6.005 6.005 1.061-1.06-6.005-6.006z" fill-rule="evenodd"></path></svg>
# <span class="visually-hidden">Hide menu</span>
# </span>
# </button>
# <a class="sliderow__title" href="/collections/new">SHOP</a>
# </div><div class="sliderow__links" data-links="">
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/new">NEW IN</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/popular">POPULAR</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/young">BABY &amp; KIDS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/t-shirts">T-SHIRTS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/tops">TOPS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/outerwears">OUTERWEAR</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/pants">BOTTOMS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/artefact">ARTEFACT (ACCESSORIES)</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="https://grayestudio.com/products/gift-card?variant=32324020306008">GIFT CARD</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title highlight--link" href="/collections/sale">SALE</a>
# </div></div>
# </div><div class="sliderule-grid blocks-0">
# </div></div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper"><button class="sliderow" data-animates="0" data-sliderule-open="sliderule-f99a83a8c336d3e3fae3c2ced23b8d7b">
# <span class="sliderow__title">GRAYE</span>
# <span class="sliderule__chevron--right">
# <svg aria-hidden="true" class="icon icon-arrow-medium-right" focusable="false" role="presentation" viewbox="0 0 9 15"><path d="M6.875 7.066.87 1.06 1.93 0l6.006 6.005L7.94 6 9 7.06l-.004.006.005.005-1.06 1.06-.006-.004-6.005 6.005-1.061-1.06 6.005-6.006z" fill-rule="evenodd"></path></svg>
# <span class="visually-hidden">Expand menu</span>
# </span>
# </button>
# <div class="mobile__menu__dropdown sliderule__panel" data-sliderule="" id="sliderule-f99a83a8c336d3e3fae3c2ced23b8d7b"><div class="sliderow sliderow__back" data-animates="1">
# <button class="drawer__button" data-sliderule-close="sliderule-f99a83a8c336d3e3fae3c2ced23b8d7b">
# <span class="sliderule__chevron--left">
# <svg aria-hidden="true" class="icon icon-arrow-medium-left" focusable="false" role="presentation" viewbox="0 0 9 15"><path d="M2.127 7.066 8.132 1.06 7.072 0 1.065 6.005 1.061 6 0 7.06l.004.006L0 7.07l1.06 1.06.006-.004 6.005 6.005 1.061-1.06-6.005-6.006z" fill-rule="evenodd"></path></svg>
# <span class="visually-hidden">Hide menu</span>
# </span>
# </button>
# <a class="sliderow__title" href="/pages/about-us">GRAYE</a>
# </div><div class="sliderow__links" data-links="">
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/pages/about-us">ABOUT</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/pages/envision-with-graye">ENVISION WITH GRAYE</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/pages/garment-care">GARMENT CARE</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/blogs/news">JOURNEY</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/workshop">WORKSHOPS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/pages/explore-our-stores">OUR STORES</a>
# </div></div>
# </div><div class="sliderule-grid blocks-0">
# </div></div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper"><button class="sliderow" data-animates="0" data-sliderule-open="sliderule-975453dbb60e68f2cd134af896b8d431">
# ...
# <h2 class="visually-hidden" id="currency-heading-localization-form-footer">
#     Currency
#   </h2>
# <popout-select>
# <div class="popout" data-popout="">
# <button aria-controls="currency-list-localization-form-footer" aria-describedby="currency-heading-localization-form-footer" aria-expanded="false" class="popout__toggle" data-popout-toggle="" type="button">
#           SGD $<svg aria-hidden="true" class="icon icon--wide icon-arrow-down" focusable="false" role="presentation" viewbox="0 0 30 17"><path d="M0 3.235 3.525 0l11.473 10.509L26.473 0 30 3.235 14.998 17z" fill-rule="evenodd"></path></svg></button>
# <ul class="popout-list" data-popout-list="" id="currency-list-localization-form-footer">
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="AUD" href="#">
# <span>AUD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="BND" href="#">
# <span>BND $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="CAD" href="#">
# <span>CAD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="CHF" href="#">
# <span>CHF CHF</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="CNY" href="#">
# <span>CNY ¥</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="DKK" href="#">
# <span>DKK kr.</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="EUR" href="#">
# <span>EUR €</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="GBP" href="#">
# <span>GBP £</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="HKD" href="#">
# <span>HKD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="IDR" href="#">
# <span>IDR Rp</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="INR" href="#">
# <span>INR ₹</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="ISK" href="#">
# <span>ISK kr</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="JPY" href="#">
# <span>JPY ¥</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="KRW" href="#">
# <span>KRW ₩</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="MOP" href="#">
# <span>MOP P</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="MYR" href="#">
# <span>MYR RM</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="NZD" href="#">
# <span>NZD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="PHP" href="#">
# <span>PHP ₱</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="PLN" href="#">
# <span>PLN zł</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="SEK" href="#">
# <span>SEK kr</span>
# </a>
# </li>
# <li class="popout-list__item popout-list__item--current">
# <a aria-current="true" class="popout-list__option" data-popout-option="" data-value="SGD" href="#">
# <span>SGD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="THB" href="#">
# <span>THB ฿</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="TWD" href="#">
# <span>TWD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="USD" href="#">
# <span>USD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="VND" href="#">
# <span>VND ₫</span>
# </a>
# </li></ul>
# <input data-popout-input="" id="CurrencySelector-localization-form-footer" name="currency_code" type="hidden" value="SGD"/>
# </div>
# </popout-select>
# </div>
# </form><noscript><form accept-charset="UTF-8" action="/localization" class="locale-footer-nojs" enctype="multipart/form-data" id="localization-form-footer-noscript" method="post"><input name="form_type" type="hidden" value="localization"/><input name="utf8" type="hidden" value="✓"/><input name="_method" type="hidden" value="put"/><input name="return_to" type="hidden" value="/collections/t-shirts"/><h2 class="visually-hidden" id="localization-form-footer-noscript-locale-heading">
#                   Currency
#                 </h2>
# <select aria-labelledby="localization-form-footer-noscript-currency-heading" name="country_code"><option value="AU">
#                       Australia (AUD
#                       $)
#                     </option><option value="BE">
#                       Belgium (EUR
#                       €)
#                     </option><option value="BN">
#                       Brunei (BND
#                       $)
#                     </option><option value="CA">
#                       Canada (CAD
#                       $)
#                     </option><option value="CN">
#                       China (CNY
#                       ¥)
#                     </option><option value="DK">
#                       Denmark (DKK
#                       kr.)
#                     </option><option value="FI">
#                       Finland (EUR
#                       €)
#                     </option><option value="FR">
#                       France (EUR
#                       €)
#                     </option><option value="DE">
#                       Germany (EUR
#                       €)
#                     </option><option value="HK">
#                       Hong Kong SAR (HKD
#                       $)
#                     </option><option value="IS">
#                       Iceland (ISK
#                       kr)
#                     </option><option value="IN">
#                       India (INR
#                       ₹)
#                     </option><option value="ID">
#                       Indonesia (IDR
#                       Rp)
#                     </option><option value="IE">
#                       Ireland (EUR
#                       €)
#                     </option><option value="IT">
#                       Italy (EUR
#                       €)
#                     </option><option value="JP">
#                       Japan (JPY
#                       ¥)
#                     </option><option value="MO">
#                       Macao SAR (MOP
#                       P)
#                     </option><option value="MY">
#                       Malaysia (MYR
#                       RM)
#                     </option><option value="MC">
#                       Monaco (EUR
#                       €)
#                     </option><option value="NL">
#                       Netherlands (EUR
#                       €)
#                     </option><option value="NZ">
#                       New Zealand (NZD
#                       $)
#                     </option><option value="NO">
#                       Norway (SGD
#                       $)
#                     </option><option value="PH">
#                       Philippines (PHP
#                       ₱)
#                     </option><option value="PL">
#                       Poland (PLN
#                       zł)
#                     </option><option value="PT">
#                       Portugal (EUR
#                       €)
#                     </option><option selected="" value="SG">
#                       Singapore (SGD
#                       $)
#                     </option><option value="KR">
#                       South Korea (KRW
#                       ₩)
#                     </option><option value="ES">
#                       Spain (EUR
#                       €)
#                     </option><option value="SE">
#                       Sweden (SEK
#                       kr)
#                     </option><option value="CH">
#                       Switzerland (CHF
#                       CHF)
#                     </option><option value="TW">
#                       Taiwan (TWD
#                       $)
#                     </option><option value="TH">
#                       Thailand (THB
#                       ฿)
#                     </option><option value="TR">
#                       Turkey (SGD
#                       $)
#                     </option><option value="GB">
#                       United Kingdom (GBP
#                       £)
#                     </option><option value="US">
#                       United States (USD
#                       $)
#                     </option><option value="VN">
#                       Vietnam (VND
#                       ₫)
#                     </option></select><button class="btn btn--primary btn--full">Update</button></form></noscript>
# </div>
# <div class="subfooter__item subfooter__item--copyright">
# <span class="subfooter__copyright"> © <a href="/" title="">G R A Y E</a> 2023 </span>
# <span class="subfooter__copyright"><a href="/pages/about-us">About</a></span>
# <span class="subfooter__copyright"><a href="/pages/contact-us">Contact</a></span>
# <span class="subfooter__copyright"><a href="/pages/delivery-information">Shipping</a></span>
# <span class="subfooter__copyright"><a href="/pages/return-and-exchange">Returns</a></span>
# <span class="subfooter__copyright"><a href="/pages/terms-conditions">Terms</a></span>
# <!-- The following lines fix Lighthouse security warnings on the Shopify link.--><!-- Remove the following line to delete Powered by Shopify from your footer -->
# <span class="subfooter__copyright" data-powered-link=""><a href="https://www.shopify.com?utm_campaign=poweredby&amp;utm_medium=shopify&amp;utm_source=onlinestore" rel="noopener" target="_blank">Powered by Shopify</a></span>
# <!-- Stop deleting here -->
# </div></div>
# </div>
# </section>
# </div>
# <!-- END sections: group-footer -->
# <div class="search--popdown">
# <!-- /snippets/search-predictive.liquid -->
# <div data-search-popdown-wrap="">
# <div class="search-popdown search__predictive" data-popdown-outer="" id="search-popdown"><predictive-search><form action="/search" method="get" role="search">
# <div class="item--loadbar" data-loading-indicator="" style="display: none;"></div>
# <div class="search__predictive__outer">
# <div class="wrapper">
# <div class="search__predictive__main">
# <div class="search__predictive__actions">
# <button class="search__predictive__button" type="submit">
# <span class="visually-hidden">Search</span>
# <svg aria-hidden="true" class="icon icon-search" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M16 14.864 14.863 16l-4.24-4.241a6.406 6.406 0 0 1-4.048 1.392 6.61 6.61 0 0 1-4.65-1.925A6.493 6.493 0 0 1 .5 9.098 6.51 6.51 0 0 1 0 6.575a6.536 6.536 0 0 1 1.922-4.652A6.62 6.62 0 0 1 4.062.5 6.52 6.52 0 0 1 6.575 0 6.5 6.5 0 0 1 9.1.5c.8.332 1.51.806 2.129 1.423a6.454 6.454 0 0 1 1.436 2.13 6.54 6.54 0 0 1 .498 2.522c0 1.503-.468 2.853-1.4 4.048L16 14.864zM3.053 10.091c.973.972 2.147 1.461 3.522 1.461 1.378 0 2.551-.489 3.525-1.461.968-.967 1.45-2.138 1.45-3.514 0-1.37-.482-2.545-1.45-3.524-.981-.968-2.154-1.45-3.525-1.45-1.376 0-2.547.483-3.513 1.45-.973.973-1.46 2.146-1.46 3.523 0 1.375.483 2.548 1.45 3.515z"></path></svg>
# </button>
# <input aria-controls="predictive-search-results" aria-label="Search our store" data-predictive-search-input="search-popdown-results" name="q" placeholder="Search..." type="search" value=""/>
# <div class="search__predictive__clear">
# <button aria-label="Reset" class="search__predictive__close__inner search-reset is-hidden" type="reset">
# <svg aria-hidden="true" class="icon icon-close" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.06 1 12.02 12.021-1.06 1.061L1 2.062z"></path><path d="M1 13.02 13.022 1l1.061 1.06-12.02 12.02z"></path></g></svg>
# Clear</button>
# </div>
# </div>
# <div class="search__predictive__close">
# <button aria-label="Close" class="search__predictive__close__inner" data-close-popdown="" type="button">
# <svg aria-hidden="true" class="icon icon-close-small" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.237 1.073 12.021 12.021-1.414 1.414L.824 2.488z"></path><path d="m.823 13.094 12.021-12.02 1.414 1.413-12.02 12.021z"></path></g></svg>
# </button>
# </div>
# </div>
# </div>
# </div><div class="header__search__results" data-predictive-search-results="" tabindex="-1"></div>
# <span aria-hidden="true" class="predictive-search-status visually-hidden" data-predictive-search-status="" role="status"></span></form></predictive-search></div>
# <span class="drawer__underlay" data-search-underlay=""></span>
# <script data-predictive-search-aria-template="" type="text/x-template">
#     <div aria-live="polite">
#       <p>
#
#           {{@if(it.count)}}
#             <span class="badge">{{ it.count }}</span>
#           {{/if}}
#           {{ it.title }} <em>{{ it.query }}</em>
#
#       </p>
#     </div>
#   </script>
# <script data-predictive-search-title-template="" type="text/x-template">
#     <div class="search__results__heading">
#
#         <p>
#           <span class="search__results__title">{{ it.title }}</span>
#           <span class="badge">{{ it.count }}</span>
#         </p>
#
#     </div>
#   </script>
# <script data-search-other-template="" type="text/x-template">
#
#       {{@each(it) => object, index}}
#         <div class="other__inline animates" style="animation-delay: {{ index | animationDelay }}ms;">
#           <p class="other__inline__title">
#             <a href="{{ object.url }}">{{ object.title | safe }}</a>
#           </p>
#         </div>
#       {{/each}}
#
#   </script>
# <script data-search-product-template="" type="text/x-template">
#
#       {{@each(it) => object, index}}
#         <a href="{{ object.url }}" class="product__inline animates" style="animation-delay: {{ index | animationDelay }}ms;">
#           <div class="product__inline__image {{ @if (object.featured_image.width === null) }} product__inline__image--no-image {{ /if}}">
#             {{ @if (object.featured_image.width !== null) }}
#               <img class="img-aspect-ratio" width="{{object.featured_image.width}}" height="{{ object.featured_image.height }}" alt="{{ object.featured_image.alt }}" src="{{ object.thumb }}">
#             {{ /if}}
#           </div>
#           <div>
#             <p class="product__inline__title">
#               {{ object.title | safe }}
#             </p>
#             <p class="product__inline__price">
#               <span class="price {{ object.classes }}">
#                 {{ object.price | safe }}
#               </span>
#               {{@if(object.sold_out)}}
#                 <br /><em>{{ object.sold_out_translation }}</em>
#               {{/if}}
#               {{@if(object.on_sale)}}
#                 <span class="compare-at">
#                   {{ object.compare_at_price | safe }}
#                 </span>
#               {{/if}}
#             </p>
#           </div>
#         </a>
#       {{/each}}
#
#   </script>
# </div>
# </div>
# <div data-modal-container=""></div><!-- Paste popup code or third party scripts below this comment line ============== -->
# <!-- And above this comment line ================================================== -->
# <div class="shopify-block shopify-app-block" id="shopify-block-1513253815146976218">
# </div><div class="shopify-block shopify-app-block" id="shopify-block-9278379683843197553"></div>
# </body>

# %%
tee_text = tee_soup.find_all('div', {'class':'product__grid__info'})

# %%
# get partial product url

tee_links = []

for a in tee_text:
    anchor_tag = a.find('a')
    if anchor_tag:
        link = anchor_tag.get('href')
        tee_links.append(link)

# %%
# get full url

from urllib.parse import urljoin

tee_links_list = []

for i in range(len(tee_links)):
    rel_url = tee_links[i]
    full_url = urljoin('https://grayestudio.com', rel_url)
    tee_links_list.append(full_url)

# %%
# get product name

product = []

for url in tee_links_list:
    t_url = url
    t_res = requests.get(t_url)
    t_soup = BeautifulSoup(t_res.content, 'lxml')

    product_text = t_soup.find('h1', {'class':'product__title heading-size-8'}).text.strip() 
    product.append(product_text)

# %%
# get material composition

material = []

for url in tee_links_list:
    t_url = url
    t_res = requests.get(t_url)
    t_soup = BeautifulSoup(t_res.content, 'lxml')

    for a in t_soup.find_all('div', {'class':'tab-content tab-content-1'}):
        anchor_tag = a.find('span', {'class':'metafield-multi_line_text_field'} )
        if anchor_tag:
            text = anchor_tag.text.strip()
            material.append(text)

# %%
# get care instructions

wash_care = []

for url in tee_links_list:
    t_url = url
    t_res = requests.get(t_url)
    t_soup = BeautifulSoup(t_res.content, 'lxml')

    for a in t_soup.find_all('div', {'class':'tab-content tab-content-4'}):
        anchor_tag = a.find('span', {'class':'metafield-multi_line_text_field'} )
        if anchor_tag:
            text = anchor_tag.text.strip()
            wash_care.append(text)

# %% [markdown]
# ### Get urls for top products

# %%
# check requests

top_url = 'https://grayestudio.com/collections/tops'
top_res = requests.get(top_url)
top_res.status_code
# Out:
# 200

# %%
# check scraped text

top_soup = BeautifulSoup(top_res.content, 'lxml')
top_soup.body
# Out:
# <body><div class="edit_popup" style="display: none;">
# <form class="edit_form" data-action="/cart/add" enctype="multipart/form-data" id="edit_cart_popup" method="post">
# </form>
# </div><!-- END app snippet --><!-- END app app block --><script defer="defer" src="https://cdn.shopify.com/extensions/4ab84696-81cc-4661-9fb4-2578a25bce95/0.94.0/assets/appointo_bundle.js" type="text/javascript"></script>
# <script defer="defer" src="https://cdn.shopify.com/extensions/0dc675f6-6451-4e34-ac60-441d0df6340d/5.38.0/assets/hulkcode.js" type="text/javascript"></script>
# <link href="https://cdn.shopify.com/extensions/0dc675f6-6451-4e34-ac60-441d0df6340d/5.38.0/assets/hulkcode.css" media="all" rel="stylesheet" type="text/css"/>
# <script defer="defer" src="https://cdn.shopify.com/extensions/07fd1ccd-f05b-4d31-94d4-a07a2e88cdad/0.4.0/assets/omnisend-in-shop.js" type="text/javascript"></script>
# <link href="https://monorail-edge.shopifysvc.com" rel="dns-prefetch"/>
# <script>(function(){if ("sendBeacon" in navigator && "performance" in window) {var session_token = document.cookie.match(/_shopify_s=([^;]*)/);function handle_abandonment_event(e) {var entries = performance.getEntries().filter(function(entry) {return /monorail-edge.shopifysvc.com/.test(entry.name);});if (!window.abandonment_tracked && entries.length === 0) {window.abandonment_tracked = true;var currentMs = Date.now();var navigation_start = performance.timing.navigationStart;var payload = {shop_id: 14141076,url: window.location.href,navigation_start,duration: currentMs - navigation_start,session_token: session_token && session_token.length === 2 ? session_token[1] : "",page_type: "collection"};window.navigator.sendBeacon("https://monorail-edge.shopifysvc.com/v1/produce", JSON.stringify({schema_id: "online_store_buyer_site_abandonment/1.1",payload: payload,metadata: {event_created_at_ms: currentMs,event_sent_at_ms: currentMs}}));}}window.addEventListener('pagehide', handle_abandonment_event);}}());</script>
# <script id="web-pixels-manager-setup">(function e(e,n,a,o,t,r,i){function s(e,n){if(document.head){var a=document.createElement("link");e.match(/spin\.dev\/?/)&&(e+="?fast_storefront_renderer=1"),a.rel="preload",a.href=e,n&&(a.as=n);try{document.head.appendChild(a)}catch(e){console&&console.warn&&console.warn("[Web Pixels Manager] Could not append prefetch link tag to DOM.")}}}var l=i||[],d=null!==e;d&&(window.Shopify=window.Shopify||{},window.Shopify.analytics=window.Shopify.analytics||{},window.Shopify.analytics.replayQueue=[],window.Shopify.analytics.publish=function(e,n,a){window.Shopify.analytics.replayQueue.push([e,n,a])});var c=function(){var e="legacy",n="unknown",a=null,o=navigator.userAgent.match(/(Firefox|Chrome)\/(\d+)/i),t=navigator.userAgent.match(/(Edg)\/(\d+)/i),r=navigator.userAgent.match(/(Version)\/(\d+)(.+)(Safari)\/(\d+)/i);r?(n="safari",a=parseInt(r[2],10)):t?(n="edge",a=parseInt(t[2],10)):o&&(n=o[1].toLocaleLowerCase(),a=parseInt(o[2],10));var i={chrome:60,firefox:55,safari:11,edge:80}[n];return void 0!==i&&null!==a&&i<=a&&(e="modern"),e}(),p=c.substring(0,1),f=o.substring(0,1);if(d)try{self.performance.mark("wpm:start")}catch(e){}if(d){var u=self.location.origin,w=(e.webPixelsConfigList||[]).filter((function(e){return"app"===e.type.toLowerCase()}));for(let e=0;e<w.length;e++){s([u,"/wpm@",r,"/web-pixel-",w[e].id,"@",w[e].scriptVersion,"/sandbox/worker.",c,".js"].join(""),"script")}}var h,y,m,g,v,b,_,S,x=[a,"/wpm","/",f,r,p,".js"].join("");h={src:x,async:!0,onload:function(){if(e){var a=window.webPixelsManager.init(e);n(a),window.Shopify.analytics.replayQueue.forEach((function(e){a.publishCustomEvent(e[0],e[1],e[2])})),window.Shopify.analytics.replayQueue=[],window.Shopify.analytics.publish=a.publishCustomEvent,l.indexOf("web_pixels_visitor_api")>-1&&(window.Shopify.analytics.visitor=a.visitor)}},onerror:function(){var n=(e.storefrontBaseUrl?e.storefrontBaseUrl.replace(/\/$/,""):self.location.origin)+"/.well-known/shopify/monorail/unstable/produce_batch",a=JSON.stringify({metadata:{event_sent_at_ms:(new Date).getTime()},events:[{schema_id:"web_pixels_manager_load/2.0",payload:{version:t||"latest",page_url:self.location.href,status:"failed",error_msg:x+" has failed to load"},metadata:{event_created_at_ms:(new Date).getTime()}}]});try{if(self.navigator.sendBeacon.bind(self.navigator)(n,a))return!0}catch(e){}const o=new XMLHttpRequest;try{return o.open("POST",n,!0),o.setRequestHeader("Content-Type","text/plain"),o.send(a),!0}catch(e){console&&console.warn&&console.warn("[Web Pixels Manager] Got an unhandled error while logging a load error.")}return!1}},y=document.createElement("script"),m=h.src,g=h.async||!0,v=h.onload,b=h.onerror,_=document.head,S=document.body,y.async=g,y.src=m,v&&y.addEventListener("load",v),b&&y.addEventListener("error",b),_?_.appendChild(y):S?S.appendChild(y):console.error("Did not find a head or body element to append the script")})({shopId: 14141076,storefrontBaseUrl: "https://grayestudio.com",cdnBaseUrl: "https://grayestudio.com/cdn",surface: "storefront-renderer",enabledBetaFlags: ["web_pixels_async_pixel_refactor"],webPixelsConfigList: [{"id":"51183930","configuration":"{\"pixelCode\":\"CAJF0PRC77U28261QING\"}","eventPayloadVersion":"v1","runtimeContext":"STRICT","scriptVersion":"0.1.0-99c70b3e91db3b02f187f0b0b5db3b0a","type":"APP","apiClientId":4383523},{"id":"shopify-app-pixel","configuration":"{}","eventPayloadVersion":"v1","runtimeContext":"STRICT","scriptVersion":"0559","apiClientId":"shopify-pixel","type":"APP"},{"id":"shopify-custom-pixel","eventPayloadVersion":"v1","runtimeContext":"LAX","scriptVersion":"0559","apiClientId":"shopify-pixel","type":"CUSTOM"}],initData: {"cart":null,"checkout":null,"customer":null,"productVariants":[]},},function pageEvents(webPixelsManagerAPI) {webPixelsManagerAPI.publish("page_viewed");webPixelsManagerAPI.publish("collection_viewed", {"collection":{"id":"109947879512","title":"Tops","productVariants":[{"id":"45327822881082","image":{"src": ...
# window.ShopifyAnalytics.meta = window.ShopifyAnalytics.meta || {};
# window.ShopifyAnalytics.meta.currency = 'SGD';
# var meta = {"products":[{"id":8335442084154,"gid":"gid:\/\/shopify\/Product\/8335442084154","vendor":"G R A Y E","type":"Top","variants":[{"id":45327822881082,"price":15900,"name":"Oversized Linen Grid Shirt - Navy Blue - SMALL","public_title":"SMALL","sku":"23T03BL-S"},{"id":45327822913850,"price":15900,"name":"Oversized Linen Grid Shirt - Navy Blue - MEDIUM","public_title":"MEDIUM","sku":"23T03BL-M"},{"id":45327822946618,"price":15900,"name":"Oversized Linen Grid Shirt - Navy Blue - LARGE","public_title":"LARGE","sku":"23T03BL-L"}]},{"id":8335442379066,"gid":"gid:\/\/shopify\/Product\/8335442379066","vendor":"G R A Y E","type":"Top","variants":[{"id":45327824060730,"price":15900,"name":"Oversized Linen Grid Shirt - Off White - SMALL","public_title":"SMALL","sku":"23T03W-S"},{"id":45327824126266,"price":15900,"name":"Oversized Linen Grid Shirt - Off White - MEDIUM","public_title":"MEDIUM","sku":"23T03W-M"},{"id":45327824191802,"price":15900,"name":"Oversized Linen Grid Shirt - Off White - LARGE","public_title":"LARGE","sku":"23T03W-L"}]},{"id":8335445295418,"gid":"gid:\/\/shopify\/Product\/8335445295418","vendor":"G R A Y E","type":"Outerwear","variants":[{"id":45327849128250,"price":13900,"name":"High Collar Shān - White - SMALL","public_title":"SMALL","sku":"23T02W-S"},{"id":45327849161018,"price":13900,"name":"High Collar Shān - White - MEDIUM","public_title":"MEDIUM","sku":"23T02W-M"},{"id":45327849193786,"price":13900,"name":"High Collar Shān - White - LARGE","public_title":"LARGE","sku":"23T02W-L"},{"id":45327849226554,"price":13900,"name":"High Collar Shān - White - EXTRA LARGE","public_title":"EXTRA LARGE","sku":"23T02W-XL"}]},{"id":8335445655866,"gid":"gid:\/\/shopify\/Product\/8335445655866","vendor":"G R A Y E","type":"Outerwear","variants":[{"id":45327852175674,"price":13900,"name":"High Collar Shān - Duo-toned Sand - SMALL","public_title":"SMALL","sku":"23T02BE-S"},{"id":45327852208442,"price":13900,"name":"High Collar Shān - Duo-toned Sand - MEDIUM","public_title":"MEDIUM","sku":"23T02BE-M"},{"id":45327852241210,"price":13900,"name":"High Collar Shān - Duo-toned Sand - LARGE","public_title":"LARGE","sku":"23T02BE-L"},{"id":45327852273978,"price":13900,"name":"High Collar Shān - Duo-toned Sand - EXTRA LARGE","public_title":"EXTRA LARGE","sku":"23T02BE-XL"}]},{"id":8248934072634,"gid":"gid:\/\/shopify\/Product\/8248934072634","vendor":"G R A Y E","type":"Top","variants":[{"id":44947118686522,"price":8500,"name":"Craftsman's Basic Top 2.0 - Artichoke - SMALL","public_title":"SMALL","sku":"23T01G-S"},{"id":44947118719290,"price":8500,"name":"Craftsman's Basic Top 2.0 - Artichoke - MEDIUM","public_title":"MEDIUM","sku":"23T01G-M"},{"id":44947118752058,"price":8500,"name":"Craftsman's Basic Top 2.0 - Artichoke - LARGE","public_title":"LARGE","sku":"23T01G-L"},{"id":44947118784826,"price":8500,"name":"Craftsman's Basic Top 2.0 - Artichoke - EXTRA LARGE","public_title":"EXTRA LARGE","sku":"23T01G-XL"}]},{"id":8248932073786,"gid":"gid:\/\/shopify\/Product\/8248932073786","vendor":"G R A Y E","type":"Top","variants":[{"id":44947113050426,"price":8500,"name":"Craftsman's Basic Top 2.0 - Black Pepper - SMALL","public_title":"SMALL","sku":"23T01B-S"},{"id":44947113083194,"price":8500,"name":"Craftsman's Basic Top 2.0 - Black Pepper - MEDIUM","public_title":"MEDIUM","sku":"23T01B-M"},{"id":44947113115962,"price":8500,"name":"Craftsman's Basic Top 2.0 - Black Pepper - LARGE","public_title":"LARGE","sku":"23T01B-L"},{"id":44947113148730,"price":8500,"name":"Craftsman's Basic Top 2.0 - Black Pepper - EXTRA LARGE","public_title":"EXTRA LARGE","sku":"23T01B-XL"}]},{"id":8080414802234,"gid":"gid:\/\/shopify\/Product\/8080414802234","vendor":"G R A Y E","type":"Top","variants":[{"id":44283539030330,"price":8500,"name":"Craftsman's Basic Top 2.0 - Salt - Small","public_title":"Small","sku":"23T01W-S"},{"id":44283539063098,"price":8500,"name":"Craftsman's Basic Top 2.0 - Salt - Medium","public_title":"Medium","sku":"23T01W-M"},{"id":4 ...
# for (var attr in meta) {
#   window.ShopifyAnalytics.meta[attr] = meta[attr];
# }</script>
# <script>window.ShopifyAnalytics.merchantGoogleAnalytics = function() {
#
# };
# </script>
# <script class="analytics">(window.gaDevIds=window.gaDevIds||[]).push('BwiEti');
#
#
# (function () {
#     var customDocumentWrite = function(content) {
#       var jquery = null;
#
#       if (window.jQuery) {
#         jquery = window.jQuery;
#       } else if (window.Checkout && window.Checkout.$) {
#         jquery = window.Checkout.$;
#       }
#
#       if (jquery) {
#         jquery('body').append(content);
#       }
#     };
#
#     var hasLoggedConversion = function(token) {
#       if (token) {
#         return document.cookie.indexOf('loggedConversion=' + token) !== -1;
#       }
#       return false;
#     }
#
#     var setCookieIfConversion = function(token) {
#       if (token) {
#         var twoMonthsFromNow = new Date(Date.now());
#         twoMonthsFromNow.setMonth(twoMonthsFromNow.getMonth() + 2);
#
#         document.cookie = 'loggedConversion=' + token + '; expires=' + twoMonthsFromNow;
#       }
#     }
#
#     var trekkie = window.ShopifyAnalytics.lib = window.trekkie = window.trekkie || [];
#     if (trekkie.integrations) {
#       return;
#     }
#     trekkie.methods = [
#       'identify',
#       'page',
#       'ready',
#       'track',
#       'trackForm',
#       'trackLink'
#     ];
#     trekkie.factory = function(method) {
#       return function() {
#         var args = Array.prototype.slice.call(arguments);
#         args.unshift(method);
#         trekkie.push(args);
#         return trekkie;
#       };
#     };
#     for (var i = 0; i < trekkie.methods.length; i++) {
#       var key = trekkie.methods[i];
#       trekkie[key] = trekkie.factory(key);
#     }
#     trekkie.load = function(config) {
#       trekkie.config = config || {};
#       trekkie.config.initialDocumentCookie = document.cookie;
#       var first = document.getElementsByTagName('script')[0];
#       var script = document.createElement('script');
#       script.type = 'text/javascript';
#       script.onerror = function(e) {
#         var scriptFallback = document.createElement('script');
#         scriptFallback.type = 'text/javascript';
#         scriptFallback.onerror = function(error) {
#                 var Monorail = {
#       produce: function produce(monorailDomain, schemaId, payload) {
#         var currentMs = new Date().getTime();
#         var event = {
#           schema_id: schemaId,
#           payload: payload,
#           metadata: {
#             event_created_at_ms: currentMs,
#             event_sent_at_ms: currentMs
#           }
#         };
#         return Monorail.sendRequest("https://" + monorailDomain + "/v1/produce", JSON.stringify(event));
#       },
#       sendRequest: function sendRequest(endpointUrl, payload) {
#         // Try the sendBeacon API
#         if (window && window.navigator && typeof window.navigator.sendBeacon === 'function' && typeof window.Blob === 'function' && !Monorail.isIos12()) {
#           var blobData = new window.Blob([payload], {
#             type: 'text/plain'
#           });
#
#           if (window.navigator.sendBeacon(endpointUrl, blobData)) {
#             return true;
#           } // sendBeacon was not successful
#
#         } // XHR beacon
#
#         var xhr = new XMLHttpRequest();
#
#         try {
#           xhr.open('POST', endpointUrl);
#           xhr.setRequestHeader('Content-Type', 'text/plain');
#           xhr.send(payload);
#         } catch (e) {
#           console.log(e);
#         }
#
#         return false;
#       },
#       isIos12: function isIos12() {
#         return window.navigator.userAgent.lastIndexOf('iPhone; CPU iPhone OS 12_') !== -1 || window.navigator.userAgent.lastIndexOf('iPad; CPU OS 12_') !== -1;
#       }
#     };
#     Monorail.produce('monorail-edge.shopifysvc.com',
#       'trekkie_storefront_load_errors/1.1',
#       {shop_id: 14141076,
#       theme_id: 159228363066,
#       app_name: "storefront",
#       context_url: window.location.href,
#       source_url: "//grayestudio.com/cdn/s/trekkie.storefront.3838335172bb3eee0c7f8320cb9d78b9a94cf814.min.js"});
#
#         };
#         scriptFallback.async = true;
#         scriptFallback.src = '//grayestudio.com/cdn/s/trekkie.storefront.3838335172bb3eee0c7f8320cb9d78b9a94cf814.min.js';
#         first.parentNode.insertBefore(scriptFallback, first);
#       };
#       script.async = true;
#       script.src = '//grayestudio.com/cdn/s/trekkie.storefront.3838335172bb3eee0c7f8320cb9d78b9a94cf814.min.js';
#       first.parentNode.insertBefore(script, first);
#     };
#     trekkie.load(
#       {"Trekkie":{"appName":"storefront","development":false,"defaultAttributes":{"shopId":14141076,"isMerchantRequest":null,"themeId":159228363066,"themeCityHash":"8037124266340387688","contentLanguage":"en","currency":"SGD"},"isServerSideCookieWritingEnabled":true,"monorailRegion":"shop_domain"},"Google Analytics":{"trackingId":"UA-91818857-1","domain":"auto","siteSpeedSampleRate":"10","enhancedEcommerce":true,"doubleClick":true,"includeSearch":true},"Facebook Pixel":{"pixelIds":["210979665975230"],"agent":"plshopify1.2"},"TikTok Pixel":{"pixelId":"CAJF0PRC77U28261QING"},"Google Gtag Pixel":{"conversionId":"AW-863292767","eventLabels":[{"type":"page_view","action_label":"AW-863292767\/kRyOCIzQ__MBEN-a05sD"},{"type":"purchase","action_label":"AW-863292767\/d14LCI_Q__MBEN-a05sD"},{"type":"view_item","action_label":"AW-863292767\/_9SJCIrR__MBEN-a05sD"},{"type":"add_to_cart","action_label":"AW-863292767\/-z8LCI3R__MBEN-a05sD"},{"type":"begin_checkout","action_label":"AW-863292767\/24KiCJDR__MBEN-a05sD"},{"type":"search","action_label":"AW-863292767\/7H8GCJPR__MBEN-a05sD"},{"type":"add_payment_info","action_label":"AW-863292767\/74zlCJbR__MBEN-a05sD"}],"targetCountry":"SG"},"Session Attribution":{},"S2S":{"facebookCapiEnabled":true,"facebookAppPixelId":"210979665975230","source":"trekkie-storefront-renderer"}}
#     );
#
#     var loaded = false;
#     trekkie.ready(function() {
#       if (loaded) return;
#       loaded = true;
#
#       window.ShopifyAnalytics.lib = window.trekkie;
#
#         ga('require', 'linker');
#       function addListener(element, type, callback) {
#         if (element.addEventListener) {
#           element.addEventListener(type, callback);
#         }
#         else if (element.attachEvent) {
#           element.attachEvent('on' + type, callback);
#         }
#       }
#       function decorate(event) {
#         event = event || window.event;
#         var target = event.target || event.srcElement;
#         if (target && (target.getAttribute('action') || target.getAttribute('href'))) {
#           ga(function (tracker) {
#             var linkerParam = tracker.get('linkerParam');
#             document.cookie = '_shopify_ga=' + linkerParam + '; ' + 'path=/';
#           });
#         }
#       }
#       addListener(window, 'load', function(){
#         for (var i=0; i < document.forms.length; i++) {
#           var action = document.forms[i].getAttribute('action');
#           if(action && action.indexOf('/cart') >= 0) {
#             addListener(document.forms[i], 'submit', decorate);
#           }
#         }
#         for (var i=0; i < document.links.length; i++) {
#           var href = document.links[i].getAttribute('href');
#           if(href && href.indexOf('/checkout') >= 0) {
#             addListener(document.links[i], 'click', decorate);
#           }
#         }
#       });
#
#
#       var originalDocumentWrite = document.write;
#       document.write = customDocumentWrite;
#       try { window.ShopifyAnalytics.merchantGoogleAnalytics.call(this); } catch(error) {};
#       document.write = originalDocumentWrite;
#
#       window.ShopifyAnalytics.lib.page(null,{"pageType":"collection","resourceType":"collection","resourceId":109947879512});
#
#       var match = window.location.pathname.match(/checkouts\/(.+)\/(thank_you|post_purchase)/)
#       var token = match? match[1]: undefined;
#       if (!hasLoggedConversion(token)) {
#         setCookieIfConversion(token);
#         window.ShopifyAnalytics.lib.track("Viewed Product Category",{"currency":"SGD","category":"Collection: tops","collectionName":"tops","collectionId":109947879512,"nonInteraction":true});
#       }
#     });
#
#
#         var eventsListenerScript = document.createElement('script');
#         eventsListenerScript.async = true;
#         eventsListenerScript.src = "//grayestudio.com/cdn/shopifycloud/shopify/assets/shop_events_listener-65cd0ba3fcd81a1df33f2510ec5bcf8c0e0958653b50e3965ec972dd638ee13f.js";
#         document.getElementsByTagName('head')[0].appendChild(eventsListenerScript);
#
# })();</script>
# <script class="boomerang">
# (function () {
#   if (window.BOOMR && (window.BOOMR.version || window.BOOMR.snippetExecuted)) {
#     return;
#   }
#   window.BOOMR = window.BOOMR || {};
#   window.BOOMR.snippetStart = new Date().getTime();
#   window.BOOMR.snippetExecuted = true;
#   window.BOOMR.snippetVersion = 12;
#   window.BOOMR.application = "storefront-renderer";
#   window.BOOMR.themeName = "Pipeline";
#   window.BOOMR.themeVersion = "7.1.2";
#   window.BOOMR.shopId = 14141076;
#   window.BOOMR.themeId = 159228363066;
#   window.BOOMR.renderRegion = "gcp-asia-southeast1";
#   window.BOOMR.url =
#     "https://grayestudio.com/cdn/shopifycloud/boomerang/shopify-boomerang-1.0.0.min.js";
#   var where = document.currentScript || document.getElementsByTagName("script")[0];
#   var parentNode = where.parentNode;
#   var promoted = false;
#   var LOADER_TIMEOUT = 3000;
#   function promote() {
#     if (promoted) {
#       return;
#     }
#     var script = document.createElement("script");
#     script.id = "boomr-scr-as";
#     script.src = window.BOOMR.url;
#     script.async = true;
#     parentNode.appendChild(script);
#     promoted = true;
#   }
#   function iframeLoader(wasFallback) {
#     promoted = true;
#     var dom, bootstrap, iframe, iframeStyle;
#     var doc = document;
#     var win = window;
#     window.BOOMR.snippetMethod = wasFallback ? "if" : "i";
#     bootstrap = function(parent, scriptId) {
#       var script = doc.createElement("script");
#       script.id = scriptId || "boomr-if-as";
#       script.src = window.BOOMR.url;
#       BOOMR_lstart = new Date().getTime();
#       parent = parent || doc.body;
#       parent.appendChild(script);
#     };
#     if (!window.addEventListener && window.attachEvent && navigator.userAgent.match(/MSIE [67]./)) {
#       window.BOOMR.snippetMethod = "s";
#       bootstrap(parentNode, "boomr-async");
#       return;
#     }
#     iframe = document.createElement("IFRAME");
#     iframe.src = "about:blank";
#     iframe.title = "";
#     iframe.role = "presentation";
#     iframe.loading = "eager";
#     iframeStyle = (iframe.frameElement || iframe).style;
#     iframeStyle.width = 0;
#     iframeStyle.height = 0;
#     iframeStyle.border = 0;
#     iframeStyle.display = "none";
#     parentNode.appendChild(iframe);
#     try {
#       win = iframe.contentWindow;
#       doc = win.document.open();
#     } catch (e) {
#       dom = document.domain;
#       iframe.src = "javascript:var d=document.open();d.domain='" + dom + "';void(0);";
#       win = iframe.contentWindow;
#       doc = win.document.open();
#     }
#     if (dom) {
#       doc._boomrl = function() {
#         this.domain = dom;
#         bootstrap();
#       };
#       doc.write("<body onload='document._boomrl();'>");
#     } else {
#       win._boomrl = function() {
#         bootstrap();
#       };
#       if (win.addEventListener) {
#         win.addEventListener("load", win._boomrl, false);
#       } else if (win.attachEvent) {
#         win.attachEvent("onload", win._boomrl);
#       }
#     }
#     doc.close();
#   }
#   var link = document.createElement("link");
#   if (link.relList &&
#     typeof link.relList.supports === "function" &&
#     link.relList.supports("preload") &&
#     ("as" in link)) {
#     window.BOOMR.snippetMethod = "p";
#     link.href = window.BOOMR.url;
#     link.rel = "preload";
#     link.as = "script";
#     link.addEventListener("load", promote);
#     link.addEventListener("error", function() {
#       iframeLoader(true);
#     });
#     setTimeout(function() {
#       if (!promoted) {
#         iframeLoader(true);
#       }
#     }, LOADER_TIMEOUT);
#     BOOMR_lstart = new Date().getTime();
#     parentNode.appendChild(link);
#   } else {
#     iframeLoader(false);
#   }
#   function boomerangSaveLoadTime(e) {
#     window.BOOMR_onload = (e && e.timeStamp) || new Date().getTime();
#   }
#   if (window.addEventListener) {
#     window.addEventListener("load", boomerangSaveLoadTime, false);
#   } else if (window.attachEvent) {
#     window.attachEvent("onload", boomerangSaveLoadTime);
#   }
#   if (document.addEventListener) {
#     document.addEventListener("onBoomerangLoaded", function(e) {
#       e.detail.BOOMR.init({
#         ResourceTiming: {
#           enabled: true,
#           trackedResourceTypes: ["script", "img", "css"]
#         },
#       });
#       e.detail.BOOMR.t_end = new Date().getTime();
#     });
#   } else if (document.attachEvent) {
#     document.attachEvent("onpropertychange", function(e) {
#       if (!e) e=event;
#       if (e.propertyName === "onBoomerangLoaded") {
#         e.detail.BOOMR.init({
#           ResourceTiming: {
#             enabled: true,
#             trackedResourceTypes: ["script", "img", "css"]
#           },
#         });
#         e.detail.BOOMR.t_end = new Date().getTime();
#       }
#     });
#   }
# })();</script>
# <a class="in-page-link visually-hidden skip-link" href="#MainContent">Skip to content</a>
# <!-- BEGIN sections: group-header -->
# <div class="shopify-section shopify-section-group-group-header" id="shopify-section-sections--20875830395194__announcement"><!-- /sections/announcement.liquid -->
# </div><div class="shopify-section shopify-section-group-group-header" id="shopify-section-sections--20875830395194__header"><!-- /sections/header.liquid --><style data-shopify="">
#   :root {
#     --COLOR-NAV-TEXT-TRANSPARENT: #f8f6f2;
#     --COLOR-HEADER-TRANSPARENT-GRADIENT: rgba(0, 0, 0, 0.2);
#     --LOGO-PADDING: 15px;
#     --menu-backfill-height: auto;
#   }
# </style>
# <div class="header__wrapper" data-header-sticky="directional" data-header-style="split" data-header-transparent="true" data-header-wrapper="" data-section-id="sections--20875830395194__header" data-section-type="header" data-underline-current="false" style="--bar-opacity: 0; --bar-width: 0; --bar-left: 0;">
# <header class="theme__header" data-header-height="">
# <div class="header__inner">
# <div class="wrapper">
# <div class="header__mobile">
# <div class="header__mobile__left">
# <button aria-controls="header-menu" aria-expanded="false" aria-haspopup="true" aria-label="Open menu" class="header__mobile__button" data-drawer-toggle="hamburger">
# <svg aria-hidden="true" class="icon icon-nav" focusable="false" role="presentation" viewbox="0 0 25 25"><path d="M0 4.062h25v2H0zm0 7h25v2H0zm0 7h25v2H0z"></path></svg>
# </button>
# </div>
# <div class="header__logo header__logo--image">
# <a class="header__logo__link" href="/" style="--LOGO-WIDTH: 30px">
# <img alt="G R A Y E" class="logo__img logo__img--color" height="30" loading="eager" src="//grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=30" srcset="
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=60 2x,
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=90 3x,
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=30
#         " width="30"/>
# </a>
# </div>
# <div class="header__mobile__right">
# <a class="header__mobile__button" data-drawer-toggle="drawer-cart" href="/cart">
# <svg aria-hidden="true" class="icon icon-cart" focusable="false" role="presentation" viewbox="0 0 25 25"><path d="M5.058 23a2 2 0 1 0 4.001-.001A2 2 0 0 0 5.058 23zm12.079 0c0 1.104.896 2 2 2s1.942-.896 1.942-2-.838-2-1.942-2-2 .896-2 2zM0 1a1 1 0 0 0 1 1h1.078l.894 3.341L5.058 13c0 .072.034.134.042.204l-1.018 4.58A.997.997 0 0 0 5.058 19h16.71a1 1 0 0 0 0-2H6.306l.458-2.061c.1.017.19.061.294.061h12.31c1.104 0 1.712-.218 2.244-1.5l3.248-6.964C25.423 4.75 24.186 4 23.079 4H5.058c-.157 0-.292.054-.438.088L3.844.772A1 1 0 0 0 2.87 0H1a1 1 0 0 0-1 1zm5.098 5H22.93l-3.192 6.798c-.038.086-.07.147-.094.19-.067.006-.113.012-.277.012H7.058v-.198l-.038-.195L5.098 6z"></path></svg>
# <span class="visually-hidden">Cart</span>
# <span class="header__cart__status">
# <span data-header-cart-price="0">
#       $0.00
#     </span>
# <span data-header-cart-count="0">
#       (0)
#     </span>
# <span data-header-cart-full="false"></span>
# </span>
# </a>
# </div>
# </div>
# <div class="header__desktop header__desktop--split" data-header-desktop=""><div class="header__desktop__bar__l" data-takes-space="">
# <div class="header__logo header__logo--image">
# <a class="header__logo__link" href="/" style="--LOGO-WIDTH: 30px">
# <img alt="G R A Y E" class="logo__img logo__img--color" height="30" loading="eager" src="//grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=30" srcset="
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=60 2x,
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=90 3x,
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=30
#         " width="30"/>
# </a>
# </div>
# </div>
# <div class="header__desktop__bar__r" data-takes-space="">
# <div class="header__desktop__bar__inline">
# <nav class="header__menu">
# <div class="header__menu__inner" data-text-items-wrapper="">
# <!-- /snippets/nav-item.liquid -->
# <div aria-controls="dropdown-ac061ab46f04475c307999887d48ca8a" aria-expanded="false" aria-haspopup="true" class="menu__item parent" data-hover-disclosure-toggle="dropdown-ac061ab46f04475c307999887d48ca8a" data-main-menu-text-item="" role="button">
# <a class="navlink navlink--toplevel" data-top-link="" href="/collections/new">
# <span class="navtext">SHOP</span>
# </a>
# <div class="header__dropdown" data-hover-disclosure="" id="dropdown-ac061ab46f04475c307999887d48ca8a">
# <div class="header__dropdown__wrapper">
# <div class="header__dropdown__inner">
# <a class="navlink navlink--child" data-stagger="" href="/collections/new">
# <span class="navtext">NEW IN</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/popular">
# <span class="navtext">POPULAR</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/young">
# <span class="navtext">BABY &amp; KIDS</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/t-shirts">
# <span class="navtext">T-SHIRTS</span>
# </a>
# <a class="navlink navlink--child main-menu--active" data-stagger="" href="/collections/tops">
# <span class="navtext">TOPS</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/outerwears">
# <span class="navtext">OUTERWEAR</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/pants">
# <span class="navtext">BOTTOMS</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/artefact">
# <span class="navtext">ARTEFACT (ACCESSORIES)</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="https://grayestudio.com/products/gift-card?variant=32324020306008">
# <span class="navtext">GIFT CARD</span>
# </a>
# <a class="navlink navlink--child highlight--link" data-stagger="" href="/collections/sale">
# <span class="navtext">SALE</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <!-- /snippets/nav-item.liquid -->
# <div aria-controls="dropdown-154a22647d0d8c8c75bccbc092e8205e" aria-expanded="false" aria-haspopup="true" class="menu__item parent" data-hover-disclosure-toggle="dropdown-154a22647d0d8c8c75bccbc092e8205e" data-main-menu-text-item="" role="button">
# <a class="navlink navlink--toplevel" data-top-link="" href="/pages/about-us">
# <span class="navtext">GRAYE</span>
# </a>
# <div class="header__dropdown" data-hover-disclosure="" id="dropdown-154a22647d0d8c8c75bccbc092e8205e">
# <div class="header__dropdown__wrapper">
# <div class="header__dropdown__inner">
# <a class="navlink navlink--child" data-stagger="" href="/pages/about-us">
# <span class="navtext">ABOUT</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/pages/envision-with-graye">
# <span class="navtext">ENVISION WITH GRAYE</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/pages/garment-care">
# <span class="navtext">GARMENT CARE</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/blogs/news">
# <span class="navtext">JOURNEY</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/workshop">
# <span class="navtext">WORKSHOPS</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/pages/explore-our-stores">
# <span class="navtext">OUR STORES</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <!-- /snippets/nav-item.liquid -->
# <div aria-controls="dropdown-91c0fb17b91c8ef1b62f43a50d46a3fc" aria-expanded="false" aria-haspopup="true" class="menu__item parent" data-hover-disclosure-toggle="dropdown-91c0fb17b91c8ef1b62f43a50d46a3fc" data-main-menu-text-item="" role="button">
# <a class="navlink navlink--toplevel" data-top-link="" href="/collections/young">
# <span class="navtext">YOUNG</span>
# </a>
# <div class="header__dropdown" data-hover-disclosure="" id="dropdown-91c0fb17b91c8ef1b62f43a50d46a3fc">
# <div class="header__dropdown__wrapper">
# <div class="header__dropdown__inner">
# <a class="navlink navlink--child" data-stagger="" href="/pages/young-by-graye">
# <span class="navtext">ABOUT YOUNG</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/pages/onesie-to-tee">
# <span class="navtext">ONESIE TO TEE</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/young">
# <span class="navtext">SHOP YOUNG</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="hover__bar"></div>
# <div class="hover__bg"></div>
# </div>
# </nav>
# <div class="header__desktop__buttons header__desktop__buttons--icons"><div class="header__desktop__button">
# <a class="navlink" href="/account">
# <svg aria-hidden="true" class="icon icon-account" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M10.713 8.771c.31.112.53.191.743.27.555.204.985.372 1.367.539 1.229.535 1.993 1.055 2.418 1.885.464.937.722 1.958.758 2.997.03.84-.662 1.538-1.524 1.538H1.525c-.862 0-1.554-.697-1.524-1.538a7.36 7.36 0 0 1 .767-3.016c.416-.811 1.18-1.33 2.41-1.866a25.25 25.25 0 0 1 1.366-.54l.972-.35a1.42 1.42 0 0 0-.006-.072c-.937-1.086-1.369-2.267-1.369-4.17C4.141 1.756 5.517 0 8.003 0c2.485 0 3.856 1.755 3.856 4.448 0 2.03-.492 3.237-1.563 4.386.169-.18.197-.253.207-.305a1.2 1.2 0 0 0-.019.16l.228.082zm-9.188 5.742h12.95a5.88 5.88 0 0 0-.608-2.402c-.428-.835-2.214-1.414-4.46-2.224-.608-.218-.509-1.765-.24-2.053.631-.677 1.166-1.471 1.166-3.386 0-1.934-.782-2.96-2.33-2.96-1.549 0-2.336 1.026-2.336 2.96 0 1.915.534 2.709 1.165 3.386.27.288.369 1.833-.238 2.053-2.245.81-4.033 1.389-4.462 2.224a5.88 5.88 0 0 0-.607 2.402z"></path></svg>
# <span class="visually-hidden">My Account</span>
# </a>
# </div>
# <div class="header__desktop__button">
# <a class="navlink" data-popdown-toggle="search-popdown" href="/search">
# <svg aria-hidden="true" class="icon icon-search" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M16 14.864 14.863 16l-4.24-4.241a6.406 6.406 0 0 1-4.048 1.392 6.61 6.61 0 0 1-4.65-1.925A6.493 6.493 0 0 1 .5 9.098 6.51 6.51 0 0 1 0 6.575a6.536 6.536 0 0 1 1.922-4.652A6.62 6.62 0 0 1 4.062.5 6.52 6.52 0 0 1 6.575 0 6.5 6.5 0 0 1 9.1.5c.8.332 1.51.806 2.129 1.423a6.454 6.454 0 0 1 1.436 2.13 6.54 6.54 0 0 1 .498 2.522c0 1.503-.468 2.853-1.4 4.048L16 14.864zM3.053 10.091c.973.972 2.147 1.461 3.522 1.461 1.378 0 2.551-.489 3.525-1.461.968-.967 1.45-2.138 1.45-3.514 0-1.37-.482-2.545-1.45-3.524-.981-.968-2.154-1.45-3.525-1.45-1.376 0-2.547.483-3.513 1.45-.973.973-1.46 2.146-1.46 3.523 0 1.375.483 2.548 1.45 3.515z"></path></svg>
# <span class="visually-hidden">Search</span>
# </a>
# </div>
# <div class="header__desktop__button">
# <a class="navlink navlink--cart" data-drawer-toggle="drawer-cart" href="/cart">
# <svg aria-hidden="true" class="icon icon-cart" focusable="false" role="presentation" viewbox="0 0 25 25"><path d="M5.058 23a2 2 0 1 0 4.001-.001A2 2 0 0 0 5.058 23zm12.079 0c0 1.104.896 2 2 2s1.942-.896 1.942-2-.838-2-1.942-2-2 .896-2 2zM0 1a1 1 0 0 0 1 1h1.078l.894 3.341L5.058 13c0 .072.034.134.042.204l-1.018 4.58A.997.997 0 0 0 5.058 19h16.71a1 1 0 0 0 0-2H6.306l.458-2.061c.1.017.19.061.294.061h12.31c1.104 0 1.712-.218 2.244-1.5l3.248-6.964C25.423 4.75 24.186 4 23.079 4H5.058c-.157 0-.292.054-.438.088L3.844.772A1 1 0 0 0 2.87 0H1a1 1 0 0 0-1 1zm5.098 5H22.93l-3.192 6.798c-.038.086-.07.147-.094.19-.067.006-.113.012-.277.012H7.058v-.198l-.038-.195L5.098 6z"></path></svg>
# <span class="visually-hidden">Cart</span>
# <span class="header__cart__status">
# <span data-header-cart-price="0">
#       $0.00
#     </span>
# <span data-header-cart-count="0">
#       (0)
#     </span>
# <span data-header-cart-full="false"></span>
# </span>
# </a>
# </div>
# </div>
# </div>
# </div></div>
# </div>
# </div>
# </header>
# <nav aria-label="Main menu" class="drawer header__drawer display-none" data-drawer="hamburger" id="header-menu">
# <div class="drawer__content">
# <div class="drawer__top">
# <div class="drawer__top__left">
# <a class="drawer__account" href="/account">
# <svg aria-hidden="true" class="icon icon-account" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M10.713 8.771c.31.112.53.191.743.27.555.204.985.372 1.367.539 1.229.535 1.993 1.055 2.418 1.885.464.937.722 1.958.758 2.997.03.84-.662 1.538-1.524 1.538H1.525c-.862 0-1.554-.697-1.524-1.538a7.36 7.36 0 0 1 .767-3.016c.416-.811 1.18-1.33 2.41-1.866a25.25 25.25 0 0 1 1.366-.54l.972-.35a1.42 1.42 0 0 0-.006-.072c-.937-1.086-1.369-2.267-1.369-4.17C4.141 1.756 5.517 0 8.003 0c2.485 0 3.856 1.755 3.856 4.448 0 2.03-.492 3.237-1.563 4.386.169-.18.197-.253.207-.305a1.2 1.2 0 0 0-.019.16l.228.082zm-9.188 5.742h12.95a5.88 5.88 0 0 0-.608-2.402c-.428-.835-2.214-1.414-4.46-2.224-.608-.218-.509-1.765-.24-2.053.631-.677 1.166-1.471 1.166-3.386 0-1.934-.782-2.96-2.33-2.96-1.549 0-2.336 1.026-2.336 2.96 0 1.915.534 2.709 1.165 3.386.27.288.369 1.833-.238 2.053-2.245.81-4.033 1.389-4.462 2.224a5.88 5.88 0 0 0-.607 2.402z"></path></svg>
# <span class="visually-hidden">My Account</span>
# </a></div>
# <button aria-label="Close" class="drawer__button drawer__close" data-drawer-toggle="hamburger">
# <svg aria-hidden="true" class="icon icon-close" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.06 1 12.02 12.021-1.06 1.061L1 2.062z"></path><path d="M1 13.02 13.022 1l1.061 1.06-12.02 12.02z"></path></g></svg>
# </button>
# </div>
# <div class="drawer__inner" data-drawer-scrolls="">
# <div class="drawer__search" data-drawer-search="">
# <!-- /snippets/search-predictive.liquid -->
# <div data-search-popdown-wrap="">
# <div class="search-drawer search__predictive" data-popdown-outer="" id="search-drawer"><predictive-search><form action="/search" method="get" role="search">
# <div class="item--loadbar" data-loading-indicator="" style="display: none;"></div>
# <div class="search__predictive__outer">
# <div class="wrapper">
# <div class="search__predictive__main">
# <div class="search__predictive__actions">
# <button class="search__predictive__button" type="submit">
# <span class="visually-hidden">Search</span>
# <svg aria-hidden="true" class="icon icon-search" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M16 14.864 14.863 16l-4.24-4.241a6.406 6.406 0 0 1-4.048 1.392 6.61 6.61 0 0 1-4.65-1.925A6.493 6.493 0 0 1 .5 9.098 6.51 6.51 0 0 1 0 6.575a6.536 6.536 0 0 1 1.922-4.652A6.62 6.62 0 0 1 4.062.5 6.52 6.52 0 0 1 6.575 0 6.5 6.5 0 0 1 9.1.5c.8.332 1.51.806 2.129 1.423a6.454 6.454 0 0 1 1.436 2.13 6.54 6.54 0 0 1 .498 2.522c0 1.503-.468 2.853-1.4 4.048L16 14.864zM3.053 10.091c.973.972 2.147 1.461 3.522 1.461 1.378 0 2.551-.489 3.525-1.461.968-.967 1.45-2.138 1.45-3.514 0-1.37-.482-2.545-1.45-3.524-.981-.968-2.154-1.45-3.525-1.45-1.376 0-2.547.483-3.513 1.45-.973.973-1.46 2.146-1.46 3.523 0 1.375.483 2.548 1.45 3.515z"></path></svg>
# </button>
# <input aria-controls="predictive-search-results" aria-label="Search our store" data-predictive-search-input="search-popdown-results" name="q" placeholder="Search..." type="search" value=""/>
# <div class="search__predictive__clear">
# <button aria-label="Reset" class="search__predictive__close__inner search-reset is-hidden" type="reset">
# <svg aria-hidden="true" class="icon icon-close" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.06 1 12.02 12.021-1.06 1.061L1 2.062z"></path><path d="M1 13.02 13.022 1l1.061 1.06-12.02 12.02z"></path></g></svg>
# Clear</button>
# </div>
# </div>
# <div class="search__predictive__close">
# <button aria-label="Close" class="search__predictive__close__inner" data-close-popdown="" type="button">
# <svg aria-hidden="true" class="icon icon-close-small" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.237 1.073 12.021 12.021-1.414 1.414L.824 2.488z"></path><path d="m.823 13.094 12.021-12.02 1.414 1.413-12.02 12.021z"></path></g></svg>
# </button>
# </div>
# </div>
# </div>
# </div><div class="header__search__results" data-predictive-search-results="" tabindex="-1"></div>
# <span aria-hidden="true" class="predictive-search-status visually-hidden" data-predictive-search-status="" role="status"></span></form></predictive-search></div>
# <script data-predictive-search-aria-template="" type="text/x-template">
#     <div aria-live="polite">
#       <p>
#
#           {{@if(it.count)}}
#             <span class="badge">{{ it.count }}</span>
#           {{/if}}
#           {{ it.title }} <em>{{ it.query }}</em>
#
#       </p>
#     </div>
#   </script>
# <script data-predictive-search-title-template="" type="text/x-template">
#     <div class="search__results__heading">
#
#         <p>
#           <span class="search__results__title">{{ it.title }}</span>
#           <span class="badge">{{ it.count }}</span>
#         </p>
#
#     </div>
#   </script>
# <script data-search-other-template="" type="text/x-template">
#
#       {{@each(it) => object, index}}
#         <div class="other__inline animates" style="animation-delay: {{ index | animationDelay }}ms;">
#           <p class="other__inline__title">
#             <a href="{{ object.url }}">{{ object.title | safe }}</a>
#           </p>
#         </div>
#       {{/each}}
#
#   </script>
# <script data-search-product-template="" type="text/x-template">
#
#       {{@each(it) => object, index}}
#         <a href="{{ object.url }}" class="product__inline animates" style="animation-delay: {{ index | animationDelay }}ms;">
#           <div class="product__inline__image {{ @if (object.featured_image.width === null) }} product__inline__image--no-image {{ /if}}">
#             {{ @if (object.featured_image.width !== null) }}
#               <img class="img-aspect-ratio" width="{{object.featured_image.width}}" height="{{ object.featured_image.height }}" alt="{{ object.featured_image.alt }}" src="{{ object.thumb }}">
#             {{ /if}}
#           </div>
#           <div>
#             <p class="product__inline__title">
#               {{ object.title | safe }}
#             </p>
#             <p class="product__inline__price">
#               <span class="price {{ object.classes }}">
#                 {{ object.price | safe }}
#               </span>
#               {{@if(object.sold_out)}}
#                 <br /><em>{{ object.sold_out_translation }}</em>
#               {{/if}}
#               {{@if(object.on_sale)}}
#                 <span class="compare-at">
#                   {{ object.compare_at_price | safe }}
#                 </span>
#               {{/if}}
#             </p>
#           </div>
#         </a>
#       {{/each}}
#
#   </script>
# </div>
# </div>
# <div class="drawer__menu" data-sliderule-pane="0" data-stagger-animation="">
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper"><button class="sliderow" data-animates="0" data-sliderule-open="sliderule-df8e1ed0a18e833743bf2a0fd4e0361e">
# <span class="sliderow__title">SHOP</span>
# <span class="sliderule__chevron--right">
# <svg aria-hidden="true" class="icon icon-arrow-medium-right" focusable="false" role="presentation" viewbox="0 0 9 15"><path d="M6.875 7.066.87 1.06 1.93 0l6.006 6.005L7.94 6 9 7.06l-.004.006.005.005-1.06 1.06-.006-.004-6.005 6.005-1.061-1.06 6.005-6.006z" fill-rule="evenodd"></path></svg>
# <span class="visually-hidden">Expand menu</span>
# </span>
# </button>
# <div class="mobile__menu__dropdown sliderule__panel" data-sliderule="" id="sliderule-df8e1ed0a18e833743bf2a0fd4e0361e"><div class="sliderow sliderow__back" data-animates="1">
# <button class="drawer__button" data-sliderule-close="sliderule-df8e1ed0a18e833743bf2a0fd4e0361e">
# <span class="sliderule__chevron--left">
# <svg aria-hidden="true" class="icon icon-arrow-medium-left" focusable="false" role="presentation" viewbox="0 0 9 15"><path d="M2.127 7.066 8.132 1.06 7.072 0 1.065 6.005 1.061 6 0 7.06l.004.006L0 7.07l1.06 1.06.006-.004 6.005 6.005 1.061-1.06-6.005-6.006z" fill-rule="evenodd"></path></svg>
# <span class="visually-hidden">Hide menu</span>
# </span>
# </button>
# <a class="sliderow__title" href="/collections/new">SHOP</a>
# </div><div class="sliderow__links" data-links="">
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/new">NEW IN</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/popular">POPULAR</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/young">BABY &amp; KIDS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/t-shirts">T-SHIRTS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/tops">TOPS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/outerwears">OUTERWEAR</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/pants">BOTTOMS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/artefact">ARTEFACT (ACCESSORIES)</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="https://grayestudio.com/products/gift-card?variant=32324020306008">GIFT CARD</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title highlight--link" href="/collections/sale">SALE</a>
# </div></div>
# </div><div class="sliderule-grid blocks-0">
# </div></div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper"><button class="sliderow" data-animates="0" data-sliderule-open="sliderule-f99a83a8c336d3e3fae3c2ced23b8d7b">
# <span class="sliderow__title">GRAYE</span>
# <span class="sliderule__chevron--right">
# <svg aria-hidden="true" class="icon icon-arrow-medium-right" focusable="false" role="presentation" viewbox="0 0 9 15"><path d="M6.875 7.066.87 1.06 1.93 0l6.006 6.005L7.94 6 9 7.06l-.004.006.005.005-1.06 1.06-.006-.004-6.005 6.005-1.061-1.06 6.005-6.006z" fill-rule="evenodd"></path></svg>
# <span class="visually-hidden">Expand menu</span>
# </span>
# </button>
# <div class="mobile__menu__dropdown sliderule__panel" data-sliderule="" id="sliderule-f99a83a8c336d3e3fae3c2ced23b8d7b"><div class="sliderow sliderow__back" data-animates="1">
# <button class="drawer__button" data-sliderule-close="sliderule-f99a83a8c336d3e3fae3c2ced23b8d7b">
# <span class="sliderule__chevron--left">
# <svg aria-hidden="true" class="icon icon-arrow-medium-left" focusable="false" role="presentation" viewbox="0 0 9 15"><path d="M2.127 7.066 8.132 1.06 7.072 0 1.065 6.005 1.061 6 0 7.06l.004.006L0 7.07l1.06 1.06.006-.004 6.005 6.005 1.061-1.06-6.005-6.006z" fill-rule="evenodd"></path></svg>
# <span class="visually-hidden">Hide menu</span>
# </span>
# </button>
# <a class="sliderow__title" href="/pages/about-us">GRAYE</a>
# </div><div class="sliderow__links" data-links="">
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/pages/about-us">ABOUT</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/pages/envision-with-graye">ENVISION WITH GRAYE</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/pages/garment-care">GARMENT CARE</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/blogs/news">JOURNEY</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/workshop">WORKSHOPS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/pages/explore-our-stores">OUR STORES</a>
# </div></div>
# </div><div class="sliderule-grid blocks-0">
# </div></div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper"><button class="sliderow" data-animates="0" data-sliderule-open="sliderule-975453dbb60e68f2cd134af896b8d431">
# ...
# <h2 class="visually-hidden" id="currency-heading-localization-form-footer">
#     Currency
#   </h2>
# <popout-select>
# <div class="popout" data-popout="">
# <button aria-controls="currency-list-localization-form-footer" aria-describedby="currency-heading-localization-form-footer" aria-expanded="false" class="popout__toggle" data-popout-toggle="" type="button">
#           SGD $<svg aria-hidden="true" class="icon icon--wide icon-arrow-down" focusable="false" role="presentation" viewbox="0 0 30 17"><path d="M0 3.235 3.525 0l11.473 10.509L26.473 0 30 3.235 14.998 17z" fill-rule="evenodd"></path></svg></button>
# <ul class="popout-list" data-popout-list="" id="currency-list-localization-form-footer">
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="AUD" href="#">
# <span>AUD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="BND" href="#">
# <span>BND $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="CAD" href="#">
# <span>CAD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="CHF" href="#">
# <span>CHF CHF</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="CNY" href="#">
# <span>CNY ¥</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="DKK" href="#">
# <span>DKK kr.</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="EUR" href="#">
# <span>EUR €</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="GBP" href="#">
# <span>GBP £</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="HKD" href="#">
# <span>HKD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="IDR" href="#">
# <span>IDR Rp</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="INR" href="#">
# <span>INR ₹</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="ISK" href="#">
# <span>ISK kr</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="JPY" href="#">
# <span>JPY ¥</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="KRW" href="#">
# <span>KRW ₩</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="MOP" href="#">
# <span>MOP P</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="MYR" href="#">
# <span>MYR RM</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="NZD" href="#">
# <span>NZD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="PHP" href="#">
# <span>PHP ₱</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="PLN" href="#">
# <span>PLN zł</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="SEK" href="#">
# <span>SEK kr</span>
# </a>
# </li>
# <li class="popout-list__item popout-list__item--current">
# <a aria-current="true" class="popout-list__option" data-popout-option="" data-value="SGD" href="#">
# <span>SGD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="THB" href="#">
# <span>THB ฿</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="TWD" href="#">
# <span>TWD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="USD" href="#">
# <span>USD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="VND" href="#">
# <span>VND ₫</span>
# </a>
# </li></ul>
# <input data-popout-input="" id="CurrencySelector-localization-form-footer" name="currency_code" type="hidden" value="SGD"/>
# </div>
# </popout-select>
# </div>
# </form><noscript><form accept-charset="UTF-8" action="/localization" class="locale-footer-nojs" enctype="multipart/form-data" id="localization-form-footer-noscript" method="post"><input name="form_type" type="hidden" value="localization"/><input name="utf8" type="hidden" value="✓"/><input name="_method" type="hidden" value="put"/><input name="return_to" type="hidden" value="/collections/tops"/><h2 class="visually-hidden" id="localization-form-footer-noscript-locale-heading">
#                   Currency
#                 </h2>
# <select aria-labelledby="localization-form-footer-noscript-currency-heading" name="country_code"><option value="AU">
#                       Australia (AUD
#                       $)
#                     </option><option value="BE">
#                       Belgium (EUR
#                       €)
#                     </option><option value="BN">
#                       Brunei (BND
#                       $)
#                     </option><option value="CA">
#                       Canada (CAD
#                       $)
#                     </option><option value="CN">
#                       China (CNY
#                       ¥)
#                     </option><option value="DK">
#                       Denmark (DKK
#                       kr.)
#                     </option><option value="FI">
#                       Finland (EUR
#                       €)
#                     </option><option value="FR">
#                       France (EUR
#                       €)
#                     </option><option value="DE">
#                       Germany (EUR
#                       €)
#                     </option><option value="HK">
#                       Hong Kong SAR (HKD
#                       $)
#                     </option><option value="IS">
#                       Iceland (ISK
#                       kr)
#                     </option><option value="IN">
#                       India (INR
#                       ₹)
#                     </option><option value="ID">
#                       Indonesia (IDR
#                       Rp)
#                     </option><option value="IE">
#                       Ireland (EUR
#                       €)
#                     </option><option value="IT">
#                       Italy (EUR
#                       €)
#                     </option><option value="JP">
#                       Japan (JPY
#                       ¥)
#                     </option><option value="MO">
#                       Macao SAR (MOP
#                       P)
#                     </option><option value="MY">
#                       Malaysia (MYR
#                       RM)
#                     </option><option value="MC">
#                       Monaco (EUR
#                       €)
#                     </option><option value="NL">
#                       Netherlands (EUR
#                       €)
#                     </option><option value="NZ">
#                       New Zealand (NZD
#                       $)
#                     </option><option value="NO">
#                       Norway (SGD
#                       $)
#                     </option><option value="PH">
#                       Philippines (PHP
#                       ₱)
#                     </option><option value="PL">
#                       Poland (PLN
#                       zł)
#                     </option><option value="PT">
#                       Portugal (EUR
#                       €)
#                     </option><option selected="" value="SG">
#                       Singapore (SGD
#                       $)
#                     </option><option value="KR">
#                       South Korea (KRW
#                       ₩)
#                     </option><option value="ES">
#                       Spain (EUR
#                       €)
#                     </option><option value="SE">
#                       Sweden (SEK
#                       kr)
#                     </option><option value="CH">
#                       Switzerland (CHF
#                       CHF)
#                     </option><option value="TW">
#                       Taiwan (TWD
#                       $)
#                     </option><option value="TH">
#                       Thailand (THB
#                       ฿)
#                     </option><option value="TR">
#                       Turkey (SGD
#                       $)
#                     </option><option value="GB">
#                       United Kingdom (GBP
#                       £)
#                     </option><option value="US">
#                       United States (USD
#                       $)
#                     </option><option value="VN">
#                       Vietnam (VND
#                       ₫)
#                     </option></select><button class="btn btn--primary btn--full">Update</button></form></noscript>
# </div>
# <div class="subfooter__item subfooter__item--copyright">
# <span class="subfooter__copyright"> © <a href="/" title="">G R A Y E</a> 2023 </span>
# <span class="subfooter__copyright"><a href="/pages/about-us">About</a></span>
# <span class="subfooter__copyright"><a href="/pages/contact-us">Contact</a></span>
# <span class="subfooter__copyright"><a href="/pages/delivery-information">Shipping</a></span>
# <span class="subfooter__copyright"><a href="/pages/return-and-exchange">Returns</a></span>
# <span class="subfooter__copyright"><a href="/pages/terms-conditions">Terms</a></span>
# <!-- The following lines fix Lighthouse security warnings on the Shopify link.--><!-- Remove the following line to delete Powered by Shopify from your footer -->
# <span class="subfooter__copyright" data-powered-link=""><a href="https://www.shopify.com?utm_campaign=poweredby&amp;utm_medium=shopify&amp;utm_source=onlinestore" rel="noopener" target="_blank">Powered by Shopify</a></span>
# <!-- Stop deleting here -->
# </div></div>
# </div>
# </section>
# </div>
# <!-- END sections: group-footer -->
# <div class="search--popdown">
# <!-- /snippets/search-predictive.liquid -->
# <div data-search-popdown-wrap="">
# <div class="search-popdown search__predictive" data-popdown-outer="" id="search-popdown"><predictive-search><form action="/search" method="get" role="search">
# <div class="item--loadbar" data-loading-indicator="" style="display: none;"></div>
# <div class="search__predictive__outer">
# <div class="wrapper">
# <div class="search__predictive__main">
# <div class="search__predictive__actions">
# <button class="search__predictive__button" type="submit">
# <span class="visually-hidden">Search</span>
# <svg aria-hidden="true" class="icon icon-search" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M16 14.864 14.863 16l-4.24-4.241a6.406 6.406 0 0 1-4.048 1.392 6.61 6.61 0 0 1-4.65-1.925A6.493 6.493 0 0 1 .5 9.098 6.51 6.51 0 0 1 0 6.575a6.536 6.536 0 0 1 1.922-4.652A6.62 6.62 0 0 1 4.062.5 6.52 6.52 0 0 1 6.575 0 6.5 6.5 0 0 1 9.1.5c.8.332 1.51.806 2.129 1.423a6.454 6.454 0 0 1 1.436 2.13 6.54 6.54 0 0 1 .498 2.522c0 1.503-.468 2.853-1.4 4.048L16 14.864zM3.053 10.091c.973.972 2.147 1.461 3.522 1.461 1.378 0 2.551-.489 3.525-1.461.968-.967 1.45-2.138 1.45-3.514 0-1.37-.482-2.545-1.45-3.524-.981-.968-2.154-1.45-3.525-1.45-1.376 0-2.547.483-3.513 1.45-.973.973-1.46 2.146-1.46 3.523 0 1.375.483 2.548 1.45 3.515z"></path></svg>
# </button>
# <input aria-controls="predictive-search-results" aria-label="Search our store" data-predictive-search-input="search-popdown-results" name="q" placeholder="Search..." type="search" value=""/>
# <div class="search__predictive__clear">
# <button aria-label="Reset" class="search__predictive__close__inner search-reset is-hidden" type="reset">
# <svg aria-hidden="true" class="icon icon-close" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.06 1 12.02 12.021-1.06 1.061L1 2.062z"></path><path d="M1 13.02 13.022 1l1.061 1.06-12.02 12.02z"></path></g></svg>
# Clear</button>
# </div>
# </div>
# <div class="search__predictive__close">
# <button aria-label="Close" class="search__predictive__close__inner" data-close-popdown="" type="button">
# <svg aria-hidden="true" class="icon icon-close-small" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.237 1.073 12.021 12.021-1.414 1.414L.824 2.488z"></path><path d="m.823 13.094 12.021-12.02 1.414 1.413-12.02 12.021z"></path></g></svg>
# </button>
# </div>
# </div>
# </div>
# </div><div class="header__search__results" data-predictive-search-results="" tabindex="-1"></div>
# <span aria-hidden="true" class="predictive-search-status visually-hidden" data-predictive-search-status="" role="status"></span></form></predictive-search></div>
# <span class="drawer__underlay" data-search-underlay=""></span>
# <script data-predictive-search-aria-template="" type="text/x-template">
#     <div aria-live="polite">
#       <p>
#
#           {{@if(it.count)}}
#             <span class="badge">{{ it.count }}</span>
#           {{/if}}
#           {{ it.title }} <em>{{ it.query }}</em>
#
#       </p>
#     </div>
#   </script>
# <script data-predictive-search-title-template="" type="text/x-template">
#     <div class="search__results__heading">
#
#         <p>
#           <span class="search__results__title">{{ it.title }}</span>
#           <span class="badge">{{ it.count }}</span>
#         </p>
#
#     </div>
#   </script>
# <script data-search-other-template="" type="text/x-template">
#
#       {{@each(it) => object, index}}
#         <div class="other__inline animates" style="animation-delay: {{ index | animationDelay }}ms;">
#           <p class="other__inline__title">
#             <a href="{{ object.url }}">{{ object.title | safe }}</a>
#           </p>
#         </div>
#       {{/each}}
#
#   </script>
# <script data-search-product-template="" type="text/x-template">
#
#       {{@each(it) => object, index}}
#         <a href="{{ object.url }}" class="product__inline animates" style="animation-delay: {{ index | animationDelay }}ms;">
#           <div class="product__inline__image {{ @if (object.featured_image.width === null) }} product__inline__image--no-image {{ /if}}">
#             {{ @if (object.featured_image.width !== null) }}
#               <img class="img-aspect-ratio" width="{{object.featured_image.width}}" height="{{ object.featured_image.height }}" alt="{{ object.featured_image.alt }}" src="{{ object.thumb }}">
#             {{ /if}}
#           </div>
#           <div>
#             <p class="product__inline__title">
#               {{ object.title | safe }}
#             </p>
#             <p class="product__inline__price">
#               <span class="price {{ object.classes }}">
#                 {{ object.price | safe }}
#               </span>
#               {{@if(object.sold_out)}}
#                 <br /><em>{{ object.sold_out_translation }}</em>
#               {{/if}}
#               {{@if(object.on_sale)}}
#                 <span class="compare-at">
#                   {{ object.compare_at_price | safe }}
#                 </span>
#               {{/if}}
#             </p>
#           </div>
#         </a>
#       {{/each}}
#
#   </script>
# </div>
# </div>
# <div data-modal-container=""></div><!-- Paste popup code or third party scripts below this comment line ============== -->
# <!-- And above this comment line ================================================== -->
# <div class="shopify-block shopify-app-block" id="shopify-block-9278379683843197553"></div><div class="shopify-block shopify-app-block" id="shopify-block-1513253815146976218">
# </div>
# </body>

# %%
top_text = top_soup.find_all('div', {'class':'product__grid__info'})

# %%
# get partial product url

top_links = []

for a in top_text:
    anchor_tag = a.find('a')
    if anchor_tag:
        link = anchor_tag.get('href')
        top_links.append(link)

# %%
# get full url

top_links_list = []

for i in range(len(top_links)):
    rel_url = top_links[i]
    full_url = urljoin('https://grayestudio.com', rel_url)
    top_links_list.append(full_url)

# %%
# get product name

for url in top_links_list:
    t_url = url
    t_res = requests.get(t_url)
    t_soup = BeautifulSoup(t_res.content, 'lxml')

    product_text = t_soup.find('h1', {'class':'product__title heading-size-8'}).text.strip() 
    product.append(product_text)

# %%
# get material composition

for url in top_links_list:
    t_url = url
    t_res = requests.get(t_url)
    t_soup = BeautifulSoup(t_res.content, 'lxml')

    for a in t_soup.find_all('div', {'class':'tab-content tab-content-1'}):
        anchor_tag = a.find('span', {'class':'metafield-multi_line_text_field'} )
        if anchor_tag:
            text = anchor_tag.text.strip()
            material.append(text)

# %%
# get care instructions

for url in top_links_list:
    t_url = url
    t_res = requests.get(t_url)
    t_soup = BeautifulSoup(t_res.content, 'lxml')

    for a in t_soup.find_all('div', {'class':'tab-content tab-content-4'}):
        anchor_tag = a.find('span', {'class':'metafield-multi_line_text_field'} )
        if anchor_tag:
            text = anchor_tag.text.strip()
            wash_care.append(text)

# %% [markdown]
# ### Get urls for outerwear products

# %%
# check requests

ow_url = 'https://grayestudio.com/collections/outerwears'
ow_res = requests.get(ow_url)
ow_res.status_code
# Out:
# 200

# %%
# check scraped text

ow_soup = BeautifulSoup(ow_res.content, 'lxml')
ow_soup.body
# Out:
# <body><div class="edit_popup" style="display: none;">
# <form class="edit_form" data-action="/cart/add" enctype="multipart/form-data" id="edit_cart_popup" method="post">
# </form>
# </div><!-- END app snippet --><!-- END app app block --><script defer="defer" src="https://cdn.shopify.com/extensions/0dc675f6-6451-4e34-ac60-441d0df6340d/5.38.0/assets/hulkcode.js" type="text/javascript"></script>
# <link href="https://cdn.shopify.com/extensions/0dc675f6-6451-4e34-ac60-441d0df6340d/5.38.0/assets/hulkcode.css" media="all" rel="stylesheet" type="text/css"/>
# <script defer="defer" src="https://cdn.shopify.com/extensions/4ab84696-81cc-4661-9fb4-2578a25bce95/0.94.0/assets/appointo_bundle.js" type="text/javascript"></script>
# <script defer="defer" src="https://cdn.shopify.com/extensions/07fd1ccd-f05b-4d31-94d4-a07a2e88cdad/0.4.0/assets/omnisend-in-shop.js" type="text/javascript"></script>
# <link href="https://monorail-edge.shopifysvc.com" rel="dns-prefetch"/>
# <script>(function(){if ("sendBeacon" in navigator && "performance" in window) {var session_token = document.cookie.match(/_shopify_s=([^;]*)/);function handle_abandonment_event(e) {var entries = performance.getEntries().filter(function(entry) {return /monorail-edge.shopifysvc.com/.test(entry.name);});if (!window.abandonment_tracked && entries.length === 0) {window.abandonment_tracked = true;var currentMs = Date.now();var navigation_start = performance.timing.navigationStart;var payload = {shop_id: 14141076,url: window.location.href,navigation_start,duration: currentMs - navigation_start,session_token: session_token && session_token.length === 2 ? session_token[1] : "",page_type: "collection"};window.navigator.sendBeacon("https://monorail-edge.shopifysvc.com/v1/produce", JSON.stringify({schema_id: "online_store_buyer_site_abandonment/1.1",payload: payload,metadata: {event_created_at_ms: currentMs,event_sent_at_ms: currentMs}}));}}window.addEventListener('pagehide', handle_abandonment_event);}}());</script>
# <script id="web-pixels-manager-setup">(function e(e,n,a,o,t,r,i){function s(e,n){if(document.head){var a=document.createElement("link");e.match(/spin\.dev\/?/)&&(e+="?fast_storefront_renderer=1"),a.rel="preload",a.href=e,n&&(a.as=n);try{document.head.appendChild(a)}catch(e){console&&console.warn&&console.warn("[Web Pixels Manager] Could not append prefetch link tag to DOM.")}}}var l=i||[],d=null!==e;d&&(window.Shopify=window.Shopify||{},window.Shopify.analytics=window.Shopify.analytics||{},window.Shopify.analytics.replayQueue=[],window.Shopify.analytics.publish=function(e,n,a){window.Shopify.analytics.replayQueue.push([e,n,a])});var c=function(){var e="legacy",n="unknown",a=null,o=navigator.userAgent.match(/(Firefox|Chrome)\/(\d+)/i),t=navigator.userAgent.match(/(Edg)\/(\d+)/i),r=navigator.userAgent.match(/(Version)\/(\d+)(.+)(Safari)\/(\d+)/i);r?(n="safari",a=parseInt(r[2],10)):t?(n="edge",a=parseInt(t[2],10)):o&&(n=o[1].toLocaleLowerCase(),a=parseInt(o[2],10));var i={chrome:60,firefox:55,safari:11,edge:80}[n];return void 0!==i&&null!==a&&i<=a&&(e="modern"),e}(),p=c.substring(0,1),f=o.substring(0,1);if(d)try{self.performance.mark("wpm:start")}catch(e){}if(d){var u=self.location.origin,w=(e.webPixelsConfigList||[]).filter((function(e){return"app"===e.type.toLowerCase()}));for(let e=0;e<w.length;e++){s([u,"/wpm@",r,"/web-pixel-",w[e].id,"@",w[e].scriptVersion,"/sandbox/worker.",c,".js"].join(""),"script")}}var h,y,m,g,v,b,_,S,x=[a,"/wpm","/",f,r,p,".js"].join("");h={src:x,async:!0,onload:function(){if(e){var a=window.webPixelsManager.init(e);n(a),window.Shopify.analytics.replayQueue.forEach((function(e){a.publishCustomEvent(e[0],e[1],e[2])})),window.Shopify.analytics.replayQueue=[],window.Shopify.analytics.publish=a.publishCustomEvent,l.indexOf("web_pixels_visitor_api")>-1&&(window.Shopify.analytics.visitor=a.visitor)}},onerror:function(){var n=(e.storefrontBaseUrl?e.storefrontBaseUrl.replace(/\/$/,""):self.location.origin)+"/.well-known/shopify/monorail/unstable/produce_batch",a=JSON.stringify({metadata:{event_sent_at_ms:(new Date).getTime()},events:[{schema_id:"web_pixels_manager_load/2.0",payload:{version:t||"latest",page_url:self.location.href,status:"failed",error_msg:x+" has failed to load"},metadata:{event_created_at_ms:(new Date).getTime()}}]});try{if(self.navigator.sendBeacon.bind(self.navigator)(n,a))return!0}catch(e){}const o=new XMLHttpRequest;try{return o.open("POST",n,!0),o.setRequestHeader("Content-Type","text/plain"),o.send(a),!0}catch(e){console&&console.warn&&console.warn("[Web Pixels Manager] Got an unhandled error while logging a load error.")}return!1}},y=document.createElement("script"),m=h.src,g=h.async||!0,v=h.onload,b=h.onerror,_=document.head,S=document.body,y.async=g,y.src=m,v&&y.addEventListener("load",v),b&&y.addEventListener("error",b),_?_.appendChild(y):S?S.appendChild(y):console.error("Did not find a head or body element to append the script")})({shopId: 14141076,storefrontBaseUrl: "https://grayestudio.com",cdnBaseUrl: "https://grayestudio.com/cdn",surface: "storefront-renderer",enabledBetaFlags: ["web_pixels_async_pixel_refactor"],webPixelsConfigList: [{"id":"51183930","configuration":"{\"pixelCode\":\"CAJF0PRC77U28261QING\"}","eventPayloadVersion":"v1","runtimeContext":"STRICT","scriptVersion":"0.1.0-99c70b3e91db3b02f187f0b0b5db3b0a","type":"APP","apiClientId":4383523},{"id":"shopify-app-pixel","configuration":"{}","eventPayloadVersion":"v1","runtimeContext":"STRICT","scriptVersion":"0559","apiClientId":"shopify-pixel","type":"APP"},{"id":"shopify-custom-pixel","eventPayloadVersion":"v1","runtimeContext":"LAX","scriptVersion":"0559","apiClientId":"shopify-pixel","type":"CUSTOM"}],initData: {"cart":null,"checkout":null,"customer":null,"productVariants":[]},},function pageEvents(webPixelsManagerAPI) {webPixelsManagerAPI.publish("page_viewed");webPixelsManagerAPI.publish("collection_viewed", {"collection":{"id":"109948141656","title":"Outerwear","productVariants":[{"id":"45327849128250","image":{" ...
# window.ShopifyAnalytics.meta = window.ShopifyAnalytics.meta || {};
# window.ShopifyAnalytics.meta.currency = 'SGD';
# var meta = {"products":[{"id":8335445295418,"gid":"gid:\/\/shopify\/Product\/8335445295418","vendor":"G R A Y E","type":"Outerwear","variants":[{"id":45327849128250,"price":13900,"name":"High Collar Shān - White - SMALL","public_title":"SMALL","sku":"23T02W-S"},{"id":45327849161018,"price":13900,"name":"High Collar Shān - White - MEDIUM","public_title":"MEDIUM","sku":"23T02W-M"},{"id":45327849193786,"price":13900,"name":"High Collar Shān - White - LARGE","public_title":"LARGE","sku":"23T02W-L"},{"id":45327849226554,"price":13900,"name":"High Collar Shān - White - EXTRA LARGE","public_title":"EXTRA LARGE","sku":"23T02W-XL"}]},{"id":8335445655866,"gid":"gid:\/\/shopify\/Product\/8335445655866","vendor":"G R A Y E","type":"Outerwear","variants":[{"id":45327852175674,"price":13900,"name":"High Collar Shān - Duo-toned Sand - SMALL","public_title":"SMALL","sku":"23T02BE-S"},{"id":45327852208442,"price":13900,"name":"High Collar Shān - Duo-toned Sand - MEDIUM","public_title":"MEDIUM","sku":"23T02BE-M"},{"id":45327852241210,"price":13900,"name":"High Collar Shān - Duo-toned Sand - LARGE","public_title":"LARGE","sku":"23T02BE-L"},{"id":45327852273978,"price":13900,"name":"High Collar Shān - Duo-toned Sand - EXTRA LARGE","public_title":"EXTRA LARGE","sku":"23T02BE-XL"}]},{"id":2085975523416,"gid":"gid:\/\/shopify\/Product\/2085975523416","vendor":"GRAYE","type":"Outerwear","variants":[{"id":20524712656984,"price":14900,"name":"Wrapped Button Kimono - SMALL","public_title":"SMALL","sku":"23J02B-S"},{"id":20524712689752,"price":14900,"name":"Wrapped Button Kimono - MEDIUM","public_title":"MEDIUM","sku":"23J02B-M"},{"id":20524712722520,"price":14900,"name":"Wrapped Button Kimono - LARGE","public_title":"LARGE","sku":"23J02B-L"},{"id":20524712755288,"price":14900,"name":"Wrapped Button Kimono - EXTRA LARGE","public_title":"EXTRA LARGE","sku":"23J02B-XL"}]},{"id":8127972081978,"gid":"gid:\/\/shopify\/Product\/8127972081978","vendor":"G R A Y E","type":"Jacket","variants":[{"id":44467208487226,"price":17900,"name":"Utility Blazer with Hood - Khaki - Small","public_title":"Small","sku":"23J01K-S"},{"id":44467208519994,"price":17900,"name":"Utility Blazer with Hood - Khaki - Medium","public_title":"Medium","sku":"23J01K-M"},{"id":44467208552762,"price":17900,"name":"Utility Blazer with Hood - Khaki - Large","public_title":"Large","sku":"23J01K-L"},{"id":44467208585530,"price":17900,"name":"Utility Blazer with Hood - Khaki - Extra Large","public_title":"Extra Large","sku":"23J01K-XL"}]},{"id":8127972213050,"gid":"gid:\/\/shopify\/Product\/8127972213050","vendor":"G R A Y E","type":"Jacket","variants":[{"id":44467208716602,"price":17900,"name":"Utility Blazer with Hood - Black - Small","public_title":"Small","sku":"23J01B-S"},{"id":44467208749370,"price":17900,"name":"Utility Blazer with Hood - Black - Medium","public_title":"Medium","sku":"23J01B-M"},{"id":44467208782138,"price":17900,"name":"Utility Blazer with Hood - Black - Large","public_title":"Large","sku":"23J01B-L"},{"id":44467208814906,"price":17900,"name":"Utility Blazer with Hood - Black - Extra Large","public_title":"Extra Large","sku":"23J01B-XL"}]},{"id":8043442078010,"gid":"gid:\/\/shopify\/Product\/8043442078010","vendor":"G R A Y E","type":"Outerwear","variants":[{"id":44135085474106,"price":18900,"name":"Utility Workwear Jacket - Small","public_title":"Small","sku":"22J01BL-S"},{"id":44135085506874,"price":18900,"name":"Utility Workwear Jacket - Medium","public_title":"Medium","sku":"22J01BL-M"},{"id":44135085539642,"price":18900,"name":"Utility Workwear Jacket - Large","public_title":"Large","sku":"22J01BL-L"},{"id":44135085572410,"price":18900,"name":"Utility Workwear Jacket - Extra Large","public_title":"Extra Large","sku":"22J01BL-XL"}]},{"id":4524094357592,"gid":"gid:\/\/shopify\/Product\/4524094357592","vendor":"G R A Y E","type":"Outerwear","variants":[{"id":33071184347224,"price":21500,"name":"Stark Kimono Coat - Black - SMALL","public_title":"SMALL","sku":"19J05B-S"},{ ...
# for (var attr in meta) {
#   window.ShopifyAnalytics.meta[attr] = meta[attr];
# }</script>
# <script>window.ShopifyAnalytics.merchantGoogleAnalytics = function() {
#
# };
# </script>
# <script class="analytics">(window.gaDevIds=window.gaDevIds||[]).push('BwiEti');
#
#
# (function () {
#     var customDocumentWrite = function(content) {
#       var jquery = null;
#
#       if (window.jQuery) {
#         jquery = window.jQuery;
#       } else if (window.Checkout && window.Checkout.$) {
#         jquery = window.Checkout.$;
#       }
#
#       if (jquery) {
#         jquery('body').append(content);
#       }
#     };
#
#     var hasLoggedConversion = function(token) {
#       if (token) {
#         return document.cookie.indexOf('loggedConversion=' + token) !== -1;
#       }
#       return false;
#     }
#
#     var setCookieIfConversion = function(token) {
#       if (token) {
#         var twoMonthsFromNow = new Date(Date.now());
#         twoMonthsFromNow.setMonth(twoMonthsFromNow.getMonth() + 2);
#
#         document.cookie = 'loggedConversion=' + token + '; expires=' + twoMonthsFromNow;
#       }
#     }
#
#     var trekkie = window.ShopifyAnalytics.lib = window.trekkie = window.trekkie || [];
#     if (trekkie.integrations) {
#       return;
#     }
#     trekkie.methods = [
#       'identify',
#       'page',
#       'ready',
#       'track',
#       'trackForm',
#       'trackLink'
#     ];
#     trekkie.factory = function(method) {
#       return function() {
#         var args = Array.prototype.slice.call(arguments);
#         args.unshift(method);
#         trekkie.push(args);
#         return trekkie;
#       };
#     };
#     for (var i = 0; i < trekkie.methods.length; i++) {
#       var key = trekkie.methods[i];
#       trekkie[key] = trekkie.factory(key);
#     }
#     trekkie.load = function(config) {
#       trekkie.config = config || {};
#       trekkie.config.initialDocumentCookie = document.cookie;
#       var first = document.getElementsByTagName('script')[0];
#       var script = document.createElement('script');
#       script.type = 'text/javascript';
#       script.onerror = function(e) {
#         var scriptFallback = document.createElement('script');
#         scriptFallback.type = 'text/javascript';
#         scriptFallback.onerror = function(error) {
#                 var Monorail = {
#       produce: function produce(monorailDomain, schemaId, payload) {
#         var currentMs = new Date().getTime();
#         var event = {
#           schema_id: schemaId,
#           payload: payload,
#           metadata: {
#             event_created_at_ms: currentMs,
#             event_sent_at_ms: currentMs
#           }
#         };
#         return Monorail.sendRequest("https://" + monorailDomain + "/v1/produce", JSON.stringify(event));
#       },
#       sendRequest: function sendRequest(endpointUrl, payload) {
#         // Try the sendBeacon API
#         if (window && window.navigator && typeof window.navigator.sendBeacon === 'function' && typeof window.Blob === 'function' && !Monorail.isIos12()) {
#           var blobData = new window.Blob([payload], {
#             type: 'text/plain'
#           });
#
#           if (window.navigator.sendBeacon(endpointUrl, blobData)) {
#             return true;
#           } // sendBeacon was not successful
#
#         } // XHR beacon
#
#         var xhr = new XMLHttpRequest();
#
#         try {
#           xhr.open('POST', endpointUrl);
#           xhr.setRequestHeader('Content-Type', 'text/plain');
#           xhr.send(payload);
#         } catch (e) {
#           console.log(e);
#         }
#
#         return false;
#       },
#       isIos12: function isIos12() {
#         return window.navigator.userAgent.lastIndexOf('iPhone; CPU iPhone OS 12_') !== -1 || window.navigator.userAgent.lastIndexOf('iPad; CPU OS 12_') !== -1;
#       }
#     };
#     Monorail.produce('monorail-edge.shopifysvc.com',
#       'trekkie_storefront_load_errors/1.1',
#       {shop_id: 14141076,
#       theme_id: 159228363066,
#       app_name: "storefront",
#       context_url: window.location.href,
#       source_url: "//grayestudio.com/cdn/s/trekkie.storefront.3838335172bb3eee0c7f8320cb9d78b9a94cf814.min.js"});
#
#         };
#         scriptFallback.async = true;
#         scriptFallback.src = '//grayestudio.com/cdn/s/trekkie.storefront.3838335172bb3eee0c7f8320cb9d78b9a94cf814.min.js';
#         first.parentNode.insertBefore(scriptFallback, first);
#       };
#       script.async = true;
#       script.src = '//grayestudio.com/cdn/s/trekkie.storefront.3838335172bb3eee0c7f8320cb9d78b9a94cf814.min.js';
#       first.parentNode.insertBefore(script, first);
#     };
#     trekkie.load(
#       {"Trekkie":{"appName":"storefront","development":false,"defaultAttributes":{"shopId":14141076,"isMerchantRequest":null,"themeId":159228363066,"themeCityHash":"8037124266340387688","contentLanguage":"en","currency":"SGD"},"isServerSideCookieWritingEnabled":true,"monorailRegion":"shop_domain"},"Google Analytics":{"trackingId":"UA-91818857-1","domain":"auto","siteSpeedSampleRate":"10","enhancedEcommerce":true,"doubleClick":true,"includeSearch":true},"Facebook Pixel":{"pixelIds":["210979665975230"],"agent":"plshopify1.2"},"TikTok Pixel":{"pixelId":"CAJF0PRC77U28261QING"},"Google Gtag Pixel":{"conversionId":"AW-863292767","eventLabels":[{"type":"page_view","action_label":"AW-863292767\/kRyOCIzQ__MBEN-a05sD"},{"type":"purchase","action_label":"AW-863292767\/d14LCI_Q__MBEN-a05sD"},{"type":"view_item","action_label":"AW-863292767\/_9SJCIrR__MBEN-a05sD"},{"type":"add_to_cart","action_label":"AW-863292767\/-z8LCI3R__MBEN-a05sD"},{"type":"begin_checkout","action_label":"AW-863292767\/24KiCJDR__MBEN-a05sD"},{"type":"search","action_label":"AW-863292767\/7H8GCJPR__MBEN-a05sD"},{"type":"add_payment_info","action_label":"AW-863292767\/74zlCJbR__MBEN-a05sD"}],"targetCountry":"SG"},"Session Attribution":{},"S2S":{"facebookCapiEnabled":true,"facebookAppPixelId":"210979665975230","source":"trekkie-storefront-renderer"}}
#     );
#
#     var loaded = false;
#     trekkie.ready(function() {
#       if (loaded) return;
#       loaded = true;
#
#       window.ShopifyAnalytics.lib = window.trekkie;
#
#         ga('require', 'linker');
#       function addListener(element, type, callback) {
#         if (element.addEventListener) {
#           element.addEventListener(type, callback);
#         }
#         else if (element.attachEvent) {
#           element.attachEvent('on' + type, callback);
#         }
#       }
#       function decorate(event) {
#         event = event || window.event;
#         var target = event.target || event.srcElement;
#         if (target && (target.getAttribute('action') || target.getAttribute('href'))) {
#           ga(function (tracker) {
#             var linkerParam = tracker.get('linkerParam');
#             document.cookie = '_shopify_ga=' + linkerParam + '; ' + 'path=/';
#           });
#         }
#       }
#       addListener(window, 'load', function(){
#         for (var i=0; i < document.forms.length; i++) {
#           var action = document.forms[i].getAttribute('action');
#           if(action && action.indexOf('/cart') >= 0) {
#             addListener(document.forms[i], 'submit', decorate);
#           }
#         }
#         for (var i=0; i < document.links.length; i++) {
#           var href = document.links[i].getAttribute('href');
#           if(href && href.indexOf('/checkout') >= 0) {
#             addListener(document.links[i], 'click', decorate);
#           }
#         }
#       });
#
#
#       var originalDocumentWrite = document.write;
#       document.write = customDocumentWrite;
#       try { window.ShopifyAnalytics.merchantGoogleAnalytics.call(this); } catch(error) {};
#       document.write = originalDocumentWrite;
#
#       window.ShopifyAnalytics.lib.page(null,{"pageType":"collection","resourceType":"collection","resourceId":109948141656});
#
#       var match = window.location.pathname.match(/checkouts\/(.+)\/(thank_you|post_purchase)/)
#       var token = match? match[1]: undefined;
#       if (!hasLoggedConversion(token)) {
#         setCookieIfConversion(token);
#         window.ShopifyAnalytics.lib.track("Viewed Product Category",{"currency":"SGD","category":"Collection: outerwears","collectionName":"outerwears","collectionId":109948141656,"nonInteraction":true});
#       }
#     });
#
#
#         var eventsListenerScript = document.createElement('script');
#         eventsListenerScript.async = true;
#         eventsListenerScript.src = "//grayestudio.com/cdn/shopifycloud/shopify/assets/shop_events_listener-65cd0ba3fcd81a1df33f2510ec5bcf8c0e0958653b50e3965ec972dd638ee13f.js";
#         document.getElementsByTagName('head')[0].appendChild(eventsListenerScript);
#
# })();</script>
# <script class="boomerang">
# (function () {
#   if (window.BOOMR && (window.BOOMR.version || window.BOOMR.snippetExecuted)) {
#     return;
#   }
#   window.BOOMR = window.BOOMR || {};
#   window.BOOMR.snippetStart = new Date().getTime();
#   window.BOOMR.snippetExecuted = true;
#   window.BOOMR.snippetVersion = 12;
#   window.BOOMR.application = "storefront-renderer";
#   window.BOOMR.themeName = "Pipeline";
#   window.BOOMR.themeVersion = "7.1.2";
#   window.BOOMR.shopId = 14141076;
#   window.BOOMR.themeId = 159228363066;
#   window.BOOMR.renderRegion = "gcp-asia-southeast1";
#   window.BOOMR.url =
#     "https://grayestudio.com/cdn/shopifycloud/boomerang/shopify-boomerang-1.0.0.min.js";
#   var where = document.currentScript || document.getElementsByTagName("script")[0];
#   var parentNode = where.parentNode;
#   var promoted = false;
#   var LOADER_TIMEOUT = 3000;
#   function promote() {
#     if (promoted) {
#       return;
#     }
#     var script = document.createElement("script");
#     script.id = "boomr-scr-as";
#     script.src = window.BOOMR.url;
#     script.async = true;
#     parentNode.appendChild(script);
#     promoted = true;
#   }
#   function iframeLoader(wasFallback) {
#     promoted = true;
#     var dom, bootstrap, iframe, iframeStyle;
#     var doc = document;
#     var win = window;
#     window.BOOMR.snippetMethod = wasFallback ? "if" : "i";
#     bootstrap = function(parent, scriptId) {
#       var script = doc.createElement("script");
#       script.id = scriptId || "boomr-if-as";
#       script.src = window.BOOMR.url;
#       BOOMR_lstart = new Date().getTime();
#       parent = parent || doc.body;
#       parent.appendChild(script);
#     };
#     if (!window.addEventListener && window.attachEvent && navigator.userAgent.match(/MSIE [67]./)) {
#       window.BOOMR.snippetMethod = "s";
#       bootstrap(parentNode, "boomr-async");
#       return;
#     }
#     iframe = document.createElement("IFRAME");
#     iframe.src = "about:blank";
#     iframe.title = "";
#     iframe.role = "presentation";
#     iframe.loading = "eager";
#     iframeStyle = (iframe.frameElement || iframe).style;
#     iframeStyle.width = 0;
#     iframeStyle.height = 0;
#     iframeStyle.border = 0;
#     iframeStyle.display = "none";
#     parentNode.appendChild(iframe);
#     try {
#       win = iframe.contentWindow;
#       doc = win.document.open();
#     } catch (e) {
#       dom = document.domain;
#       iframe.src = "javascript:var d=document.open();d.domain='" + dom + "';void(0);";
#       win = iframe.contentWindow;
#       doc = win.document.open();
#     }
#     if (dom) {
#       doc._boomrl = function() {
#         this.domain = dom;
#         bootstrap();
#       };
#       doc.write("<body onload='document._boomrl();'>");
#     } else {
#       win._boomrl = function() {
#         bootstrap();
#       };
#       if (win.addEventListener) {
#         win.addEventListener("load", win._boomrl, false);
#       } else if (win.attachEvent) {
#         win.attachEvent("onload", win._boomrl);
#       }
#     }
#     doc.close();
#   }
#   var link = document.createElement("link");
#   if (link.relList &&
#     typeof link.relList.supports === "function" &&
#     link.relList.supports("preload") &&
#     ("as" in link)) {
#     window.BOOMR.snippetMethod = "p";
#     link.href = window.BOOMR.url;
#     link.rel = "preload";
#     link.as = "script";
#     link.addEventListener("load", promote);
#     link.addEventListener("error", function() {
#       iframeLoader(true);
#     });
#     setTimeout(function() {
#       if (!promoted) {
#         iframeLoader(true);
#       }
#     }, LOADER_TIMEOUT);
#     BOOMR_lstart = new Date().getTime();
#     parentNode.appendChild(link);
#   } else {
#     iframeLoader(false);
#   }
#   function boomerangSaveLoadTime(e) {
#     window.BOOMR_onload = (e && e.timeStamp) || new Date().getTime();
#   }
#   if (window.addEventListener) {
#     window.addEventListener("load", boomerangSaveLoadTime, false);
#   } else if (window.attachEvent) {
#     window.attachEvent("onload", boomerangSaveLoadTime);
#   }
#   if (document.addEventListener) {
#     document.addEventListener("onBoomerangLoaded", function(e) {
#       e.detail.BOOMR.init({
#         ResourceTiming: {
#           enabled: true,
#           trackedResourceTypes: ["script", "img", "css"]
#         },
#       });
#       e.detail.BOOMR.t_end = new Date().getTime();
#     });
#   } else if (document.attachEvent) {
#     document.attachEvent("onpropertychange", function(e) {
#       if (!e) e=event;
#       if (e.propertyName === "onBoomerangLoaded") {
#         e.detail.BOOMR.init({
#           ResourceTiming: {
#             enabled: true,
#             trackedResourceTypes: ["script", "img", "css"]
#           },
#         });
#         e.detail.BOOMR.t_end = new Date().getTime();
#       }
#     });
#   }
# })();</script>
# <a class="in-page-link visually-hidden skip-link" href="#MainContent">Skip to content</a>
# <!-- BEGIN sections: group-header -->
# <div class="shopify-section shopify-section-group-group-header" id="shopify-section-sections--20875830395194__announcement"><!-- /sections/announcement.liquid -->
# </div><div class="shopify-section shopify-section-group-group-header" id="shopify-section-sections--20875830395194__header"><!-- /sections/header.liquid --><style data-shopify="">
#   :root {
#     --COLOR-NAV-TEXT-TRANSPARENT: #f8f6f2;
#     --COLOR-HEADER-TRANSPARENT-GRADIENT: rgba(0, 0, 0, 0.2);
#     --LOGO-PADDING: 15px;
#     --menu-backfill-height: auto;
#   }
# </style>
# <div class="header__wrapper" data-header-sticky="directional" data-header-style="split" data-header-transparent="true" data-header-wrapper="" data-section-id="sections--20875830395194__header" data-section-type="header" data-underline-current="false" style="--bar-opacity: 0; --bar-width: 0; --bar-left: 0;">
# <header class="theme__header" data-header-height="">
# <div class="header__inner">
# <div class="wrapper">
# <div class="header__mobile">
# <div class="header__mobile__left">
# <button aria-controls="header-menu" aria-expanded="false" aria-haspopup="true" aria-label="Open menu" class="header__mobile__button" data-drawer-toggle="hamburger">
# <svg aria-hidden="true" class="icon icon-nav" focusable="false" role="presentation" viewbox="0 0 25 25"><path d="M0 4.062h25v2H0zm0 7h25v2H0zm0 7h25v2H0z"></path></svg>
# </button>
# </div>
# <div class="header__logo header__logo--image">
# <a class="header__logo__link" href="/" style="--LOGO-WIDTH: 30px">
# <img alt="G R A Y E" class="logo__img logo__img--color" height="30" loading="eager" src="//grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=30" srcset="
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=60 2x,
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=90 3x,
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=30
#         " width="30"/>
# </a>
# </div>
# <div class="header__mobile__right">
# <a class="header__mobile__button" data-drawer-toggle="drawer-cart" href="/cart">
# <svg aria-hidden="true" class="icon icon-cart" focusable="false" role="presentation" viewbox="0 0 25 25"><path d="M5.058 23a2 2 0 1 0 4.001-.001A2 2 0 0 0 5.058 23zm12.079 0c0 1.104.896 2 2 2s1.942-.896 1.942-2-.838-2-1.942-2-2 .896-2 2zM0 1a1 1 0 0 0 1 1h1.078l.894 3.341L5.058 13c0 .072.034.134.042.204l-1.018 4.58A.997.997 0 0 0 5.058 19h16.71a1 1 0 0 0 0-2H6.306l.458-2.061c.1.017.19.061.294.061h12.31c1.104 0 1.712-.218 2.244-1.5l3.248-6.964C25.423 4.75 24.186 4 23.079 4H5.058c-.157 0-.292.054-.438.088L3.844.772A1 1 0 0 0 2.87 0H1a1 1 0 0 0-1 1zm5.098 5H22.93l-3.192 6.798c-.038.086-.07.147-.094.19-.067.006-.113.012-.277.012H7.058v-.198l-.038-.195L5.098 6z"></path></svg>
# <span class="visually-hidden">Cart</span>
# <span class="header__cart__status">
# <span data-header-cart-price="0">
#       $0.00
#     </span>
# <span data-header-cart-count="0">
#       (0)
#     </span>
# <span data-header-cart-full="false"></span>
# </span>
# </a>
# </div>
# </div>
# <div class="header__desktop header__desktop--split" data-header-desktop=""><div class="header__desktop__bar__l" data-takes-space="">
# <div class="header__logo header__logo--image">
# <a class="header__logo__link" href="/" style="--LOGO-WIDTH: 30px">
# <img alt="G R A Y E" class="logo__img logo__img--color" height="30" loading="eager" src="//grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=30" srcset="
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=60 2x,
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=90 3x,
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=30
#         " width="30"/>
# </a>
# </div>
# </div>
# <div class="header__desktop__bar__r" data-takes-space="">
# <div class="header__desktop__bar__inline">
# <nav class="header__menu">
# <div class="header__menu__inner" data-text-items-wrapper="">
# <!-- /snippets/nav-item.liquid -->
# <div aria-controls="dropdown-ac061ab46f04475c307999887d48ca8a" aria-expanded="false" aria-haspopup="true" class="menu__item parent" data-hover-disclosure-toggle="dropdown-ac061ab46f04475c307999887d48ca8a" data-main-menu-text-item="" role="button">
# <a class="navlink navlink--toplevel" data-top-link="" href="/collections/new">
# <span class="navtext">SHOP</span>
# </a>
# <div class="header__dropdown" data-hover-disclosure="" id="dropdown-ac061ab46f04475c307999887d48ca8a">
# <div class="header__dropdown__wrapper">
# <div class="header__dropdown__inner">
# <a class="navlink navlink--child" data-stagger="" href="/collections/new">
# <span class="navtext">NEW IN</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/popular">
# <span class="navtext">POPULAR</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/young">
# <span class="navtext">BABY &amp; KIDS</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/t-shirts">
# <span class="navtext">T-SHIRTS</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/tops">
# <span class="navtext">TOPS</span>
# </a>
# <a class="navlink navlink--child main-menu--active" data-stagger="" href="/collections/outerwears">
# <span class="navtext">OUTERWEAR</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/pants">
# <span class="navtext">BOTTOMS</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/artefact">
# <span class="navtext">ARTEFACT (ACCESSORIES)</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="https://grayestudio.com/products/gift-card?variant=32324020306008">
# <span class="navtext">GIFT CARD</span>
# </a>
# <a class="navlink navlink--child highlight--link" data-stagger="" href="/collections/sale">
# <span class="navtext">SALE</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <!-- /snippets/nav-item.liquid -->
# <div aria-controls="dropdown-154a22647d0d8c8c75bccbc092e8205e" aria-expanded="false" aria-haspopup="true" class="menu__item parent" data-hover-disclosure-toggle="dropdown-154a22647d0d8c8c75bccbc092e8205e" data-main-menu-text-item="" role="button">
# <a class="navlink navlink--toplevel" data-top-link="" href="/pages/about-us">
# <span class="navtext">GRAYE</span>
# </a>
# <div class="header__dropdown" data-hover-disclosure="" id="dropdown-154a22647d0d8c8c75bccbc092e8205e">
# <div class="header__dropdown__wrapper">
# <div class="header__dropdown__inner">
# <a class="navlink navlink--child" data-stagger="" href="/pages/about-us">
# <span class="navtext">ABOUT</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/pages/envision-with-graye">
# <span class="navtext">ENVISION WITH GRAYE</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/pages/garment-care">
# <span class="navtext">GARMENT CARE</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/blogs/news">
# <span class="navtext">JOURNEY</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/workshop">
# <span class="navtext">WORKSHOPS</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/pages/explore-our-stores">
# <span class="navtext">OUR STORES</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <!-- /snippets/nav-item.liquid -->
# <div aria-controls="dropdown-91c0fb17b91c8ef1b62f43a50d46a3fc" aria-expanded="false" aria-haspopup="true" class="menu__item parent" data-hover-disclosure-toggle="dropdown-91c0fb17b91c8ef1b62f43a50d46a3fc" data-main-menu-text-item="" role="button">
# <a class="navlink navlink--toplevel" data-top-link="" href="/collections/young">
# <span class="navtext">YOUNG</span>
# </a>
# <div class="header__dropdown" data-hover-disclosure="" id="dropdown-91c0fb17b91c8ef1b62f43a50d46a3fc">
# <div class="header__dropdown__wrapper">
# <div class="header__dropdown__inner">
# <a class="navlink navlink--child" data-stagger="" href="/pages/young-by-graye">
# <span class="navtext">ABOUT YOUNG</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/pages/onesie-to-tee">
# <span class="navtext">ONESIE TO TEE</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/young">
# <span class="navtext">SHOP YOUNG</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="hover__bar"></div>
# <div class="hover__bg"></div>
# </div>
# </nav>
# <div class="header__desktop__buttons header__desktop__buttons--icons"><div class="header__desktop__button">
# <a class="navlink" href="/account">
# <svg aria-hidden="true" class="icon icon-account" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M10.713 8.771c.31.112.53.191.743.27.555.204.985.372 1.367.539 1.229.535 1.993 1.055 2.418 1.885.464.937.722 1.958.758 2.997.03.84-.662 1.538-1.524 1.538H1.525c-.862 0-1.554-.697-1.524-1.538a7.36 7.36 0 0 1 .767-3.016c.416-.811 1.18-1.33 2.41-1.866a25.25 25.25 0 0 1 1.366-.54l.972-.35a1.42 1.42 0 0 0-.006-.072c-.937-1.086-1.369-2.267-1.369-4.17C4.141 1.756 5.517 0 8.003 0c2.485 0 3.856 1.755 3.856 4.448 0 2.03-.492 3.237-1.563 4.386.169-.18.197-.253.207-.305a1.2 1.2 0 0 0-.019.16l.228.082zm-9.188 5.742h12.95a5.88 5.88 0 0 0-.608-2.402c-.428-.835-2.214-1.414-4.46-2.224-.608-.218-.509-1.765-.24-2.053.631-.677 1.166-1.471 1.166-3.386 0-1.934-.782-2.96-2.33-2.96-1.549 0-2.336 1.026-2.336 2.96 0 1.915.534 2.709 1.165 3.386.27.288.369 1.833-.238 2.053-2.245.81-4.033 1.389-4.462 2.224a5.88 5.88 0 0 0-.607 2.402z"></path></svg>
# <span class="visually-hidden">My Account</span>
# </a>
# </div>
# <div class="header__desktop__button">
# <a class="navlink" data-popdown-toggle="search-popdown" href="/search">
# <svg aria-hidden="true" class="icon icon-search" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M16 14.864 14.863 16l-4.24-4.241a6.406 6.406 0 0 1-4.048 1.392 6.61 6.61 0 0 1-4.65-1.925A6.493 6.493 0 0 1 .5 9.098 6.51 6.51 0 0 1 0 6.575a6.536 6.536 0 0 1 1.922-4.652A6.62 6.62 0 0 1 4.062.5 6.52 6.52 0 0 1 6.575 0 6.5 6.5 0 0 1 9.1.5c.8.332 1.51.806 2.129 1.423a6.454 6.454 0 0 1 1.436 2.13 6.54 6.54 0 0 1 .498 2.522c0 1.503-.468 2.853-1.4 4.048L16 14.864zM3.053 10.091c.973.972 2.147 1.461 3.522 1.461 1.378 0 2.551-.489 3.525-1.461.968-.967 1.45-2.138 1.45-3.514 0-1.37-.482-2.545-1.45-3.524-.981-.968-2.154-1.45-3.525-1.45-1.376 0-2.547.483-3.513 1.45-.973.973-1.46 2.146-1.46 3.523 0 1.375.483 2.548 1.45 3.515z"></path></svg>
# <span class="visually-hidden">Search</span>
# </a>
# </div>
# <div class="header__desktop__button">
# <a class="navlink navlink--cart" data-drawer-toggle="drawer-cart" href="/cart">
# <svg aria-hidden="true" class="icon icon-cart" focusable="false" role="presentation" viewbox="0 0 25 25"><path d="M5.058 23a2 2 0 1 0 4.001-.001A2 2 0 0 0 5.058 23zm12.079 0c0 1.104.896 2 2 2s1.942-.896 1.942-2-.838-2-1.942-2-2 .896-2 2zM0 1a1 1 0 0 0 1 1h1.078l.894 3.341L5.058 13c0 .072.034.134.042.204l-1.018 4.58A.997.997 0 0 0 5.058 19h16.71a1 1 0 0 0 0-2H6.306l.458-2.061c.1.017.19.061.294.061h12.31c1.104 0 1.712-.218 2.244-1.5l3.248-6.964C25.423 4.75 24.186 4 23.079 4H5.058c-.157 0-.292.054-.438.088L3.844.772A1 1 0 0 0 2.87 0H1a1 1 0 0 0-1 1zm5.098 5H22.93l-3.192 6.798c-.038.086-.07.147-.094.19-.067.006-.113.012-.277.012H7.058v-.198l-.038-.195L5.098 6z"></path></svg>
# <span class="visually-hidden">Cart</span>
# <span class="header__cart__status">
# <span data-header-cart-price="0">
#       $0.00
#     </span>
# <span data-header-cart-count="0">
#       (0)
#     </span>
# <span data-header-cart-full="false"></span>
# </span>
# </a>
# </div>
# </div>
# </div>
# </div></div>
# </div>
# </div>
# </header>
# <nav aria-label="Main menu" class="drawer header__drawer display-none" data-drawer="hamburger" id="header-menu">
# <div class="drawer__content">
# <div class="drawer__top">
# <div class="drawer__top__left">
# <a class="drawer__account" href="/account">
# <svg aria-hidden="true" class="icon icon-account" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M10.713 8.771c.31.112.53.191.743.27.555.204.985.372 1.367.539 1.229.535 1.993 1.055 2.418 1.885.464.937.722 1.958.758 2.997.03.84-.662 1.538-1.524 1.538H1.525c-.862 0-1.554-.697-1.524-1.538a7.36 7.36 0 0 1 .767-3.016c.416-.811 1.18-1.33 2.41-1.866a25.25 25.25 0 0 1 1.366-.54l.972-.35a1.42 1.42 0 0 0-.006-.072c-.937-1.086-1.369-2.267-1.369-4.17C4.141 1.756 5.517 0 8.003 0c2.485 0 3.856 1.755 3.856 4.448 0 2.03-.492 3.237-1.563 4.386.169-.18.197-.253.207-.305a1.2 1.2 0 0 0-.019.16l.228.082zm-9.188 5.742h12.95a5.88 5.88 0 0 0-.608-2.402c-.428-.835-2.214-1.414-4.46-2.224-.608-.218-.509-1.765-.24-2.053.631-.677 1.166-1.471 1.166-3.386 0-1.934-.782-2.96-2.33-2.96-1.549 0-2.336 1.026-2.336 2.96 0 1.915.534 2.709 1.165 3.386.27.288.369 1.833-.238 2.053-2.245.81-4.033 1.389-4.462 2.224a5.88 5.88 0 0 0-.607 2.402z"></path></svg>
# <span class="visually-hidden">My Account</span>
# </a></div>
# <button aria-label="Close" class="drawer__button drawer__close" data-drawer-toggle="hamburger">
# <svg aria-hidden="true" class="icon icon-close" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.06 1 12.02 12.021-1.06 1.061L1 2.062z"></path><path d="M1 13.02 13.022 1l1.061 1.06-12.02 12.02z"></path></g></svg>
# </button>
# </div>
# <div class="drawer__inner" data-drawer-scrolls="">
# <div class="drawer__search" data-drawer-search="">
# <!-- /snippets/search-predictive.liquid -->
# <div data-search-popdown-wrap="">
# <div class="search-drawer search__predictive" data-popdown-outer="" id="search-drawer"><predictive-search><form action="/search" method="get" role="search">
# <div class="item--loadbar" data-loading-indicator="" style="display: none;"></div>
# <div class="search__predictive__outer">
# <div class="wrapper">
# <div class="search__predictive__main">
# <div class="search__predictive__actions">
# <button class="search__predictive__button" type="submit">
# <span class="visually-hidden">Search</span>
# <svg aria-hidden="true" class="icon icon-search" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M16 14.864 14.863 16l-4.24-4.241a6.406 6.406 0 0 1-4.048 1.392 6.61 6.61 0 0 1-4.65-1.925A6.493 6.493 0 0 1 .5 9.098 6.51 6.51 0 0 1 0 6.575a6.536 6.536 0 0 1 1.922-4.652A6.62 6.62 0 0 1 4.062.5 6.52 6.52 0 0 1 6.575 0 6.5 6.5 0 0 1 9.1.5c.8.332 1.51.806 2.129 1.423a6.454 6.454 0 0 1 1.436 2.13 6.54 6.54 0 0 1 .498 2.522c0 1.503-.468 2.853-1.4 4.048L16 14.864zM3.053 10.091c.973.972 2.147 1.461 3.522 1.461 1.378 0 2.551-.489 3.525-1.461.968-.967 1.45-2.138 1.45-3.514 0-1.37-.482-2.545-1.45-3.524-.981-.968-2.154-1.45-3.525-1.45-1.376 0-2.547.483-3.513 1.45-.973.973-1.46 2.146-1.46 3.523 0 1.375.483 2.548 1.45 3.515z"></path></svg>
# </button>
# <input aria-controls="predictive-search-results" aria-label="Search our store" data-predictive-search-input="search-popdown-results" name="q" placeholder="Search..." type="search" value=""/>
# <div class="search__predictive__clear">
# <button aria-label="Reset" class="search__predictive__close__inner search-reset is-hidden" type="reset">
# <svg aria-hidden="true" class="icon icon-close" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.06 1 12.02 12.021-1.06 1.061L1 2.062z"></path><path d="M1 13.02 13.022 1l1.061 1.06-12.02 12.02z"></path></g></svg>
# Clear</button>
# </div>
# </div>
# <div class="search__predictive__close">
# <button aria-label="Close" class="search__predictive__close__inner" data-close-popdown="" type="button">
# <svg aria-hidden="true" class="icon icon-close-small" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.237 1.073 12.021 12.021-1.414 1.414L.824 2.488z"></path><path d="m.823 13.094 12.021-12.02 1.414 1.413-12.02 12.021z"></path></g></svg>
# </button>
# </div>
# </div>
# </div>
# </div><div class="header__search__results" data-predictive-search-results="" tabindex="-1"></div>
# <span aria-hidden="true" class="predictive-search-status visually-hidden" data-predictive-search-status="" role="status"></span></form></predictive-search></div>
# <script data-predictive-search-aria-template="" type="text/x-template">
#     <div aria-live="polite">
#       <p>
#
#           {{@if(it.count)}}
#             <span class="badge">{{ it.count }}</span>
#           {{/if}}
#           {{ it.title }} <em>{{ it.query }}</em>
#
#       </p>
#     </div>
#   </script>
# <script data-predictive-search-title-template="" type="text/x-template">
#     <div class="search__results__heading">
#
#         <p>
#           <span class="search__results__title">{{ it.title }}</span>
#           <span class="badge">{{ it.count }}</span>
#         </p>
#
#     </div>
#   </script>
# <script data-search-other-template="" type="text/x-template">
#
#       {{@each(it) => object, index}}
#         <div class="other__inline animates" style="animation-delay: {{ index | animationDelay }}ms;">
#           <p class="other__inline__title">
#             <a href="{{ object.url }}">{{ object.title | safe }}</a>
#           </p>
#         </div>
#       {{/each}}
#
#   </script>
# <script data-search-product-template="" type="text/x-template">
#
#       {{@each(it) => object, index}}
#         <a href="{{ object.url }}" class="product__inline animates" style="animation-delay: {{ index | animationDelay }}ms;">
#           <div class="product__inline__image {{ @if (object.featured_image.width === null) }} product__inline__image--no-image {{ /if}}">
#             {{ @if (object.featured_image.width !== null) }}
#               <img class="img-aspect-ratio" width="{{object.featured_image.width}}" height="{{ object.featured_image.height }}" alt="{{ object.featured_image.alt }}" src="{{ object.thumb }}">
#             {{ /if}}
#           </div>
#           <div>
#             <p class="product__inline__title">
#               {{ object.title | safe }}
#             </p>
#             <p class="product__inline__price">
#               <span class="price {{ object.classes }}">
#                 {{ object.price | safe }}
#               </span>
#               {{@if(object.sold_out)}}
#                 <br /><em>{{ object.sold_out_translation }}</em>
#               {{/if}}
#               {{@if(object.on_sale)}}
#                 <span class="compare-at">
#                   {{ object.compare_at_price | safe }}
#                 </span>
#               {{/if}}
#             </p>
#           </div>
#         </a>
#       {{/each}}
#
#   </script>
# </div>
# </div>
# <div class="drawer__menu" data-sliderule-pane="0" data-stagger-animation="">
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper"><button class="sliderow" data-animates="0" data-sliderule-open="sliderule-df8e1ed0a18e833743bf2a0fd4e0361e">
# <span class="sliderow__title">SHOP</span>
# <span class="sliderule__chevron--right">
# <svg aria-hidden="true" class="icon icon-arrow-medium-right" focusable="false" role="presentation" viewbox="0 0 9 15"><path d="M6.875 7.066.87 1.06 1.93 0l6.006 6.005L7.94 6 9 7.06l-.004.006.005.005-1.06 1.06-.006-.004-6.005 6.005-1.061-1.06 6.005-6.006z" fill-rule="evenodd"></path></svg>
# <span class="visually-hidden">Expand menu</span>
# </span>
# </button>
# <div class="mobile__menu__dropdown sliderule__panel" data-sliderule="" id="sliderule-df8e1ed0a18e833743bf2a0fd4e0361e"><div class="sliderow sliderow__back" data-animates="1">
# <button class="drawer__button" data-sliderule-close="sliderule-df8e1ed0a18e833743bf2a0fd4e0361e">
# <span class="sliderule__chevron--left">
# <svg aria-hidden="true" class="icon icon-arrow-medium-left" focusable="false" role="presentation" viewbox="0 0 9 15"><path d="M2.127 7.066 8.132 1.06 7.072 0 1.065 6.005 1.061 6 0 7.06l.004.006L0 7.07l1.06 1.06.006-.004 6.005 6.005 1.061-1.06-6.005-6.006z" fill-rule="evenodd"></path></svg>
# <span class="visually-hidden">Hide menu</span>
# </span>
# </button>
# <a class="sliderow__title" href="/collections/new">SHOP</a>
# </div><div class="sliderow__links" data-links="">
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/new">NEW IN</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/popular">POPULAR</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/young">BABY &amp; KIDS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/t-shirts">T-SHIRTS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/tops">TOPS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/outerwears">OUTERWEAR</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/pants">BOTTOMS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/artefact">ARTEFACT (ACCESSORIES)</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="https://grayestudio.com/products/gift-card?variant=32324020306008">GIFT CARD</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title highlight--link" href="/collections/sale">SALE</a>
# </div></div>
# </div><div class="sliderule-grid blocks-0">
# </div></div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper"><button class="sliderow" data-animates="0" data-sliderule-open="sliderule-f99a83a8c336d3e3fae3c2ced23b8d7b">
# <span class="sliderow__title">GRAYE</span>
# <span class="sliderule__chevron--right">
# <svg aria-hidden="true" class="icon icon-arrow-medium-right" focusable="false" role="presentation" viewbox="0 0 9 15"><path d="M6.875 7.066.87 1.06 1.93 0l6.006 6.005L7.94 6 9 7.06l-.004.006.005.005-1.06 1.06-.006-.004-6.005 6.005-1.061-1.06 6.005-6.006z" fill-rule="evenodd"></path></svg>
# <span class="visually-hidden">Expand menu</span>
# </span>
# </button>
# <div class="mobile__menu__dropdown sliderule__panel" data-sliderule="" id="sliderule-f99a83a8c336d3e3fae3c2ced23b8d7b"><div class="sliderow sliderow__back" data-animates="1">
# <button class="drawer__button" data-sliderule-close="sliderule-f99a83a8c336d3e3fae3c2ced23b8d7b">
# <span class="sliderule__chevron--left">
# <svg aria-hidden="true" class="icon icon-arrow-medium-left" focusable="false" role="presentation" viewbox="0 0 9 15"><path d="M2.127 7.066 8.132 1.06 7.072 0 1.065 6.005 1.061 6 0 7.06l.004.006L0 7.07l1.06 1.06.006-.004 6.005 6.005 1.061-1.06-6.005-6.006z" fill-rule="evenodd"></path></svg>
# <span class="visually-hidden">Hide menu</span>
# </span>
# </button>
# <a class="sliderow__title" href="/pages/about-us">GRAYE</a>
# </div><div class="sliderow__links" data-links="">
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/pages/about-us">ABOUT</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/pages/envision-with-graye">ENVISION WITH GRAYE</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/pages/garment-care">GARMENT CARE</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/blogs/news">JOURNEY</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/workshop">WORKSHOPS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/pages/explore-our-stores">OUR STORES</a>
# </div></div>
# </div><div class="sliderule-grid blocks-0">
# </div></div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper"><button class="sliderow" data-animates="0" data-sliderule-open="sliderule-975453dbb60e68f2cd134af896b8d431">
# ...
# <h2 class="visually-hidden" id="currency-heading-localization-form-footer">
#     Currency
#   </h2>
# <popout-select>
# <div class="popout" data-popout="">
# <button aria-controls="currency-list-localization-form-footer" aria-describedby="currency-heading-localization-form-footer" aria-expanded="false" class="popout__toggle" data-popout-toggle="" type="button">
#           SGD $<svg aria-hidden="true" class="icon icon--wide icon-arrow-down" focusable="false" role="presentation" viewbox="0 0 30 17"><path d="M0 3.235 3.525 0l11.473 10.509L26.473 0 30 3.235 14.998 17z" fill-rule="evenodd"></path></svg></button>
# <ul class="popout-list" data-popout-list="" id="currency-list-localization-form-footer">
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="AUD" href="#">
# <span>AUD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="BND" href="#">
# <span>BND $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="CAD" href="#">
# <span>CAD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="CHF" href="#">
# <span>CHF CHF</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="CNY" href="#">
# <span>CNY ¥</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="DKK" href="#">
# <span>DKK kr.</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="EUR" href="#">
# <span>EUR €</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="GBP" href="#">
# <span>GBP £</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="HKD" href="#">
# <span>HKD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="IDR" href="#">
# <span>IDR Rp</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="INR" href="#">
# <span>INR ₹</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="ISK" href="#">
# <span>ISK kr</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="JPY" href="#">
# <span>JPY ¥</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="KRW" href="#">
# <span>KRW ₩</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="MOP" href="#">
# <span>MOP P</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="MYR" href="#">
# <span>MYR RM</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="NZD" href="#">
# <span>NZD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="PHP" href="#">
# <span>PHP ₱</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="PLN" href="#">
# <span>PLN zł</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="SEK" href="#">
# <span>SEK kr</span>
# </a>
# </li>
# <li class="popout-list__item popout-list__item--current">
# <a aria-current="true" class="popout-list__option" data-popout-option="" data-value="SGD" href="#">
# <span>SGD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="THB" href="#">
# <span>THB ฿</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="TWD" href="#">
# <span>TWD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="USD" href="#">
# <span>USD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="VND" href="#">
# <span>VND ₫</span>
# </a>
# </li></ul>
# <input data-popout-input="" id="CurrencySelector-localization-form-footer" name="currency_code" type="hidden" value="SGD"/>
# </div>
# </popout-select>
# </div>
# </form><noscript><form accept-charset="UTF-8" action="/localization" class="locale-footer-nojs" enctype="multipart/form-data" id="localization-form-footer-noscript" method="post"><input name="form_type" type="hidden" value="localization"/><input name="utf8" type="hidden" value="✓"/><input name="_method" type="hidden" value="put"/><input name="return_to" type="hidden" value="/collections/outerwears"/><h2 class="visually-hidden" id="localization-form-footer-noscript-locale-heading">
#                   Currency
#                 </h2>
# <select aria-labelledby="localization-form-footer-noscript-currency-heading" name="country_code"><option value="AU">
#                       Australia (AUD
#                       $)
#                     </option><option value="BE">
#                       Belgium (EUR
#                       €)
#                     </option><option value="BN">
#                       Brunei (BND
#                       $)
#                     </option><option value="CA">
#                       Canada (CAD
#                       $)
#                     </option><option value="CN">
#                       China (CNY
#                       ¥)
#                     </option><option value="DK">
#                       Denmark (DKK
#                       kr.)
#                     </option><option value="FI">
#                       Finland (EUR
#                       €)
#                     </option><option value="FR">
#                       France (EUR
#                       €)
#                     </option><option value="DE">
#                       Germany (EUR
#                       €)
#                     </option><option value="HK">
#                       Hong Kong SAR (HKD
#                       $)
#                     </option><option value="IS">
#                       Iceland (ISK
#                       kr)
#                     </option><option value="IN">
#                       India (INR
#                       ₹)
#                     </option><option value="ID">
#                       Indonesia (IDR
#                       Rp)
#                     </option><option value="IE">
#                       Ireland (EUR
#                       €)
#                     </option><option value="IT">
#                       Italy (EUR
#                       €)
#                     </option><option value="JP">
#                       Japan (JPY
#                       ¥)
#                     </option><option value="MO">
#                       Macao SAR (MOP
#                       P)
#                     </option><option value="MY">
#                       Malaysia (MYR
#                       RM)
#                     </option><option value="MC">
#                       Monaco (EUR
#                       €)
#                     </option><option value="NL">
#                       Netherlands (EUR
#                       €)
#                     </option><option value="NZ">
#                       New Zealand (NZD
#                       $)
#                     </option><option value="NO">
#                       Norway (SGD
#                       $)
#                     </option><option value="PH">
#                       Philippines (PHP
#                       ₱)
#                     </option><option value="PL">
#                       Poland (PLN
#                       zł)
#                     </option><option value="PT">
#                       Portugal (EUR
#                       €)
#                     </option><option selected="" value="SG">
#                       Singapore (SGD
#                       $)
#                     </option><option value="KR">
#                       South Korea (KRW
#                       ₩)
#                     </option><option value="ES">
#                       Spain (EUR
#                       €)
#                     </option><option value="SE">
#                       Sweden (SEK
#                       kr)
#                     </option><option value="CH">
#                       Switzerland (CHF
#                       CHF)
#                     </option><option value="TW">
#                       Taiwan (TWD
#                       $)
#                     </option><option value="TH">
#                       Thailand (THB
#                       ฿)
#                     </option><option value="TR">
#                       Turkey (SGD
#                       $)
#                     </option><option value="GB">
#                       United Kingdom (GBP
#                       £)
#                     </option><option value="US">
#                       United States (USD
#                       $)
#                     </option><option value="VN">
#                       Vietnam (VND
#                       ₫)
#                     </option></select><button class="btn btn--primary btn--full">Update</button></form></noscript>
# </div>
# <div class="subfooter__item subfooter__item--copyright">
# <span class="subfooter__copyright"> © <a href="/" title="">G R A Y E</a> 2023 </span>
# <span class="subfooter__copyright"><a href="/pages/about-us">About</a></span>
# <span class="subfooter__copyright"><a href="/pages/contact-us">Contact</a></span>
# <span class="subfooter__copyright"><a href="/pages/delivery-information">Shipping</a></span>
# <span class="subfooter__copyright"><a href="/pages/return-and-exchange">Returns</a></span>
# <span class="subfooter__copyright"><a href="/pages/terms-conditions">Terms</a></span>
# <!-- The following lines fix Lighthouse security warnings on the Shopify link.--><!-- Remove the following line to delete Powered by Shopify from your footer -->
# <span class="subfooter__copyright" data-powered-link=""><a href="https://www.shopify.com?utm_campaign=poweredby&amp;utm_medium=shopify&amp;utm_source=onlinestore" rel="noopener" target="_blank">Powered by Shopify</a></span>
# <!-- Stop deleting here -->
# </div></div>
# </div>
# </section>
# </div>
# <!-- END sections: group-footer -->
# <div class="search--popdown">
# <!-- /snippets/search-predictive.liquid -->
# <div data-search-popdown-wrap="">
# <div class="search-popdown search__predictive" data-popdown-outer="" id="search-popdown"><predictive-search><form action="/search" method="get" role="search">
# <div class="item--loadbar" data-loading-indicator="" style="display: none;"></div>
# <div class="search__predictive__outer">
# <div class="wrapper">
# <div class="search__predictive__main">
# <div class="search__predictive__actions">
# <button class="search__predictive__button" type="submit">
# <span class="visually-hidden">Search</span>
# <svg aria-hidden="true" class="icon icon-search" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M16 14.864 14.863 16l-4.24-4.241a6.406 6.406 0 0 1-4.048 1.392 6.61 6.61 0 0 1-4.65-1.925A6.493 6.493 0 0 1 .5 9.098 6.51 6.51 0 0 1 0 6.575a6.536 6.536 0 0 1 1.922-4.652A6.62 6.62 0 0 1 4.062.5 6.52 6.52 0 0 1 6.575 0 6.5 6.5 0 0 1 9.1.5c.8.332 1.51.806 2.129 1.423a6.454 6.454 0 0 1 1.436 2.13 6.54 6.54 0 0 1 .498 2.522c0 1.503-.468 2.853-1.4 4.048L16 14.864zM3.053 10.091c.973.972 2.147 1.461 3.522 1.461 1.378 0 2.551-.489 3.525-1.461.968-.967 1.45-2.138 1.45-3.514 0-1.37-.482-2.545-1.45-3.524-.981-.968-2.154-1.45-3.525-1.45-1.376 0-2.547.483-3.513 1.45-.973.973-1.46 2.146-1.46 3.523 0 1.375.483 2.548 1.45 3.515z"></path></svg>
# </button>
# <input aria-controls="predictive-search-results" aria-label="Search our store" data-predictive-search-input="search-popdown-results" name="q" placeholder="Search..." type="search" value=""/>
# <div class="search__predictive__clear">
# <button aria-label="Reset" class="search__predictive__close__inner search-reset is-hidden" type="reset">
# <svg aria-hidden="true" class="icon icon-close" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.06 1 12.02 12.021-1.06 1.061L1 2.062z"></path><path d="M1 13.02 13.022 1l1.061 1.06-12.02 12.02z"></path></g></svg>
# Clear</button>
# </div>
# </div>
# <div class="search__predictive__close">
# <button aria-label="Close" class="search__predictive__close__inner" data-close-popdown="" type="button">
# <svg aria-hidden="true" class="icon icon-close-small" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.237 1.073 12.021 12.021-1.414 1.414L.824 2.488z"></path><path d="m.823 13.094 12.021-12.02 1.414 1.413-12.02 12.021z"></path></g></svg>
# </button>
# </div>
# </div>
# </div>
# </div><div class="header__search__results" data-predictive-search-results="" tabindex="-1"></div>
# <span aria-hidden="true" class="predictive-search-status visually-hidden" data-predictive-search-status="" role="status"></span></form></predictive-search></div>
# <span class="drawer__underlay" data-search-underlay=""></span>
# <script data-predictive-search-aria-template="" type="text/x-template">
#     <div aria-live="polite">
#       <p>
#
#           {{@if(it.count)}}
#             <span class="badge">{{ it.count }}</span>
#           {{/if}}
#           {{ it.title }} <em>{{ it.query }}</em>
#
#       </p>
#     </div>
#   </script>
# <script data-predictive-search-title-template="" type="text/x-template">
#     <div class="search__results__heading">
#
#         <p>
#           <span class="search__results__title">{{ it.title }}</span>
#           <span class="badge">{{ it.count }}</span>
#         </p>
#
#     </div>
#   </script>
# <script data-search-other-template="" type="text/x-template">
#
#       {{@each(it) => object, index}}
#         <div class="other__inline animates" style="animation-delay: {{ index | animationDelay }}ms;">
#           <p class="other__inline__title">
#             <a href="{{ object.url }}">{{ object.title | safe }}</a>
#           </p>
#         </div>
#       {{/each}}
#
#   </script>
# <script data-search-product-template="" type="text/x-template">
#
#       {{@each(it) => object, index}}
#         <a href="{{ object.url }}" class="product__inline animates" style="animation-delay: {{ index | animationDelay }}ms;">
#           <div class="product__inline__image {{ @if (object.featured_image.width === null) }} product__inline__image--no-image {{ /if}}">
#             {{ @if (object.featured_image.width !== null) }}
#               <img class="img-aspect-ratio" width="{{object.featured_image.width}}" height="{{ object.featured_image.height }}" alt="{{ object.featured_image.alt }}" src="{{ object.thumb }}">
#             {{ /if}}
#           </div>
#           <div>
#             <p class="product__inline__title">
#               {{ object.title | safe }}
#             </p>
#             <p class="product__inline__price">
#               <span class="price {{ object.classes }}">
#                 {{ object.price | safe }}
#               </span>
#               {{@if(object.sold_out)}}
#                 <br /><em>{{ object.sold_out_translation }}</em>
#               {{/if}}
#               {{@if(object.on_sale)}}
#                 <span class="compare-at">
#                   {{ object.compare_at_price | safe }}
#                 </span>
#               {{/if}}
#             </p>
#           </div>
#         </a>
#       {{/each}}
#
#   </script>
# </div>
# </div>
# <div data-modal-container=""></div><!-- Paste popup code or third party scripts below this comment line ============== -->
# <!-- And above this comment line ================================================== -->
# <div class="shopify-block shopify-app-block" id="shopify-block-9278379683843197553"></div><div class="shopify-block shopify-app-block" id="shopify-block-1513253815146976218">
# </div>
# </body>

# %%
ow_text = ow_soup.find_all('div', {'class':'product__grid__info'})

# %%
# get partial product url

ow_links = []

for a in ow_text:
    anchor_tag = a.find('a')
    if anchor_tag:
        link = anchor_tag.get('href')
        ow_links.append(link)

# %%
# get full url

ow_links_list = []

for i in range(len(ow_links)):
    rel_url = ow_links[i]
    full_url = urljoin('https://grayestudio.com', rel_url)
    ow_links_list.append(full_url)

# %%
# get product name

for url in ow_links_list:
    o_url = url
    o_res = requests.get(o_url)
    o_soup = BeautifulSoup(o_res.content, 'lxml')

    product_text = o_soup.find('h1', {'class':'product__title heading-size-8'}).text.strip() 
    product.append(product_text)

# %%
# get material composition

for url in ow_links_list:
    o_url = url
    o_res = requests.get(o_url)
    o_soup = BeautifulSoup(o_res.content, 'lxml')

    for a in o_soup.find_all('div', {'class':'tab-content tab-content-1'}):
        anchor_tag = a.find('span', {'class':'metafield-multi_line_text_field'} )
        if anchor_tag:
            text = anchor_tag.text.strip()
            material.append(text)

# %%
# get care instructions

for url in ow_links_list:
    o_url = url
    o_res = requests.get(o_url)
    o_soup = BeautifulSoup(o_res.content, 'lxml')

    for a in o_soup.find_all('div', {'class':'tab-content tab-content-4'}):
        anchor_tag = a.find('span', {'class':'metafield-multi_line_text_field'} )
        if anchor_tag:
            text = anchor_tag.text.strip()
            wash_care.append(text)

# %% [markdown]
# ### Get urls for bottoms products

# %%
# check requests

b_url = 'https://grayestudio.com/collections/pants'
b_res = requests.get(b_url)
b_res.status_code
# Out:
# 200

# %%
# check scraped text

b_soup = BeautifulSoup(b_res.content, 'lxml')
b_soup.body
# Out:
# <body><div class="edit_popup" style="display: none;">
# <form class="edit_form" data-action="/cart/add" enctype="multipart/form-data" id="edit_cart_popup" method="post">
# </form>
# </div><!-- END app snippet --><!-- END app app block --><script defer="defer" src="https://cdn.shopify.com/extensions/07fd1ccd-f05b-4d31-94d4-a07a2e88cdad/0.4.0/assets/omnisend-in-shop.js" type="text/javascript"></script>
# <script defer="defer" src="https://cdn.shopify.com/extensions/0dc675f6-6451-4e34-ac60-441d0df6340d/5.38.0/assets/hulkcode.js" type="text/javascript"></script>
# <link href="https://cdn.shopify.com/extensions/0dc675f6-6451-4e34-ac60-441d0df6340d/5.38.0/assets/hulkcode.css" media="all" rel="stylesheet" type="text/css"/>
# <script defer="defer" src="https://cdn.shopify.com/extensions/4ab84696-81cc-4661-9fb4-2578a25bce95/0.94.0/assets/appointo_bundle.js" type="text/javascript"></script>
# <link href="https://monorail-edge.shopifysvc.com" rel="dns-prefetch"/>
# <script>(function(){if ("sendBeacon" in navigator && "performance" in window) {var session_token = document.cookie.match(/_shopify_s=([^;]*)/);function handle_abandonment_event(e) {var entries = performance.getEntries().filter(function(entry) {return /monorail-edge.shopifysvc.com/.test(entry.name);});if (!window.abandonment_tracked && entries.length === 0) {window.abandonment_tracked = true;var currentMs = Date.now();var navigation_start = performance.timing.navigationStart;var payload = {shop_id: 14141076,url: window.location.href,navigation_start,duration: currentMs - navigation_start,session_token: session_token && session_token.length === 2 ? session_token[1] : "",page_type: "collection"};window.navigator.sendBeacon("https://monorail-edge.shopifysvc.com/v1/produce", JSON.stringify({schema_id: "online_store_buyer_site_abandonment/1.1",payload: payload,metadata: {event_created_at_ms: currentMs,event_sent_at_ms: currentMs}}));}}window.addEventListener('pagehide', handle_abandonment_event);}}());</script>
# <script id="web-pixels-manager-setup">(function e(e,n,a,o,t,r,i){function s(e,n){if(document.head){var a=document.createElement("link");e.match(/spin\.dev\/?/)&&(e+="?fast_storefront_renderer=1"),a.rel="preload",a.href=e,n&&(a.as=n);try{document.head.appendChild(a)}catch(e){console&&console.warn&&console.warn("[Web Pixels Manager] Could not append prefetch link tag to DOM.")}}}var l=i||[],d=null!==e;d&&(window.Shopify=window.Shopify||{},window.Shopify.analytics=window.Shopify.analytics||{},window.Shopify.analytics.replayQueue=[],window.Shopify.analytics.publish=function(e,n,a){window.Shopify.analytics.replayQueue.push([e,n,a])});var c=function(){var e="legacy",n="unknown",a=null,o=navigator.userAgent.match(/(Firefox|Chrome)\/(\d+)/i),t=navigator.userAgent.match(/(Edg)\/(\d+)/i),r=navigator.userAgent.match(/(Version)\/(\d+)(.+)(Safari)\/(\d+)/i);r?(n="safari",a=parseInt(r[2],10)):t?(n="edge",a=parseInt(t[2],10)):o&&(n=o[1].toLocaleLowerCase(),a=parseInt(o[2],10));var i={chrome:60,firefox:55,safari:11,edge:80}[n];return void 0!==i&&null!==a&&i<=a&&(e="modern"),e}(),p=c.substring(0,1),f=o.substring(0,1);if(d)try{self.performance.mark("wpm:start")}catch(e){}if(d){var u=self.location.origin,w=(e.webPixelsConfigList||[]).filter((function(e){return"app"===e.type.toLowerCase()}));for(let e=0;e<w.length;e++){s([u,"/wpm@",r,"/web-pixel-",w[e].id,"@",w[e].scriptVersion,"/sandbox/worker.",c,".js"].join(""),"script")}}var h,y,m,g,v,b,_,S,x=[a,"/wpm","/",f,r,p,".js"].join("");h={src:x,async:!0,onload:function(){if(e){var a=window.webPixelsManager.init(e);n(a),window.Shopify.analytics.replayQueue.forEach((function(e){a.publishCustomEvent(e[0],e[1],e[2])})),window.Shopify.analytics.replayQueue=[],window.Shopify.analytics.publish=a.publishCustomEvent,l.indexOf("web_pixels_visitor_api")>-1&&(window.Shopify.analytics.visitor=a.visitor)}},onerror:function(){var n=(e.storefrontBaseUrl?e.storefrontBaseUrl.replace(/\/$/,""):self.location.origin)+"/.well-known/shopify/monorail/unstable/produce_batch",a=JSON.stringify({metadata:{event_sent_at_ms:(new Date).getTime()},events:[{schema_id:"web_pixels_manager_load/2.0",payload:{version:t||"latest",page_url:self.location.href,status:"failed",error_msg:x+" has failed to load"},metadata:{event_created_at_ms:(new Date).getTime()}}]});try{if(self.navigator.sendBeacon.bind(self.navigator)(n,a))return!0}catch(e){}const o=new XMLHttpRequest;try{return o.open("POST",n,!0),o.setRequestHeader("Content-Type","text/plain"),o.send(a),!0}catch(e){console&&console.warn&&console.warn("[Web Pixels Manager] Got an unhandled error while logging a load error.")}return!1}},y=document.createElement("script"),m=h.src,g=h.async||!0,v=h.onload,b=h.onerror,_=document.head,S=document.body,y.async=g,y.src=m,v&&y.addEventListener("load",v),b&&y.addEventListener("error",b),_?_.appendChild(y):S?S.appendChild(y):console.error("Did not find a head or body element to append the script")})({shopId: 14141076,storefrontBaseUrl: "https://grayestudio.com",cdnBaseUrl: "https://grayestudio.com/cdn",surface: "storefront-renderer",enabledBetaFlags: ["web_pixels_async_pixel_refactor"],webPixelsConfigList: [{"id":"51183930","configuration":"{\"pixelCode\":\"CAJF0PRC77U28261QING\"}","eventPayloadVersion":"v1","runtimeContext":"STRICT","scriptVersion":"0.1.0-99c70b3e91db3b02f187f0b0b5db3b0a","type":"APP","apiClientId":4383523},{"id":"shopify-app-pixel","configuration":"{}","eventPayloadVersion":"v1","runtimeContext":"STRICT","scriptVersion":"0559","apiClientId":"shopify-pixel","type":"APP"},{"id":"shopify-custom-pixel","eventPayloadVersion":"v1","runtimeContext":"LAX","scriptVersion":"0559","apiClientId":"shopify-pixel","type":"CUSTOM"}],initData: {"cart":null,"checkout":null,"customer":null,"productVariants":[]},},function pageEvents(webPixelsManagerAPI) {webPixelsManagerAPI.publish("page_viewed");webPixelsManagerAPI.publish("collection_viewed", {"collection":{"id":"109947945048","title":"Bottoms","productVariants":[{"id":"45327811969338","image":{"sr ...
# window.ShopifyAnalytics.meta = window.ShopifyAnalytics.meta || {};
# window.ShopifyAnalytics.meta.currency = 'SGD';
# var meta = {"products":[{"id":8335439855930,"gid":"gid:\/\/shopify\/Product\/8335439855930","vendor":"G R A Y E","type":"Pants","variants":[{"id":45327811969338,"price":15500,"name":"GRAYE Harem Pants - SMALL","public_title":"SMALL","sku":"23B02B-S"},{"id":45327812002106,"price":15500,"name":"GRAYE Harem Pants - MEDIUM","public_title":"MEDIUM","sku":"23B02B-M"},{"id":45327812034874,"price":15500,"name":"GRAYE Harem Pants - LARGE","public_title":"LARGE","sku":"23B02B-L"}]},{"id":8335448670522,"gid":"gid:\/\/shopify\/Product\/8335448670522","vendor":"G R A Y E","type":"Pants","variants":[{"id":45327873016122,"price":13500,"name":"GRAYE Straight Cut Pants - Steel Gray - 26","public_title":"26","sku":"23B03DGR-26"},{"id":45327873048890,"price":13500,"name":"GRAYE Straight Cut Pants - Steel Gray - 28","public_title":"28","sku":"23B03DGR-28"},{"id":45327873081658,"price":13500,"name":"GRAYE Straight Cut Pants - Steel Gray - 30","public_title":"30","sku":"23B03DGR-30"},{"id":45327873147194,"price":13500,"name":"GRAYE Straight Cut Pants - Steel Gray - 32","public_title":"32","sku":"23B03DGR-32"},{"id":45327873212730,"price":13500,"name":"GRAYE Straight Cut Pants - Steel Gray - 34","public_title":"34","sku":"23B03DGR-34"},{"id":45327873278266,"price":13500,"name":"GRAYE Straight Cut Pants - Steel Gray - 36","public_title":"36","sku":"23B03DGR-36"}]},{"id":8335448998202,"gid":"gid:\/\/shopify\/Product\/8335448998202","vendor":"G R A Y E","type":"Pants","variants":[{"id":45327875768634,"price":13500,"name":"GRAYE Straight-Cut Pants - Mauve Gray - 26","public_title":"26","sku":"23B03MGR-26"},{"id":45327875801402,"price":13500,"name":"GRAYE Straight-Cut Pants - Mauve Gray - 28","public_title":"28","sku":"23B03MGR-28"},{"id":45327875834170,"price":13500,"name":"GRAYE Straight-Cut Pants - Mauve Gray - 30","public_title":"30","sku":"23BMGR-30"},{"id":45327875866938,"price":13500,"name":"GRAYE Straight-Cut Pants - Mauve Gray - 32","public_title":"32","sku":"23B03MGR-32"},{"id":45327875899706,"price":13500,"name":"GRAYE Straight-Cut Pants - Mauve Gray - 34","public_title":"34","sku":"23B03MGR-34"},{"id":45327875932474,"price":13500,"name":"GRAYE Straight-Cut Pants - Mauve Gray - 36","public_title":"36","sku":"23B03MGR-36"}]},{"id":8321313112378,"gid":"gid:\/\/shopify\/Product\/8321313112378","vendor":"G R A Y E","type":"Pants","variants":[{"id":45295812673850,"price":14900,"name":"Multi-Pocket Ripstop Pants - Black - 26","public_title":"26","sku":"22B02B-26"},{"id":45273593971002,"price":14900,"name":"Multi-Pocket Ripstop Pants - Black - 28","public_title":"28","sku":"22B02B-28"},{"id":45273594003770,"price":14900,"name":"Multi-Pocket Ripstop Pants - Black - 30","public_title":"30","sku":"22B02B-30"},{"id":45273594036538,"price":14900,"name":"Multi-Pocket Ripstop Pants - Black - 32","public_title":"32","sku":"22B02B-32"},{"id":45273594069306,"price":14900,"name":"Multi-Pocket Ripstop Pants - Black - 34","public_title":"34","sku":"22B02B-34"},{"id":45273594102074,"price":14900,"name":"Multi-Pocket Ripstop Pants - Black - 36","public_title":"36","sku":"22B02B-36"}]},{"id":8321310327098,"gid":"gid:\/\/shopify\/Product\/8321310327098","vendor":"G R A Y E","type":"Pants","variants":[{"id":45295814607162,"price":14900,"name":"Multi-Pocket Ripstop Pants - Light Khaki - 26","public_title":"26","sku":"22B02K-26"},{"id":45273573032250,"price":14900,"name":"Multi-Pocket Ripstop Pants - Light Khaki - 28","public_title":"28","sku":"22B02K-28"},{"id":45273573065018,"price":14900,"name":"Multi-Pocket Ripstop Pants - Light Khaki - 30","public_title":"30","sku":"22B02K-30"},{"id":45273573097786,"price":14900,"name":"Multi-Pocket Ripstop Pants - Light Khaki - 32","public_title":"32","sku":"22B02K-32"},{"id":45273573130554,"price":14900,"name":"Multi-Pocket Ripstop Pants - Light Khaki - 34","public_title":"34","sku":"22B02K-34"},{"id":45273573163322,"price":14900,"name":"Multi-Pocket Ripstop Pants - Light Khaki - 36","public_title":"36","sku":"22B02K-36"}]},{"id" ...
# for (var attr in meta) {
#   window.ShopifyAnalytics.meta[attr] = meta[attr];
# }</script>
# <script>window.ShopifyAnalytics.merchantGoogleAnalytics = function() {
#
# };
# </script>
# <script class="analytics">(window.gaDevIds=window.gaDevIds||[]).push('BwiEti');
#
#
# (function () {
#     var customDocumentWrite = function(content) {
#       var jquery = null;
#
#       if (window.jQuery) {
#         jquery = window.jQuery;
#       } else if (window.Checkout && window.Checkout.$) {
#         jquery = window.Checkout.$;
#       }
#
#       if (jquery) {
#         jquery('body').append(content);
#       }
#     };
#
#     var hasLoggedConversion = function(token) {
#       if (token) {
#         return document.cookie.indexOf('loggedConversion=' + token) !== -1;
#       }
#       return false;
#     }
#
#     var setCookieIfConversion = function(token) {
#       if (token) {
#         var twoMonthsFromNow = new Date(Date.now());
#         twoMonthsFromNow.setMonth(twoMonthsFromNow.getMonth() + 2);
#
#         document.cookie = 'loggedConversion=' + token + '; expires=' + twoMonthsFromNow;
#       }
#     }
#
#     var trekkie = window.ShopifyAnalytics.lib = window.trekkie = window.trekkie || [];
#     if (trekkie.integrations) {
#       return;
#     }
#     trekkie.methods = [
#       'identify',
#       'page',
#       'ready',
#       'track',
#       'trackForm',
#       'trackLink'
#     ];
#     trekkie.factory = function(method) {
#       return function() {
#         var args = Array.prototype.slice.call(arguments);
#         args.unshift(method);
#         trekkie.push(args);
#         return trekkie;
#       };
#     };
#     for (var i = 0; i < trekkie.methods.length; i++) {
#       var key = trekkie.methods[i];
#       trekkie[key] = trekkie.factory(key);
#     }
#     trekkie.load = function(config) {
#       trekkie.config = config || {};
#       trekkie.config.initialDocumentCookie = document.cookie;
#       var first = document.getElementsByTagName('script')[0];
#       var script = document.createElement('script');
#       script.type = 'text/javascript';
#       script.onerror = function(e) {
#         var scriptFallback = document.createElement('script');
#         scriptFallback.type = 'text/javascript';
#         scriptFallback.onerror = function(error) {
#                 var Monorail = {
#       produce: function produce(monorailDomain, schemaId, payload) {
#         var currentMs = new Date().getTime();
#         var event = {
#           schema_id: schemaId,
#           payload: payload,
#           metadata: {
#             event_created_at_ms: currentMs,
#             event_sent_at_ms: currentMs
#           }
#         };
#         return Monorail.sendRequest("https://" + monorailDomain + "/v1/produce", JSON.stringify(event));
#       },
#       sendRequest: function sendRequest(endpointUrl, payload) {
#         // Try the sendBeacon API
#         if (window && window.navigator && typeof window.navigator.sendBeacon === 'function' && typeof window.Blob === 'function' && !Monorail.isIos12()) {
#           var blobData = new window.Blob([payload], {
#             type: 'text/plain'
#           });
#
#           if (window.navigator.sendBeacon(endpointUrl, blobData)) {
#             return true;
#           } // sendBeacon was not successful
#
#         } // XHR beacon
#
#         var xhr = new XMLHttpRequest();
#
#         try {
#           xhr.open('POST', endpointUrl);
#           xhr.setRequestHeader('Content-Type', 'text/plain');
#           xhr.send(payload);
#         } catch (e) {
#           console.log(e);
#         }
#
#         return false;
#       },
#       isIos12: function isIos12() {
#         return window.navigator.userAgent.lastIndexOf('iPhone; CPU iPhone OS 12_') !== -1 || window.navigator.userAgent.lastIndexOf('iPad; CPU OS 12_') !== -1;
#       }
#     };
#     Monorail.produce('monorail-edge.shopifysvc.com',
#       'trekkie_storefront_load_errors/1.1',
#       {shop_id: 14141076,
#       theme_id: 159228363066,
#       app_name: "storefront",
#       context_url: window.location.href,
#       source_url: "//grayestudio.com/cdn/s/trekkie.storefront.3838335172bb3eee0c7f8320cb9d78b9a94cf814.min.js"});
#
#         };
#         scriptFallback.async = true;
#         scriptFallback.src = '//grayestudio.com/cdn/s/trekkie.storefront.3838335172bb3eee0c7f8320cb9d78b9a94cf814.min.js';
#         first.parentNode.insertBefore(scriptFallback, first);
#       };
#       script.async = true;
#       script.src = '//grayestudio.com/cdn/s/trekkie.storefront.3838335172bb3eee0c7f8320cb9d78b9a94cf814.min.js';
#       first.parentNode.insertBefore(script, first);
#     };
#     trekkie.load(
#       {"Trekkie":{"appName":"storefront","development":false,"defaultAttributes":{"shopId":14141076,"isMerchantRequest":null,"themeId":159228363066,"themeCityHash":"8037124266340387688","contentLanguage":"en","currency":"SGD"},"isServerSideCookieWritingEnabled":true,"monorailRegion":"shop_domain"},"Google Analytics":{"trackingId":"UA-91818857-1","domain":"auto","siteSpeedSampleRate":"10","enhancedEcommerce":true,"doubleClick":true,"includeSearch":true},"Facebook Pixel":{"pixelIds":["210979665975230"],"agent":"plshopify1.2"},"TikTok Pixel":{"pixelId":"CAJF0PRC77U28261QING"},"Google Gtag Pixel":{"conversionId":"AW-863292767","eventLabels":[{"type":"page_view","action_label":"AW-863292767\/kRyOCIzQ__MBEN-a05sD"},{"type":"purchase","action_label":"AW-863292767\/d14LCI_Q__MBEN-a05sD"},{"type":"view_item","action_label":"AW-863292767\/_9SJCIrR__MBEN-a05sD"},{"type":"add_to_cart","action_label":"AW-863292767\/-z8LCI3R__MBEN-a05sD"},{"type":"begin_checkout","action_label":"AW-863292767\/24KiCJDR__MBEN-a05sD"},{"type":"search","action_label":"AW-863292767\/7H8GCJPR__MBEN-a05sD"},{"type":"add_payment_info","action_label":"AW-863292767\/74zlCJbR__MBEN-a05sD"}],"targetCountry":"SG"},"Session Attribution":{},"S2S":{"facebookCapiEnabled":true,"facebookAppPixelId":"210979665975230","source":"trekkie-storefront-renderer"}}
#     );
#
#     var loaded = false;
#     trekkie.ready(function() {
#       if (loaded) return;
#       loaded = true;
#
#       window.ShopifyAnalytics.lib = window.trekkie;
#
#         ga('require', 'linker');
#       function addListener(element, type, callback) {
#         if (element.addEventListener) {
#           element.addEventListener(type, callback);
#         }
#         else if (element.attachEvent) {
#           element.attachEvent('on' + type, callback);
#         }
#       }
#       function decorate(event) {
#         event = event || window.event;
#         var target = event.target || event.srcElement;
#         if (target && (target.getAttribute('action') || target.getAttribute('href'))) {
#           ga(function (tracker) {
#             var linkerParam = tracker.get('linkerParam');
#             document.cookie = '_shopify_ga=' + linkerParam + '; ' + 'path=/';
#           });
#         }
#       }
#       addListener(window, 'load', function(){
#         for (var i=0; i < document.forms.length; i++) {
#           var action = document.forms[i].getAttribute('action');
#           if(action && action.indexOf('/cart') >= 0) {
#             addListener(document.forms[i], 'submit', decorate);
#           }
#         }
#         for (var i=0; i < document.links.length; i++) {
#           var href = document.links[i].getAttribute('href');
#           if(href && href.indexOf('/checkout') >= 0) {
#             addListener(document.links[i], 'click', decorate);
#           }
#         }
#       });
#
#
#       var originalDocumentWrite = document.write;
#       document.write = customDocumentWrite;
#       try { window.ShopifyAnalytics.merchantGoogleAnalytics.call(this); } catch(error) {};
#       document.write = originalDocumentWrite;
#
#       window.ShopifyAnalytics.lib.page(null,{"pageType":"collection","resourceType":"collection","resourceId":109947945048});
#
#       var match = window.location.pathname.match(/checkouts\/(.+)\/(thank_you|post_purchase)/)
#       var token = match? match[1]: undefined;
#       if (!hasLoggedConversion(token)) {
#         setCookieIfConversion(token);
#         window.ShopifyAnalytics.lib.track("Viewed Product Category",{"currency":"SGD","category":"Collection: pants","collectionName":"pants","collectionId":109947945048,"nonInteraction":true});
#       }
#     });
#
#
#         var eventsListenerScript = document.createElement('script');
#         eventsListenerScript.async = true;
#         eventsListenerScript.src = "//grayestudio.com/cdn/shopifycloud/shopify/assets/shop_events_listener-65cd0ba3fcd81a1df33f2510ec5bcf8c0e0958653b50e3965ec972dd638ee13f.js";
#         document.getElementsByTagName('head')[0].appendChild(eventsListenerScript);
#
# })();</script>
# <script class="boomerang">
# (function () {
#   if (window.BOOMR && (window.BOOMR.version || window.BOOMR.snippetExecuted)) {
#     return;
#   }
#   window.BOOMR = window.BOOMR || {};
#   window.BOOMR.snippetStart = new Date().getTime();
#   window.BOOMR.snippetExecuted = true;
#   window.BOOMR.snippetVersion = 12;
#   window.BOOMR.application = "storefront-renderer";
#   window.BOOMR.themeName = "Pipeline";
#   window.BOOMR.themeVersion = "7.1.2";
#   window.BOOMR.shopId = 14141076;
#   window.BOOMR.themeId = 159228363066;
#   window.BOOMR.renderRegion = "gcp-asia-southeast1";
#   window.BOOMR.url =
#     "https://grayestudio.com/cdn/shopifycloud/boomerang/shopify-boomerang-1.0.0.min.js";
#   var where = document.currentScript || document.getElementsByTagName("script")[0];
#   var parentNode = where.parentNode;
#   var promoted = false;
#   var LOADER_TIMEOUT = 3000;
#   function promote() {
#     if (promoted) {
#       return;
#     }
#     var script = document.createElement("script");
#     script.id = "boomr-scr-as";
#     script.src = window.BOOMR.url;
#     script.async = true;
#     parentNode.appendChild(script);
#     promoted = true;
#   }
#   function iframeLoader(wasFallback) {
#     promoted = true;
#     var dom, bootstrap, iframe, iframeStyle;
#     var doc = document;
#     var win = window;
#     window.BOOMR.snippetMethod = wasFallback ? "if" : "i";
#     bootstrap = function(parent, scriptId) {
#       var script = doc.createElement("script");
#       script.id = scriptId || "boomr-if-as";
#       script.src = window.BOOMR.url;
#       BOOMR_lstart = new Date().getTime();
#       parent = parent || doc.body;
#       parent.appendChild(script);
#     };
#     if (!window.addEventListener && window.attachEvent && navigator.userAgent.match(/MSIE [67]./)) {
#       window.BOOMR.snippetMethod = "s";
#       bootstrap(parentNode, "boomr-async");
#       return;
#     }
#     iframe = document.createElement("IFRAME");
#     iframe.src = "about:blank";
#     iframe.title = "";
#     iframe.role = "presentation";
#     iframe.loading = "eager";
#     iframeStyle = (iframe.frameElement || iframe).style;
#     iframeStyle.width = 0;
#     iframeStyle.height = 0;
#     iframeStyle.border = 0;
#     iframeStyle.display = "none";
#     parentNode.appendChild(iframe);
#     try {
#       win = iframe.contentWindow;
#       doc = win.document.open();
#     } catch (e) {
#       dom = document.domain;
#       iframe.src = "javascript:var d=document.open();d.domain='" + dom + "';void(0);";
#       win = iframe.contentWindow;
#       doc = win.document.open();
#     }
#     if (dom) {
#       doc._boomrl = function() {
#         this.domain = dom;
#         bootstrap();
#       };
#       doc.write("<body onload='document._boomrl();'>");
#     } else {
#       win._boomrl = function() {
#         bootstrap();
#       };
#       if (win.addEventListener) {
#         win.addEventListener("load", win._boomrl, false);
#       } else if (win.attachEvent) {
#         win.attachEvent("onload", win._boomrl);
#       }
#     }
#     doc.close();
#   }
#   var link = document.createElement("link");
#   if (link.relList &&
#     typeof link.relList.supports === "function" &&
#     link.relList.supports("preload") &&
#     ("as" in link)) {
#     window.BOOMR.snippetMethod = "p";
#     link.href = window.BOOMR.url;
#     link.rel = "preload";
#     link.as = "script";
#     link.addEventListener("load", promote);
#     link.addEventListener("error", function() {
#       iframeLoader(true);
#     });
#     setTimeout(function() {
#       if (!promoted) {
#         iframeLoader(true);
#       }
#     }, LOADER_TIMEOUT);
#     BOOMR_lstart = new Date().getTime();
#     parentNode.appendChild(link);
#   } else {
#     iframeLoader(false);
#   }
#   function boomerangSaveLoadTime(e) {
#     window.BOOMR_onload = (e && e.timeStamp) || new Date().getTime();
#   }
#   if (window.addEventListener) {
#     window.addEventListener("load", boomerangSaveLoadTime, false);
#   } else if (window.attachEvent) {
#     window.attachEvent("onload", boomerangSaveLoadTime);
#   }
#   if (document.addEventListener) {
#     document.addEventListener("onBoomerangLoaded", function(e) {
#       e.detail.BOOMR.init({
#         ResourceTiming: {
#           enabled: true,
#           trackedResourceTypes: ["script", "img", "css"]
#         },
#       });
#       e.detail.BOOMR.t_end = new Date().getTime();
#     });
#   } else if (document.attachEvent) {
#     document.attachEvent("onpropertychange", function(e) {
#       if (!e) e=event;
#       if (e.propertyName === "onBoomerangLoaded") {
#         e.detail.BOOMR.init({
#           ResourceTiming: {
#             enabled: true,
#             trackedResourceTypes: ["script", "img", "css"]
#           },
#         });
#         e.detail.BOOMR.t_end = new Date().getTime();
#       }
#     });
#   }
# })();</script>
# <a class="in-page-link visually-hidden skip-link" href="#MainContent">Skip to content</a>
# <!-- BEGIN sections: group-header -->
# <div class="shopify-section shopify-section-group-group-header" id="shopify-section-sections--20875830395194__announcement"><!-- /sections/announcement.liquid -->
# </div><div class="shopify-section shopify-section-group-group-header" id="shopify-section-sections--20875830395194__header"><!-- /sections/header.liquid --><style data-shopify="">
#   :root {
#     --COLOR-NAV-TEXT-TRANSPARENT: #f8f6f2;
#     --COLOR-HEADER-TRANSPARENT-GRADIENT: rgba(0, 0, 0, 0.2);
#     --LOGO-PADDING: 15px;
#     --menu-backfill-height: auto;
#   }
# </style>
# <div class="header__wrapper" data-header-sticky="directional" data-header-style="split" data-header-transparent="true" data-header-wrapper="" data-section-id="sections--20875830395194__header" data-section-type="header" data-underline-current="false" style="--bar-opacity: 0; --bar-width: 0; --bar-left: 0;">
# <header class="theme__header" data-header-height="">
# <div class="header__inner">
# <div class="wrapper">
# <div class="header__mobile">
# <div class="header__mobile__left">
# <button aria-controls="header-menu" aria-expanded="false" aria-haspopup="true" aria-label="Open menu" class="header__mobile__button" data-drawer-toggle="hamburger">
# <svg aria-hidden="true" class="icon icon-nav" focusable="false" role="presentation" viewbox="0 0 25 25"><path d="M0 4.062h25v2H0zm0 7h25v2H0zm0 7h25v2H0z"></path></svg>
# </button>
# </div>
# <div class="header__logo header__logo--image">
# <a class="header__logo__link" href="/" style="--LOGO-WIDTH: 30px">
# <img alt="G R A Y E" class="logo__img logo__img--color" height="30" loading="eager" src="//grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=30" srcset="
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=60 2x,
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=90 3x,
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=30
#         " width="30"/>
# </a>
# </div>
# <div class="header__mobile__right">
# <a class="header__mobile__button" data-drawer-toggle="drawer-cart" href="/cart">
# <svg aria-hidden="true" class="icon icon-cart" focusable="false" role="presentation" viewbox="0 0 25 25"><path d="M5.058 23a2 2 0 1 0 4.001-.001A2 2 0 0 0 5.058 23zm12.079 0c0 1.104.896 2 2 2s1.942-.896 1.942-2-.838-2-1.942-2-2 .896-2 2zM0 1a1 1 0 0 0 1 1h1.078l.894 3.341L5.058 13c0 .072.034.134.042.204l-1.018 4.58A.997.997 0 0 0 5.058 19h16.71a1 1 0 0 0 0-2H6.306l.458-2.061c.1.017.19.061.294.061h12.31c1.104 0 1.712-.218 2.244-1.5l3.248-6.964C25.423 4.75 24.186 4 23.079 4H5.058c-.157 0-.292.054-.438.088L3.844.772A1 1 0 0 0 2.87 0H1a1 1 0 0 0-1 1zm5.098 5H22.93l-3.192 6.798c-.038.086-.07.147-.094.19-.067.006-.113.012-.277.012H7.058v-.198l-.038-.195L5.098 6z"></path></svg>
# <span class="visually-hidden">Cart</span>
# <span class="header__cart__status">
# <span data-header-cart-price="0">
#       $0.00
#     </span>
# <span data-header-cart-count="0">
#       (0)
#     </span>
# <span data-header-cart-full="false"></span>
# </span>
# </a>
# </div>
# </div>
# <div class="header__desktop header__desktop--split" data-header-desktop=""><div class="header__desktop__bar__l" data-takes-space="">
# <div class="header__logo header__logo--image">
# <a class="header__logo__link" href="/" style="--LOGO-WIDTH: 30px">
# <img alt="G R A Y E" class="logo__img logo__img--color" height="30" loading="eager" src="//grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=30" srcset="
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=60 2x,
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=90 3x,
#           //grayestudio.com/cdn/shop/files/GRAYE_SECONDARY_LOGO_MARK_GRAY.png?v=1680067071&amp;width=30
#         " width="30"/>
# </a>
# </div>
# </div>
# <div class="header__desktop__bar__r" data-takes-space="">
# <div class="header__desktop__bar__inline">
# <nav class="header__menu">
# <div class="header__menu__inner" data-text-items-wrapper="">
# <!-- /snippets/nav-item.liquid -->
# <div aria-controls="dropdown-ac061ab46f04475c307999887d48ca8a" aria-expanded="false" aria-haspopup="true" class="menu__item parent" data-hover-disclosure-toggle="dropdown-ac061ab46f04475c307999887d48ca8a" data-main-menu-text-item="" role="button">
# <a class="navlink navlink--toplevel" data-top-link="" href="/collections/new">
# <span class="navtext">SHOP</span>
# </a>
# <div class="header__dropdown" data-hover-disclosure="" id="dropdown-ac061ab46f04475c307999887d48ca8a">
# <div class="header__dropdown__wrapper">
# <div class="header__dropdown__inner">
# <a class="navlink navlink--child" data-stagger="" href="/collections/new">
# <span class="navtext">NEW IN</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/popular">
# <span class="navtext">POPULAR</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/young">
# <span class="navtext">BABY &amp; KIDS</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/t-shirts">
# <span class="navtext">T-SHIRTS</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/tops">
# <span class="navtext">TOPS</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/outerwears">
# <span class="navtext">OUTERWEAR</span>
# </a>
# <a class="navlink navlink--child main-menu--active" data-stagger="" href="/collections/pants">
# <span class="navtext">BOTTOMS</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/artefact">
# <span class="navtext">ARTEFACT (ACCESSORIES)</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="https://grayestudio.com/products/gift-card?variant=32324020306008">
# <span class="navtext">GIFT CARD</span>
# </a>
# <a class="navlink navlink--child highlight--link" data-stagger="" href="/collections/sale">
# <span class="navtext">SALE</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <!-- /snippets/nav-item.liquid -->
# <div aria-controls="dropdown-154a22647d0d8c8c75bccbc092e8205e" aria-expanded="false" aria-haspopup="true" class="menu__item parent" data-hover-disclosure-toggle="dropdown-154a22647d0d8c8c75bccbc092e8205e" data-main-menu-text-item="" role="button">
# <a class="navlink navlink--toplevel" data-top-link="" href="/pages/about-us">
# <span class="navtext">GRAYE</span>
# </a>
# <div class="header__dropdown" data-hover-disclosure="" id="dropdown-154a22647d0d8c8c75bccbc092e8205e">
# <div class="header__dropdown__wrapper">
# <div class="header__dropdown__inner">
# <a class="navlink navlink--child" data-stagger="" href="/pages/about-us">
# <span class="navtext">ABOUT</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/pages/envision-with-graye">
# <span class="navtext">ENVISION WITH GRAYE</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/pages/garment-care">
# <span class="navtext">GARMENT CARE</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/blogs/news">
# <span class="navtext">JOURNEY</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/workshop">
# <span class="navtext">WORKSHOPS</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/pages/explore-our-stores">
# <span class="navtext">OUR STORES</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <!-- /snippets/nav-item.liquid -->
# <div aria-controls="dropdown-91c0fb17b91c8ef1b62f43a50d46a3fc" aria-expanded="false" aria-haspopup="true" class="menu__item parent" data-hover-disclosure-toggle="dropdown-91c0fb17b91c8ef1b62f43a50d46a3fc" data-main-menu-text-item="" role="button">
# <a class="navlink navlink--toplevel" data-top-link="" href="/collections/young">
# <span class="navtext">YOUNG</span>
# </a>
# <div class="header__dropdown" data-hover-disclosure="" id="dropdown-91c0fb17b91c8ef1b62f43a50d46a3fc">
# <div class="header__dropdown__wrapper">
# <div class="header__dropdown__inner">
# <a class="navlink navlink--child" data-stagger="" href="/pages/young-by-graye">
# <span class="navtext">ABOUT YOUNG</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/pages/onesie-to-tee">
# <span class="navtext">ONESIE TO TEE</span>
# </a>
# <a class="navlink navlink--child" data-stagger="" href="/collections/young">
# <span class="navtext">SHOP YOUNG</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="hover__bar"></div>
# <div class="hover__bg"></div>
# </div>
# </nav>
# <div class="header__desktop__buttons header__desktop__buttons--icons"><div class="header__desktop__button">
# <a class="navlink" href="/account">
# <svg aria-hidden="true" class="icon icon-account" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M10.713 8.771c.31.112.53.191.743.27.555.204.985.372 1.367.539 1.229.535 1.993 1.055 2.418 1.885.464.937.722 1.958.758 2.997.03.84-.662 1.538-1.524 1.538H1.525c-.862 0-1.554-.697-1.524-1.538a7.36 7.36 0 0 1 .767-3.016c.416-.811 1.18-1.33 2.41-1.866a25.25 25.25 0 0 1 1.366-.54l.972-.35a1.42 1.42 0 0 0-.006-.072c-.937-1.086-1.369-2.267-1.369-4.17C4.141 1.756 5.517 0 8.003 0c2.485 0 3.856 1.755 3.856 4.448 0 2.03-.492 3.237-1.563 4.386.169-.18.197-.253.207-.305a1.2 1.2 0 0 0-.019.16l.228.082zm-9.188 5.742h12.95a5.88 5.88 0 0 0-.608-2.402c-.428-.835-2.214-1.414-4.46-2.224-.608-.218-.509-1.765-.24-2.053.631-.677 1.166-1.471 1.166-3.386 0-1.934-.782-2.96-2.33-2.96-1.549 0-2.336 1.026-2.336 2.96 0 1.915.534 2.709 1.165 3.386.27.288.369 1.833-.238 2.053-2.245.81-4.033 1.389-4.462 2.224a5.88 5.88 0 0 0-.607 2.402z"></path></svg>
# <span class="visually-hidden">My Account</span>
# </a>
# </div>
# <div class="header__desktop__button">
# <a class="navlink" data-popdown-toggle="search-popdown" href="/search">
# <svg aria-hidden="true" class="icon icon-search" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M16 14.864 14.863 16l-4.24-4.241a6.406 6.406 0 0 1-4.048 1.392 6.61 6.61 0 0 1-4.65-1.925A6.493 6.493 0 0 1 .5 9.098 6.51 6.51 0 0 1 0 6.575a6.536 6.536 0 0 1 1.922-4.652A6.62 6.62 0 0 1 4.062.5 6.52 6.52 0 0 1 6.575 0 6.5 6.5 0 0 1 9.1.5c.8.332 1.51.806 2.129 1.423a6.454 6.454 0 0 1 1.436 2.13 6.54 6.54 0 0 1 .498 2.522c0 1.503-.468 2.853-1.4 4.048L16 14.864zM3.053 10.091c.973.972 2.147 1.461 3.522 1.461 1.378 0 2.551-.489 3.525-1.461.968-.967 1.45-2.138 1.45-3.514 0-1.37-.482-2.545-1.45-3.524-.981-.968-2.154-1.45-3.525-1.45-1.376 0-2.547.483-3.513 1.45-.973.973-1.46 2.146-1.46 3.523 0 1.375.483 2.548 1.45 3.515z"></path></svg>
# <span class="visually-hidden">Search</span>
# </a>
# </div>
# <div class="header__desktop__button">
# <a class="navlink navlink--cart" data-drawer-toggle="drawer-cart" href="/cart">
# <svg aria-hidden="true" class="icon icon-cart" focusable="false" role="presentation" viewbox="0 0 25 25"><path d="M5.058 23a2 2 0 1 0 4.001-.001A2 2 0 0 0 5.058 23zm12.079 0c0 1.104.896 2 2 2s1.942-.896 1.942-2-.838-2-1.942-2-2 .896-2 2zM0 1a1 1 0 0 0 1 1h1.078l.894 3.341L5.058 13c0 .072.034.134.042.204l-1.018 4.58A.997.997 0 0 0 5.058 19h16.71a1 1 0 0 0 0-2H6.306l.458-2.061c.1.017.19.061.294.061h12.31c1.104 0 1.712-.218 2.244-1.5l3.248-6.964C25.423 4.75 24.186 4 23.079 4H5.058c-.157 0-.292.054-.438.088L3.844.772A1 1 0 0 0 2.87 0H1a1 1 0 0 0-1 1zm5.098 5H22.93l-3.192 6.798c-.038.086-.07.147-.094.19-.067.006-.113.012-.277.012H7.058v-.198l-.038-.195L5.098 6z"></path></svg>
# <span class="visually-hidden">Cart</span>
# <span class="header__cart__status">
# <span data-header-cart-price="0">
#       $0.00
#     </span>
# <span data-header-cart-count="0">
#       (0)
#     </span>
# <span data-header-cart-full="false"></span>
# </span>
# </a>
# </div>
# </div>
# </div>
# </div></div>
# </div>
# </div>
# </header>
# <nav aria-label="Main menu" class="drawer header__drawer display-none" data-drawer="hamburger" id="header-menu">
# <div class="drawer__content">
# <div class="drawer__top">
# <div class="drawer__top__left">
# <a class="drawer__account" href="/account">
# <svg aria-hidden="true" class="icon icon-account" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M10.713 8.771c.31.112.53.191.743.27.555.204.985.372 1.367.539 1.229.535 1.993 1.055 2.418 1.885.464.937.722 1.958.758 2.997.03.84-.662 1.538-1.524 1.538H1.525c-.862 0-1.554-.697-1.524-1.538a7.36 7.36 0 0 1 .767-3.016c.416-.811 1.18-1.33 2.41-1.866a25.25 25.25 0 0 1 1.366-.54l.972-.35a1.42 1.42 0 0 0-.006-.072c-.937-1.086-1.369-2.267-1.369-4.17C4.141 1.756 5.517 0 8.003 0c2.485 0 3.856 1.755 3.856 4.448 0 2.03-.492 3.237-1.563 4.386.169-.18.197-.253.207-.305a1.2 1.2 0 0 0-.019.16l.228.082zm-9.188 5.742h12.95a5.88 5.88 0 0 0-.608-2.402c-.428-.835-2.214-1.414-4.46-2.224-.608-.218-.509-1.765-.24-2.053.631-.677 1.166-1.471 1.166-3.386 0-1.934-.782-2.96-2.33-2.96-1.549 0-2.336 1.026-2.336 2.96 0 1.915.534 2.709 1.165 3.386.27.288.369 1.833-.238 2.053-2.245.81-4.033 1.389-4.462 2.224a5.88 5.88 0 0 0-.607 2.402z"></path></svg>
# <span class="visually-hidden">My Account</span>
# </a></div>
# <button aria-label="Close" class="drawer__button drawer__close" data-drawer-toggle="hamburger">
# <svg aria-hidden="true" class="icon icon-close" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.06 1 12.02 12.021-1.06 1.061L1 2.062z"></path><path d="M1 13.02 13.022 1l1.061 1.06-12.02 12.02z"></path></g></svg>
# </button>
# </div>
# <div class="drawer__inner" data-drawer-scrolls="">
# <div class="drawer__search" data-drawer-search="">
# <!-- /snippets/search-predictive.liquid -->
# <div data-search-popdown-wrap="">
# <div class="search-drawer search__predictive" data-popdown-outer="" id="search-drawer"><predictive-search><form action="/search" method="get" role="search">
# <div class="item--loadbar" data-loading-indicator="" style="display: none;"></div>
# <div class="search__predictive__outer">
# <div class="wrapper">
# <div class="search__predictive__main">
# <div class="search__predictive__actions">
# <button class="search__predictive__button" type="submit">
# <span class="visually-hidden">Search</span>
# <svg aria-hidden="true" class="icon icon-search" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M16 14.864 14.863 16l-4.24-4.241a6.406 6.406 0 0 1-4.048 1.392 6.61 6.61 0 0 1-4.65-1.925A6.493 6.493 0 0 1 .5 9.098 6.51 6.51 0 0 1 0 6.575a6.536 6.536 0 0 1 1.922-4.652A6.62 6.62 0 0 1 4.062.5 6.52 6.52 0 0 1 6.575 0 6.5 6.5 0 0 1 9.1.5c.8.332 1.51.806 2.129 1.423a6.454 6.454 0 0 1 1.436 2.13 6.54 6.54 0 0 1 .498 2.522c0 1.503-.468 2.853-1.4 4.048L16 14.864zM3.053 10.091c.973.972 2.147 1.461 3.522 1.461 1.378 0 2.551-.489 3.525-1.461.968-.967 1.45-2.138 1.45-3.514 0-1.37-.482-2.545-1.45-3.524-.981-.968-2.154-1.45-3.525-1.45-1.376 0-2.547.483-3.513 1.45-.973.973-1.46 2.146-1.46 3.523 0 1.375.483 2.548 1.45 3.515z"></path></svg>
# </button>
# <input aria-controls="predictive-search-results" aria-label="Search our store" data-predictive-search-input="search-popdown-results" name="q" placeholder="Search..." type="search" value=""/>
# <div class="search__predictive__clear">
# <button aria-label="Reset" class="search__predictive__close__inner search-reset is-hidden" type="reset">
# <svg aria-hidden="true" class="icon icon-close" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.06 1 12.02 12.021-1.06 1.061L1 2.062z"></path><path d="M1 13.02 13.022 1l1.061 1.06-12.02 12.02z"></path></g></svg>
# Clear</button>
# </div>
# </div>
# <div class="search__predictive__close">
# <button aria-label="Close" class="search__predictive__close__inner" data-close-popdown="" type="button">
# <svg aria-hidden="true" class="icon icon-close-small" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.237 1.073 12.021 12.021-1.414 1.414L.824 2.488z"></path><path d="m.823 13.094 12.021-12.02 1.414 1.413-12.02 12.021z"></path></g></svg>
# </button>
# </div>
# </div>
# </div>
# </div><div class="header__search__results" data-predictive-search-results="" tabindex="-1"></div>
# <span aria-hidden="true" class="predictive-search-status visually-hidden" data-predictive-search-status="" role="status"></span></form></predictive-search></div>
# <script data-predictive-search-aria-template="" type="text/x-template">
#     <div aria-live="polite">
#       <p>
#
#           {{@if(it.count)}}
#             <span class="badge">{{ it.count }}</span>
#           {{/if}}
#           {{ it.title }} <em>{{ it.query }}</em>
#
#       </p>
#     </div>
#   </script>
# <script data-predictive-search-title-template="" type="text/x-template">
#     <div class="search__results__heading">
#
#         <p>
#           <span class="search__results__title">{{ it.title }}</span>
#           <span class="badge">{{ it.count }}</span>
#         </p>
#
#     </div>
#   </script>
# <script data-search-other-template="" type="text/x-template">
#
#       {{@each(it) => object, index}}
#         <div class="other__inline animates" style="animation-delay: {{ index | animationDelay }}ms;">
#           <p class="other__inline__title">
#             <a href="{{ object.url }}">{{ object.title | safe }}</a>
#           </p>
#         </div>
#       {{/each}}
#
#   </script>
# <script data-search-product-template="" type="text/x-template">
#
#       {{@each(it) => object, index}}
#         <a href="{{ object.url }}" class="product__inline animates" style="animation-delay: {{ index | animationDelay }}ms;">
#           <div class="product__inline__image {{ @if (object.featured_image.width === null) }} product__inline__image--no-image {{ /if}}">
#             {{ @if (object.featured_image.width !== null) }}
#               <img class="img-aspect-ratio" width="{{object.featured_image.width}}" height="{{ object.featured_image.height }}" alt="{{ object.featured_image.alt }}" src="{{ object.thumb }}">
#             {{ /if}}
#           </div>
#           <div>
#             <p class="product__inline__title">
#               {{ object.title | safe }}
#             </p>
#             <p class="product__inline__price">
#               <span class="price {{ object.classes }}">
#                 {{ object.price | safe }}
#               </span>
#               {{@if(object.sold_out)}}
#                 <br /><em>{{ object.sold_out_translation }}</em>
#               {{/if}}
#               {{@if(object.on_sale)}}
#                 <span class="compare-at">
#                   {{ object.compare_at_price | safe }}
#                 </span>
#               {{/if}}
#             </p>
#           </div>
#         </a>
#       {{/each}}
#
#   </script>
# </div>
# </div>
# <div class="drawer__menu" data-sliderule-pane="0" data-stagger-animation="">
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper"><button class="sliderow" data-animates="0" data-sliderule-open="sliderule-df8e1ed0a18e833743bf2a0fd4e0361e">
# <span class="sliderow__title">SHOP</span>
# <span class="sliderule__chevron--right">
# <svg aria-hidden="true" class="icon icon-arrow-medium-right" focusable="false" role="presentation" viewbox="0 0 9 15"><path d="M6.875 7.066.87 1.06 1.93 0l6.006 6.005L7.94 6 9 7.06l-.004.006.005.005-1.06 1.06-.006-.004-6.005 6.005-1.061-1.06 6.005-6.006z" fill-rule="evenodd"></path></svg>
# <span class="visually-hidden">Expand menu</span>
# </span>
# </button>
# <div class="mobile__menu__dropdown sliderule__panel" data-sliderule="" id="sliderule-df8e1ed0a18e833743bf2a0fd4e0361e"><div class="sliderow sliderow__back" data-animates="1">
# <button class="drawer__button" data-sliderule-close="sliderule-df8e1ed0a18e833743bf2a0fd4e0361e">
# <span class="sliderule__chevron--left">
# <svg aria-hidden="true" class="icon icon-arrow-medium-left" focusable="false" role="presentation" viewbox="0 0 9 15"><path d="M2.127 7.066 8.132 1.06 7.072 0 1.065 6.005 1.061 6 0 7.06l.004.006L0 7.07l1.06 1.06.006-.004 6.005 6.005 1.061-1.06-6.005-6.006z" fill-rule="evenodd"></path></svg>
# <span class="visually-hidden">Hide menu</span>
# </span>
# </button>
# <a class="sliderow__title" href="/collections/new">SHOP</a>
# </div><div class="sliderow__links" data-links="">
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/new">NEW IN</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/popular">POPULAR</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/young">BABY &amp; KIDS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/t-shirts">T-SHIRTS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/tops">TOPS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/outerwears">OUTERWEAR</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/pants">BOTTOMS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/artefact">ARTEFACT (ACCESSORIES)</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="https://grayestudio.com/products/gift-card?variant=32324020306008">GIFT CARD</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title highlight--link" href="/collections/sale">SALE</a>
# </div></div>
# </div><div class="sliderule-grid blocks-0">
# </div></div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper"><button class="sliderow" data-animates="0" data-sliderule-open="sliderule-f99a83a8c336d3e3fae3c2ced23b8d7b">
# <span class="sliderow__title">GRAYE</span>
# <span class="sliderule__chevron--right">
# <svg aria-hidden="true" class="icon icon-arrow-medium-right" focusable="false" role="presentation" viewbox="0 0 9 15"><path d="M6.875 7.066.87 1.06 1.93 0l6.006 6.005L7.94 6 9 7.06l-.004.006.005.005-1.06 1.06-.006-.004-6.005 6.005-1.061-1.06 6.005-6.006z" fill-rule="evenodd"></path></svg>
# <span class="visually-hidden">Expand menu</span>
# </span>
# </button>
# <div class="mobile__menu__dropdown sliderule__panel" data-sliderule="" id="sliderule-f99a83a8c336d3e3fae3c2ced23b8d7b"><div class="sliderow sliderow__back" data-animates="1">
# <button class="drawer__button" data-sliderule-close="sliderule-f99a83a8c336d3e3fae3c2ced23b8d7b">
# <span class="sliderule__chevron--left">
# <svg aria-hidden="true" class="icon icon-arrow-medium-left" focusable="false" role="presentation" viewbox="0 0 9 15"><path d="M2.127 7.066 8.132 1.06 7.072 0 1.065 6.005 1.061 6 0 7.06l.004.006L0 7.07l1.06 1.06.006-.004 6.005 6.005 1.061-1.06-6.005-6.006z" fill-rule="evenodd"></path></svg>
# <span class="visually-hidden">Hide menu</span>
# </span>
# </button>
# <a class="sliderow__title" href="/pages/about-us">GRAYE</a>
# </div><div class="sliderow__links" data-links="">
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/pages/about-us">ABOUT</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/pages/envision-with-graye">ENVISION WITH GRAYE</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/pages/garment-care">GARMENT CARE</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/blogs/news">JOURNEY</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/collections/workshop">WORKSHOPS</a>
# </div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper">
# <div class="sliderow" data-animates="1">
# <a class="sliderow__title" href="/pages/explore-our-stores">OUR STORES</a>
# </div></div>
# </div><div class="sliderule-grid blocks-0">
# </div></div></div>
# <!-- /snippets/nav-item-mobile.liquid --><div class="sliderule__wrapper"><button class="sliderow" data-animates="0" data-sliderule-open="sliderule-975453dbb60e68f2cd134af896b8d431">
# ...
# <h2 class="visually-hidden" id="currency-heading-localization-form-footer">
#     Currency
#   </h2>
# <popout-select>
# <div class="popout" data-popout="">
# <button aria-controls="currency-list-localization-form-footer" aria-describedby="currency-heading-localization-form-footer" aria-expanded="false" class="popout__toggle" data-popout-toggle="" type="button">
#           SGD $<svg aria-hidden="true" class="icon icon--wide icon-arrow-down" focusable="false" role="presentation" viewbox="0 0 30 17"><path d="M0 3.235 3.525 0l11.473 10.509L26.473 0 30 3.235 14.998 17z" fill-rule="evenodd"></path></svg></button>
# <ul class="popout-list" data-popout-list="" id="currency-list-localization-form-footer">
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="AUD" href="#">
# <span>AUD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="BND" href="#">
# <span>BND $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="CAD" href="#">
# <span>CAD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="CHF" href="#">
# <span>CHF CHF</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="CNY" href="#">
# <span>CNY ¥</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="DKK" href="#">
# <span>DKK kr.</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="EUR" href="#">
# <span>EUR €</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="GBP" href="#">
# <span>GBP £</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="HKD" href="#">
# <span>HKD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="IDR" href="#">
# <span>IDR Rp</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="INR" href="#">
# <span>INR ₹</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="ISK" href="#">
# <span>ISK kr</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="JPY" href="#">
# <span>JPY ¥</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="KRW" href="#">
# <span>KRW ₩</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="MOP" href="#">
# <span>MOP P</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="MYR" href="#">
# <span>MYR RM</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="NZD" href="#">
# <span>NZD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="PHP" href="#">
# <span>PHP ₱</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="PLN" href="#">
# <span>PLN zł</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="SEK" href="#">
# <span>SEK kr</span>
# </a>
# </li>
# <li class="popout-list__item popout-list__item--current">
# <a aria-current="true" class="popout-list__option" data-popout-option="" data-value="SGD" href="#">
# <span>SGD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="THB" href="#">
# <span>THB ฿</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="TWD" href="#">
# <span>TWD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="USD" href="#">
# <span>USD $</span>
# </a>
# </li>
# <li class="popout-list__item">
# <a class="popout-list__option" data-popout-option="" data-value="VND" href="#">
# <span>VND ₫</span>
# </a>
# </li></ul>
# <input data-popout-input="" id="CurrencySelector-localization-form-footer" name="currency_code" type="hidden" value="SGD"/>
# </div>
# </popout-select>
# </div>
# </form><noscript><form accept-charset="UTF-8" action="/localization" class="locale-footer-nojs" enctype="multipart/form-data" id="localization-form-footer-noscript" method="post"><input name="form_type" type="hidden" value="localization"/><input name="utf8" type="hidden" value="✓"/><input name="_method" type="hidden" value="put"/><input name="return_to" type="hidden" value="/collections/pants"/><h2 class="visually-hidden" id="localization-form-footer-noscript-locale-heading">
#                   Currency
#                 </h2>
# <select aria-labelledby="localization-form-footer-noscript-currency-heading" name="country_code"><option value="AU">
#                       Australia (AUD
#                       $)
#                     </option><option value="BE">
#                       Belgium (EUR
#                       €)
#                     </option><option value="BN">
#                       Brunei (BND
#                       $)
#                     </option><option value="CA">
#                       Canada (CAD
#                       $)
#                     </option><option value="CN">
#                       China (CNY
#                       ¥)
#                     </option><option value="DK">
#                       Denmark (DKK
#                       kr.)
#                     </option><option value="FI">
#                       Finland (EUR
#                       €)
#                     </option><option value="FR">
#                       France (EUR
#                       €)
#                     </option><option value="DE">
#                       Germany (EUR
#                       €)
#                     </option><option value="HK">
#                       Hong Kong SAR (HKD
#                       $)
#                     </option><option value="IS">
#                       Iceland (ISK
#                       kr)
#                     </option><option value="IN">
#                       India (INR
#                       ₹)
#                     </option><option value="ID">
#                       Indonesia (IDR
#                       Rp)
#                     </option><option value="IE">
#                       Ireland (EUR
#                       €)
#                     </option><option value="IT">
#                       Italy (EUR
#                       €)
#                     </option><option value="JP">
#                       Japan (JPY
#                       ¥)
#                     </option><option value="MO">
#                       Macao SAR (MOP
#                       P)
#                     </option><option value="MY">
#                       Malaysia (MYR
#                       RM)
#                     </option><option value="MC">
#                       Monaco (EUR
#                       €)
#                     </option><option value="NL">
#                       Netherlands (EUR
#                       €)
#                     </option><option value="NZ">
#                       New Zealand (NZD
#                       $)
#                     </option><option value="NO">
#                       Norway (SGD
#                       $)
#                     </option><option value="PH">
#                       Philippines (PHP
#                       ₱)
#                     </option><option value="PL">
#                       Poland (PLN
#                       zł)
#                     </option><option value="PT">
#                       Portugal (EUR
#                       €)
#                     </option><option selected="" value="SG">
#                       Singapore (SGD
#                       $)
#                     </option><option value="KR">
#                       South Korea (KRW
#                       ₩)
#                     </option><option value="ES">
#                       Spain (EUR
#                       €)
#                     </option><option value="SE">
#                       Sweden (SEK
#                       kr)
#                     </option><option value="CH">
#                       Switzerland (CHF
#                       CHF)
#                     </option><option value="TW">
#                       Taiwan (TWD
#                       $)
#                     </option><option value="TH">
#                       Thailand (THB
#                       ฿)
#                     </option><option value="TR">
#                       Turkey (SGD
#                       $)
#                     </option><option value="GB">
#                       United Kingdom (GBP
#                       £)
#                     </option><option value="US">
#                       United States (USD
#                       $)
#                     </option><option value="VN">
#                       Vietnam (VND
#                       ₫)
#                     </option></select><button class="btn btn--primary btn--full">Update</button></form></noscript>
# </div>
# <div class="subfooter__item subfooter__item--copyright">
# <span class="subfooter__copyright"> © <a href="/" title="">G R A Y E</a> 2023 </span>
# <span class="subfooter__copyright"><a href="/pages/about-us">About</a></span>
# <span class="subfooter__copyright"><a href="/pages/contact-us">Contact</a></span>
# <span class="subfooter__copyright"><a href="/pages/delivery-information">Shipping</a></span>
# <span class="subfooter__copyright"><a href="/pages/return-and-exchange">Returns</a></span>
# <span class="subfooter__copyright"><a href="/pages/terms-conditions">Terms</a></span>
# <!-- The following lines fix Lighthouse security warnings on the Shopify link.--><!-- Remove the following line to delete Powered by Shopify from your footer -->
# <span class="subfooter__copyright" data-powered-link=""><a href="https://www.shopify.com?utm_campaign=poweredby&amp;utm_medium=shopify&amp;utm_source=onlinestore" rel="noopener" target="_blank">Powered by Shopify</a></span>
# <!-- Stop deleting here -->
# </div></div>
# </div>
# </section>
# </div>
# <!-- END sections: group-footer -->
# <div class="search--popdown">
# <!-- /snippets/search-predictive.liquid -->
# <div data-search-popdown-wrap="">
# <div class="search-popdown search__predictive" data-popdown-outer="" id="search-popdown"><predictive-search><form action="/search" method="get" role="search">
# <div class="item--loadbar" data-loading-indicator="" style="display: none;"></div>
# <div class="search__predictive__outer">
# <div class="wrapper">
# <div class="search__predictive__main">
# <div class="search__predictive__actions">
# <button class="search__predictive__button" type="submit">
# <span class="visually-hidden">Search</span>
# <svg aria-hidden="true" class="icon icon-search" focusable="false" role="presentation" viewbox="0 0 16 16"><path d="M16 14.864 14.863 16l-4.24-4.241a6.406 6.406 0 0 1-4.048 1.392 6.61 6.61 0 0 1-4.65-1.925A6.493 6.493 0 0 1 .5 9.098 6.51 6.51 0 0 1 0 6.575a6.536 6.536 0 0 1 1.922-4.652A6.62 6.62 0 0 1 4.062.5 6.52 6.52 0 0 1 6.575 0 6.5 6.5 0 0 1 9.1.5c.8.332 1.51.806 2.129 1.423a6.454 6.454 0 0 1 1.436 2.13 6.54 6.54 0 0 1 .498 2.522c0 1.503-.468 2.853-1.4 4.048L16 14.864zM3.053 10.091c.973.972 2.147 1.461 3.522 1.461 1.378 0 2.551-.489 3.525-1.461.968-.967 1.45-2.138 1.45-3.514 0-1.37-.482-2.545-1.45-3.524-.981-.968-2.154-1.45-3.525-1.45-1.376 0-2.547.483-3.513 1.45-.973.973-1.46 2.146-1.46 3.523 0 1.375.483 2.548 1.45 3.515z"></path></svg>
# </button>
# <input aria-controls="predictive-search-results" aria-label="Search our store" data-predictive-search-input="search-popdown-results" name="q" placeholder="Search..." type="search" value=""/>
# <div class="search__predictive__clear">
# <button aria-label="Reset" class="search__predictive__close__inner search-reset is-hidden" type="reset">
# <svg aria-hidden="true" class="icon icon-close" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.06 1 12.02 12.021-1.06 1.061L1 2.062z"></path><path d="M1 13.02 13.022 1l1.061 1.06-12.02 12.02z"></path></g></svg>
# Clear</button>
# </div>
# </div>
# <div class="search__predictive__close">
# <button aria-label="Close" class="search__predictive__close__inner" data-close-popdown="" type="button">
# <svg aria-hidden="true" class="icon icon-close-small" focusable="false" role="presentation" viewbox="0 0 15 15"><g fill-rule="evenodd"><path d="m2.237 1.073 12.021 12.021-1.414 1.414L.824 2.488z"></path><path d="m.823 13.094 12.021-12.02 1.414 1.413-12.02 12.021z"></path></g></svg>
# </button>
# </div>
# </div>
# </div>
# </div><div class="header__search__results" data-predictive-search-results="" tabindex="-1"></div>
# <span aria-hidden="true" class="predictive-search-status visually-hidden" data-predictive-search-status="" role="status"></span></form></predictive-search></div>
# <span class="drawer__underlay" data-search-underlay=""></span>
# <script data-predictive-search-aria-template="" type="text/x-template">
#     <div aria-live="polite">
#       <p>
#
#           {{@if(it.count)}}
#             <span class="badge">{{ it.count }}</span>
#           {{/if}}
#           {{ it.title }} <em>{{ it.query }}</em>
#
#       </p>
#     </div>
#   </script>
# <script data-predictive-search-title-template="" type="text/x-template">
#     <div class="search__results__heading">
#
#         <p>
#           <span class="search__results__title">{{ it.title }}</span>
#           <span class="badge">{{ it.count }}</span>
#         </p>
#
#     </div>
#   </script>
# <script data-search-other-template="" type="text/x-template">
#
#       {{@each(it) => object, index}}
#         <div class="other__inline animates" style="animation-delay: {{ index | animationDelay }}ms;">
#           <p class="other__inline__title">
#             <a href="{{ object.url }}">{{ object.title | safe }}</a>
#           </p>
#         </div>
#       {{/each}}
#
#   </script>
# <script data-search-product-template="" type="text/x-template">
#
#       {{@each(it) => object, index}}
#         <a href="{{ object.url }}" class="product__inline animates" style="animation-delay: {{ index | animationDelay }}ms;">
#           <div class="product__inline__image {{ @if (object.featured_image.width === null) }} product__inline__image--no-image {{ /if}}">
#             {{ @if (object.featured_image.width !== null) }}
#               <img class="img-aspect-ratio" width="{{object.featured_image.width}}" height="{{ object.featured_image.height }}" alt="{{ object.featured_image.alt }}" src="{{ object.thumb }}">
#             {{ /if}}
#           </div>
#           <div>
#             <p class="product__inline__title">
#               {{ object.title | safe }}
#             </p>
#             <p class="product__inline__price">
#               <span class="price {{ object.classes }}">
#                 {{ object.price | safe }}
#               </span>
#               {{@if(object.sold_out)}}
#                 <br /><em>{{ object.sold_out_translation }}</em>
#               {{/if}}
#               {{@if(object.on_sale)}}
#                 <span class="compare-at">
#                   {{ object.compare_at_price | safe }}
#                 </span>
#               {{/if}}
#             </p>
#           </div>
#         </a>
#       {{/each}}
#
#   </script>
# </div>
# </div>
# <div data-modal-container=""></div><!-- Paste popup code or third party scripts below this comment line ============== -->
# <!-- And above this comment line ================================================== -->
# <div class="shopify-block shopify-app-block" id="shopify-block-1513253815146976218">
# </div><div class="shopify-block shopify-app-block" id="shopify-block-9278379683843197553"></div>
# </body>

# %%
b_text = b_soup.find_all('div', {'class':'product__grid__info'})

# %%
# get partial product url

b_links = []

for a in b_text:
    anchor_tag = a.find('a')
    if anchor_tag:
        link = anchor_tag.get('href')
        b_links.append(link)

# %%
# get full url

b_links_list = []

for i in range(len(b_links)):
    rel_url = b_links[i]
    full_url = urljoin('https://grayestudio.com', rel_url)
    b_links_list.append(full_url)

# %%
# get product name

for url in b_links_list:
    b_url = url
    b_res = requests.get(b_url)
    b_soup = BeautifulSoup(b_res.content, 'lxml')

    product_text = b_soup.find('h1', {'class':'product__title heading-size-8'}).text.strip() 
    product.append(product_text)

# %%
# get material composition

for url in b_links_list:
    b_url = url
    b_res = requests.get(b_url)
    b_soup = BeautifulSoup(b_res.content, 'lxml')

    for a in b_soup.find_all('div', {'class':'tab-content tab-content-1'}):
        anchor_tag = a.find('span', {'class':'metafield-multi_line_text_field'} )
        if anchor_tag:
            text = anchor_tag.text.strip()
            material.append(text)

# %%
# get care instructions

for url in b_links_list:
    b_url = url
    b_res = requests.get(b_url)
    b_soup = BeautifulSoup(b_res.content, 'lxml')

    for a in b_soup.find_all('div', {'class':'tab-content tab-content-4'}):
        anchor_tag = a.find('span', {'class':'metafield-multi_line_text_field'} )
        if anchor_tag:
            text = anchor_tag.text.strip()
            wash_care.append(text)

# %%
print(len(product))
print(len(material))
print(len(wash_care))
# Out:
# 94
# 94
# 94

# %%
graye = pd.DataFrame({'product': product,
                      'material': material,
                      'wash_care': wash_care})

graye
# Out:
#                           product  \
# 0       V Ribbed Tee - Mint Green
# 1       V Ribbed Tee - Space Blue
# 2               Cupro tee - Stone
# 3               Cupro Tee - Brick
# 4          Cupro Tee - Jade Green
# ..                            ...
# 89    Unisex Boxer Shorts - Camel
# 90    Unisex Boxer Shorts - Ivory
# 91     Elasticated Workwear Pants
# 92  Detachable Suspender Trousers
# 93     Wide Sculpted Denim Shorts
#
#                                              material  \
# 0                                         100% Cotton
# 1                                         100% Cotton
# 2   49.8% Cupro\n46.1% Cotton\n4.1% Lycra\nDouble ...
# 3   49.8% Cupro\n46.1% Cotton\n4.1% Lycra\nDouble ...
# 4   49.8% Cupro\n46.1% Cotton\n4.1% Lycra \nDouble...
# ..                                                ...
# 89                                 100% Cotton Poplin
# 90                                 100% Cotton Poplin
# 91                                        100% Cotton
# 92                                        100% Cotton
# 93                     70% cotton 30% polyester blend
#
#                                             wash_care
# 0   Machine Wash Cool
# Do not bleach
# Do not tumble ...
# 1   Machine Wash Cool
# Do not bleach
# Do not tumble ...
# 2   Machine Wash Cool\nDo Not Bleach\nDo Not Tumbl...
# 3   Machine Wash Cool\nDo Not Bleach\nDo Not Tumbl...
# 4   Machine Wash Cool\nDo Not Bleach\nDo Not Tumbl...
# ..                                                ...
# 89  Machine Wash Cool\nDo Not Bleach\nDo Not Tumbl...
# 90  Machine Wash Cool\nDo Not Bleach\nDo Not Tumbl...
# 91  Machine Wash Cool\nDo Not Bleach\nDo Not Tumbl...
# 92  Machine Wash Cool\nWash With Similar Colours\n...
# 93  Machine Wash Cool\nDo not bleach\nDo not tumbl...
#
# [94 rows x 3 columns]

# %%
# save as csv

graye.to_csv('data/graye_og.csv', index=False)
